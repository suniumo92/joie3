# %% [markdown]
# # Assignment2

# %% [markdown]
# # Describe

# %% [markdown]
# We chose "Monitoring BBC podcasts" as our dataset. There are three datasets in "Monitoring BBC podcasts", one is about word timings which describes information of "start time","end time" as well as "word confidence" of each word. Another one is about "transcripts with punctuation and sentence level timings". This dataset shows the time of a sentence and also provide the number of the word in each sentence, also the "speakerId"(the id of speaker) and "summary prob"(the probability that this sentence will appear in an extractive summary) as well as other information in this sentence. The third one is related to the name of place which be hightlighted.
#
# The link of the data that I used in this assignment is http://data.cstr.ed.ac.uk/globalvox/extsumm/

# %% [markdown]
# In this assignment, I will focus on the second dataset which is about the sentences timing and different speakers and the data is in JSON format.
#
# 1.data type: It's the Json format and I will convert it into dataFrame and it will be tabular and textual.

# %% [markdown]
# First step, import JSON files.

# %%
import pandas as pd
import numpy as np
import urllib.request
import ijson #install ijson from this website https://pypi.python.org/pypi/ijson#downloads
import itertools
import requests
import bs4
import re

# %% [markdown]
# There are two folders in this dataset one is for 2016 and another one is for 2017.
# Here get all urls in folder 2016.

# %%
root_url = 'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/'
index_url = root_url + '?C=N;O=D'
def getUrls():
    response = requests.get(index_url)
    soup = bs4.BeautifulSoup(response.text, "lxml")
    return [a.attrs.get('href') for a in soup.select('[href^=2017]')]

urls = []
for item in getUrls():
    urls.append(root_url + item)
urls
# Out:
# ['http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170627060900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626231400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626222100worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626152800globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626151000worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626133100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626122200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626114500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170626060900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170625231500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170625210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170625171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170625130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170624233500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170624210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170624171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170624130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170624033000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170624030000inthebalance.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623230500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623151400worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623150500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623142900hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623142200thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623130400bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623125600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623055500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170623023000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622230600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622154400newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622151100worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622145300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622122200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622115000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622071000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622013000theinquiry.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621230500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621221300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621150500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621150300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621124300worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621120100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621103900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621075300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621074700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620230800globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620221600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620153400worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620150100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620120500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620115700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170620054000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619221700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619151500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619145000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619115700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619113000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619055100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170619004300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170618230900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170618210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170618171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170618130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170617230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170617210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170617171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170617130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170617083900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170617033000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170617030000inthebalance.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616230200globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616222600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616152800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616141100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616140600thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616135700hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616134900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616085000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170616054600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615230600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615215300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615153600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615145600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615113400hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615111000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615103500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615085100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615063500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615023000theinquiry.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614230500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614220300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614142900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614114200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614111600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614103300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614070500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614023000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613230400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613221500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613152000worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613143000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613130800worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613120700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613115300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613114200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170613062900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612230300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612224000worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612151400worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612142900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612115200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612111900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612111000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170612054400bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170611230300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170611210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170611173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170611130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170610230900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170610210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170610173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170610130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170610092600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170610072500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170610033000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170610023000inthebalance.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609234300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609230800globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609151300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609145600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609125700worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609123500thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609100300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609081000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170609020600hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608204300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608203200worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608151400worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608143900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608141400newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608113600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608105800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608100000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608092200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607151300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607143500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607130000worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607092500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607090300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607085600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607055900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606231700globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606215200worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606155500hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606152600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606143100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606130000worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606121100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606115900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606113700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170606060000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605221700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605172100worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605144400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605130000worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605114100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605113700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605112700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170605055700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170604230200globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170604210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170604173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170604153900hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170604130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170604123600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170603224800globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170603210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170603171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170603130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170603080500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170603070300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170603033000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602234300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602222100worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602152600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602145500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602135200thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602130000worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602121700worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602121300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602114000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170602064600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601224800globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601223100worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601160800hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601143300worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601133400bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601130000worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601120000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601064100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601013000theinquiry.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531225000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531223000worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531150600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531150500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531142300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531130000worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531122400bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531111000worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531064600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530232400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530150800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530141100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530130000worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530114600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530114500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170530054200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529232000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529152000worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529141700globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529105500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529103900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529103100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529095600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529054300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170529013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170528230900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170528210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170528171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170528130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170527230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170527210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170527171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170527130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170527033000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170527023000inthebalance.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526222300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526151800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526150700globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526124900thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526121900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526121100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526113100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170526013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525232500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525225100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525151100worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525144200globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525120600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525114300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525112500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525063800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170525013000theinquiry.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524213300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524151600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524145800globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524102500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524094900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170524062900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523231700globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523215000worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523191700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523153300hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523145300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170523093600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522230900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522215500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522152300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522151300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522142700globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522124700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522113600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522112800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522103800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522055000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522004500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170521230300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170521210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170521171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170521130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170520230400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170520210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170520171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170520130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170520033000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170520023000inthebalance.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519231600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519221500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519153200worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519150400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519134200thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519114600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519112900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519063700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170519013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518232600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518222700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518153800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518152400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518114100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518104200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518085200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518060500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170518013000theinquiry.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517221900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517213700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517153500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517145300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517115000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517105700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517102200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517055000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170517013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516221400worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516153700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516143300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516113200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516111400bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516072500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170516060500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515232700globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515220800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515152600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515150200globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515132600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515123500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515114700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515110800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515104100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515003800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170514230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170514210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170514130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170513230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170513210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170513171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170513130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170513033000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512225400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512224800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512151900worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512151800globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512140100thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512133900hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512113900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512105500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512102200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512070200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170512010600hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170511230200globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170511210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170511173000sixoclocknews.extsumm.asrsent.json',
# ...
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170405115300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170405061200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170405013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404230000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404223000worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404150700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404142300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404113600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404111300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404101600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170404054600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403225200globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403223300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403150800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403144000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403120200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403115000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403113000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170403053900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170402231100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170402210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170402171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170402130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401081300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401075800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401074700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401023000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331230100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331221300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331154000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331153200worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331151700hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331142400newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331132700thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331122100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331115500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331111500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331054200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170331013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330230500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330220100worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330152000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330150400worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330114900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330112700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330105600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330094600worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330064300bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170330013000theinquiry.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329230400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329220800worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329144900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329115100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329094800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329063100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170329013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170328231300globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170328153700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170328150900globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170328124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170328115800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170328090400bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170328082600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170328055800bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327225600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327221000worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327173000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327154200worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327144000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327124500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327123100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327120900bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327080100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327071500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327013000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170327003700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170326230400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170326210000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170326171500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170326130000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170326000100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325220000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325181500sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325140000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325110100bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325103400bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325090400bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325033000theworldthisweek.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325003200globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170325000200worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324220000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324183000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324161400globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324150000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324145600thefifthfloor.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324134500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324125200bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324121500bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324111700bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324100100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324070600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324023000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324011000globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170324001900worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323220000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323183000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323182200worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323160100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323150000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323134500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323132000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323100100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323071000bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170323014500globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322231300worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322220000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322183000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322182200worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322162800globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322150000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322134500worldatone.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322124600bestoftoday.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322102600globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322023000hardtalk.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170322000100globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170321232700worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170321220000newshour.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170321183000sixoclocknews.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170321181500worldbusinessreport.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170321155700globalnewspodcast.extsumm.asrsent.json',
#  'http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170321150000newshour.extsumm.asrsent.json',
#  ...]

# %% [markdown]
# Find all JSON files on June 23rd which is the day related to "Vote Leave" and print their indexs.

# %%
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170407230200globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170401023000theworldthisweek.extsumm.asrsent.json") + 1,"]")
# Out:
# [ 810 : 882 ]

# %%
########input these indexs and merge these files into one dataFrame###########

speakerInfo = []
for item in urls[810:882]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo.append(segments[num])
        
speakerInfo
# Out:
# [{'SummaryProb': Decimal('0.2874'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('37.62'),
#   'nwords': 83,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.1',
#   'speakerId': 's0001',
#   'startTime': Decimal('6.77'),
#   'trans': "This is the B.B.C. for details of a complete range of programmes go to B.B.C. world service dot com forward slash, Welcome to the latest global news compiled in the early hours of Saturday, the eighth of April, I'm Jackie Leonard, with a selection of highlights from across B.B.C. world service news today coming up at least four people have been killed and fifteen injured after a truck, was hijacked and driven into pedestrians in the Swedish capital Stockholm gunshots were also reported."},
#  {'SummaryProb': Decimal('0.0034'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('39.21'),
#   'nwords': 5,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.2',
#   'speakerId': 's0001',
#   'startTime': Decimal('37.87'),
#   'trans': 'So your hobby ripped there.'},
#  {'SummaryProb': Decimal('0.0188'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('39.69'),
#   'nwords': 2,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.3',
#   'speakerId': 's0001',
#   'startTime': Decimal('39.3'),
#   'trans': 'Thank you.'},
#  {'SummaryProb': Decimal('0.0129'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('42.19'),
#   'nwords': 4,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.4',
#   'speakerId': 's0001',
#   'startTime': 41,
#   'trans': 'Sweden has been attacked.'},
#  {'SummaryProb': Decimal('0.1309'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('54.49'),
#   'nwords': 37,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.5',
#   'speakerId': 's0001',
#   'startTime': Decimal('42.36'),
#   'trans': "Everything indicates that this is a terrorist attack or hear from Stockholm, we'll also have more on the implications of the American attack on a Syrian air base as Moscow warns, it could have extremely serious consequences."},
#  {'SummaryProb': Decimal('0.2176'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('76.54'),
#   'nwords': 55,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.6',
#   'speakerId': 's0001',
#   'startTime': Decimal('57.7'),
#   'trans': "This is an act of aggression, justified by a completely invented pretext, also in the podcast Malaysia bids farewell to hosting the annual formula one Grand Prix saying the cost can no longer be justified and the radical new study that's transforming our understanding of the workings of the human memory more on those stories."},
#  {'SummaryProb': Decimal('0.0582'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('85.82'),
#   'nwords': 31,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.7',
#   'speakerId': 's0001',
#   'startTime': Decimal('76.54'),
#   'trans': 'Later, but first, you may remember that, as we were recording the last podcast news was just breaking in Sweden, but his truck had driven into pedestrians in the capital, Stockholm.'},
#  {'SummaryProb': Decimal('0.0494'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('91.46'),
#   'nwords': 18,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.8',
#   'speakerId': 's0001',
#   'startTime': Decimal('86.2'),
#   'trans': 'At the time, we knew only that several people had been injured, the city quickly went into locked.'},
#  {'SummaryProb': Decimal('0.2883'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('135.11'),
#   'nwords': 100,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.9',
#   'speakerId': 's0001',
#   'startTime': Decimal('96.73'),
#   'trans': "We now know that four People were killed and at least fifteen more were injured and have the pet or Jean was, I heard that noise, I heard the screams, I saw the people as they walked immediately, and there were just outside a store, there were dead dog owners screaming that was Lady laying with the severed furtive there were blood everywhere, Bell bodies on the ground everywhere, in a sense of panic people standing by beloved ones, but also people running away these Swedish Prime Minister's Stephane Louvain described it as a terrorist incident, so your hobby report."},
#  {'SummaryProb': Decimal('0.0049'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('135.85'),
#   'nwords': 3,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.10',
#   'speakerId': 's0001',
#   'startTime': Decimal('135.25'),
#   'trans': 'I thank you.'},
#  {'SummaryProb': Decimal('0.0059'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('138.39'),
#   'nwords': 4,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.11',
#   'speakerId': 's0001',
#   'startTime': Decimal('137.2'),
#   'trans': 'Sweden has been attacked.'},
#  {'SummaryProb': Decimal('0.0044'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('140.81'),
#   'nwords': 8,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.12',
#   'speakerId': 's0001',
#   'startTime': Decimal('138.56'),
#   'trans': 'Everything indicates that this is a terrorist attack.'},
#  {'SummaryProb': Decimal('0.0238'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('143.21'),
#   'nwords': 5,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.13',
#   'speakerId': 's0001',
#   'startTime': Decimal('141.54'),
#   'trans': 'The government is obviously informed.'},
#  {'SummaryProb': Decimal('0.0301'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('150.43'),
#   'nwords': 20,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.14',
#   'speakerId': 's0001',
#   'startTime': Decimal('143.25'),
#   'trans': 'All the time we get continuous information, the government is doing everything to support the authorities, who are working now.'},
#  {'SummaryProb': Decimal('0.029'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('159.46'),
#   'nwords': 36,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.15',
#   'speakerId': 's0001',
#   'startTime': Decimal('150.43'),
#   'trans': "We urge the public to be alert and listen not, at least on the police information, and now we think about the victims and their families, and the injured, and that's what I have to say."},
#  {'SummaryProb': Decimal('0.0076'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('161.12'),
#   'nwords': 5,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.16',
#   'speakerId': 's0001',
#   'startTime': Decimal('159.46'),
#   'trans': 'Now, I return to Stockholm.'},
#  {'SummaryProb': Decimal('0.7655'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('204.4'),
#   'nwords': 122,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.17',
#   'speakerId': 's0001',
#   'startTime': Decimal('161.12'),
#   'trans': "Now, the police have made an arrest and just before we recorded this podcast current fuggle and a reporter at the Swedish public broadcaster., S.V., t. in Stockholm, told us more about the arrest, the police arrested one man in mashed in a residential neighbourhood than Merced suburb in northern stock are quite close to the airport, and we don't know much about this man, yet we don't know if he is the attacker, But he is probably the same man, that the police was looking for, and they also sent out photographs of him, trying to find him, and they arrested him because they saw him in the store, and he was acting weird and that made them do this arrest."},
#  {'SummaryProb': Decimal('0.079'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('219.85'),
#   'nwords': 43,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.18',
#   'speakerId': 's0001',
#   'startTime': Decimal('204.63'),
#   'trans': 'What I also think is interesting is that mashed this suburb and Stockholm is also where one of the paras attackers, though, at least one a prison, I was involved in the attack, and some way Muhammad Bell Cade lived for three years.'},
#  {'SummaryProb': Decimal('0.0787'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('228.08'),
#   'nwords': 17,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.19',
#   'speakerId': 's0001',
#   'startTime': Decimal('220.01'),
#   'trans': "He was later killed in Brussels during a terrorist raided, it's obviously been a very shocking attack."},
#  {'SummaryProb': Decimal('0.0661'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('231.53'),
#   'nwords': 7,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.20',
#   'speakerId': 's0001',
#   'startTime': Decimal('228.6'),
#   'trans': 'What has been the reaction in Sweden.'},
#  {'SummaryProb': Decimal('0.4482'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('265.63'),
#   'nwords': 98,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.21',
#   'speakerId': 's0001',
#   'startTime': Decimal('231.53'),
#   'trans': "What are people saying to each while people are very devastated, of course, shocked that this happened, but also a lot of people, not that surprised there did happen, we didn't sort of waiting for it to happen, because we hadn't attacked six years ago that time, it was a suicide attack, who failed, but it was the same street, the same area, there's a very, very busy shopping street had that that part, but also has been a lot of love among the people in stock, I'm among the people in Sweden, you can look on Facebook."},
#  {'SummaryProb': Decimal('0.0475'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('270.02'),
#   'nwords': 15,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.22',
#   'speakerId': 's0001',
#   'startTime': Decimal('265.94'),
#   'trans': 'People are opening up their homes and stock on for those who cannot get home.'},
#  {'SummaryProb': Decimal('0.0128'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('272.02'),
#   'nwords': 7,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.23',
#   'speakerId': 's0001',
#   'startTime': Decimal('270.02'),
#   'trans': 'Because the subway has been shut down.'},
#  {'SummaryProb': Decimal('0.0834'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('282.01'),
#   'nwords': 36,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.24',
#   'speakerId': 's0001',
#   'startTime': Decimal('272.24'),
#   'trans': "It's been difficult to get out of stock on to leave your offers, so their Results have been a lot of love, a story in my neighbourhood, which is in the suburb of Sweden, I've stuck."},
#  {'SummaryProb': Decimal('0.0399'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('289.27'),
#   'nwords': 18,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.25',
#   'speakerId': 's0001',
#   'startTime': Decimal('282.01'),
#   'trans': "I handed out free food to children, because their Mamas mums and dad couldn't get home from work."},
#  {'SummaryProb': Decimal('0.0305'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('290.85'),
#   'nwords': 7,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.26',
#   'speakerId': 's0001',
#   'startTime': Decimal('289.45'),
#   'trans': "So there's been a lot of love."},
#  {'SummaryProb': Decimal('0.0641'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('294.12'),
#   'nwords': 9,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.27',
#   'speakerId': 's0001',
#   'startTime': Decimal('291.66'),
#   'trans': 'So how ready was Sweden for such an incident.'},
#  {'SummaryProb': Decimal('0.3004'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('319.32'),
#   'nwords': 78,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.28',
#   'speakerId': 's0001',
#   'startTime': Decimal('294.26'),
#   'trans': "Here's our security correspondent Frank Gardner, Sweden was totally unprepared for this, they've not had a terrorist attack there for seven years, the last thing was in twenty ten were in a failed suicide bomber blew himself up in the centre, a stock and that shocked people, but then they got back on with their normal lives and there isn't the sense of security, Sweden, like Germany's very averse to surveillance, they're very much a liberal open society."},
#  {'SummaryProb': Decimal('0.0204'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('322.35'),
#   'nwords': 11,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.29',
#   'speakerId': 's0001',
#   'startTime': Decimal('319.82'),
#   'trans': 'Although the pendulum is starting to swing in the other direction.'},
#  {'SummaryProb': Decimal('0.0238'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('328.46'),
#   'nwords': 19,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.30',
#   'speakerId': 's0001',
#   'startTime': Decimal('322.38'),
#   'trans': "I've just spent two days at a conference in Stockholm, and they are vulnerable, there's no question about it."},
#  {'SummaryProb': Decimal('0.0909'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('347.24'),
#   'nwords': 50,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.31',
#   'speakerId': 's0001',
#   'startTime': Decimal('328.71'),
#   'trans': "There are areas of the suburbs and places like Gothenburg, where the police don't even go into their own noon terrorist finances that people who are financing Isis who financing ocean, and I'm told that Swedish legislation, just simply doesn't have the law in place to crack down on them."},
#  {'SummaryProb': Decimal('0.0465'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('355.87'),
#   'nwords': 28,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.32',
#   'speakerId': 's0001',
#   'startTime': Decimal('347.43'),
#   'trans': "So, so far, the NA sort of terrorism efforts are directed outwards, but the fear is that it's only a matter of time before it becomes directed inwards."},
#  {'SummaryProb': Decimal('0.8032'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('414.99'),
#   'nwords': 146,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.33',
#   'speakerId': 's0001',
#   'startTime': Decimal('356.05'),
#   'trans': "So they are sitting, I think, on a sort Of simmering time bomb, and it's a worry that was Frank Gardner, a security correspondent outrage from Russia support from most of the West, the world is divided in its reaction to Presidents trumps most decisive most dramatic foreign policy move, since entering the white House, a missile attack on a Syrian government airbase U.S. officials had the base had been used to launch a chemical weapons attack in North Western Syria that left dozens of civilians dead on Tuesday, a Republican Senator who sits on the U.S. Senate foreign relations Committee Corey gardener, said President trump was demonstrating that America was no longer impotent on the international stage, it would appear that the era of leaping from behind mission of Nations, and how that will be two and into the side regime and peace and Syria."},
#  {'SummaryProb': Decimal('0.1902'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('441.99'),
#   'nwords': 69,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.34',
#   'speakerId': 's0001',
#   'startTime': Decimal('415.59'),
#   'trans': "So, how do you have you is that a correspondent in Washington, Italy, mud pool, it's certainly shared by most people in his party, if you're talking international as we were, of course, there's the outrage from Syria calling in a rash action and from Russia, but NA in terms of allies, the British U.N. envoy has that Bush our said, has been put on notice by the strike."},
#  {'SummaryProb': Decimal('0.038'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('451.29'),
#   'nwords': 24,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.35',
#   'speakerId': 's0001',
#   'startTime': Decimal('441.99'),
#   'trans': 'Canada has said it fully supports the air strikes France as well, and Jordan, crucially, also says, it was a necessary, an appropriate response.'},
#  {'SummaryProb': Decimal('0.0443'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('464.21'),
#   'nwords': 27,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.36',
#   'speakerId': 's0001',
#   'startTime': Decimal('451.81'),
#   'trans': "China's responses interesting, of course, NA she's here at the moment, and it is with President trump in moral, Ah, Go on his estate in in Florida."},
#  {'SummaryProb': Decimal('0.0323'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('473.56'),
#   'nwords': 22,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.37',
#   'speakerId': 's0001',
#   'startTime': Decimal('464.47'),
#   'trans': "It hasn't condemned as this attack, but says it all along opposed the use of force, and has urged for Carmen restraint."},
#  {'SummaryProb': Decimal('0.5393'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('520.22'),
#   'nwords': 129,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.38',
#   'speakerId': 's0001',
#   'startTime': Decimal('473.89'),
#   'trans': "Now, here in the U.S there has been a lot of praise, even from some Democrats for this action and or a lot of Republicans, like the one you heard, there have been coming out onto the T.V. networks and saying, finally, we have a strong President, there are those, like Rand Paul within the Republican party who are saying this is not what we we signed up for this is not something that we should get involved in in the Middle East, and there are others who were urging caution, like Kerr, John McCain, who of course gram for President as well in the past, saying, we shouldn't get too excited by this, this isn't the beginning of the end, he said, it's the end of the beginning."},
#  {'SummaryProb': Decimal('0.0168'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('524.33'),
#   'nwords': 6,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.39',
#   'speakerId': 's0001',
#   'startTime': Decimal('520.79'),
#   'trans': 'This is a targeted limited action.'},
#  {'SummaryProb': Decimal('0.0508'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('534.59'),
#   'nwords': 29,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.40',
#   'speakerId': 's0001',
#   'startTime': Decimal('524.33'),
#   'trans': 'Of course, we know that the Russians were warned head of these air strikes and clearly the implication, there is that they then warn the Syrian army as well.'},
#  {'SummaryProb': Decimal('0.0569'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('543.7'),
#   'nwords': 29,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.41',
#   'speakerId': 's0001',
#   'startTime': Decimal('535.07'),
#   'trans': 'This is sending a message, this is not necessarily changing the complexion of the war, having a good relationship with Russia is a good thing, not a bad thing.'},
#  {'SummaryProb': Decimal('0.0197'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('546.52'),
#   'nwords': 10,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.42',
#   'speakerId': 's0001',
#   'startTime': Decimal('543.88'),
#   'trans': 'So tweeted President trump at the beginning of the year.'},
#  {'SummaryProb': Decimal('0.0292'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('548.94'),
#   'nwords': 8,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.43',
#   'speakerId': 's0001',
#   'startTime': Decimal('546.79'),
#   'trans': 'These strikes have certainly not created the atmosphere.'},
#  {'SummaryProb': Decimal('0.108'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('562.24'),
#   'nwords': 37,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.44',
#   'speakerId': 's0001',
#   'startTime': Decimal('548.94'),
#   'trans': "He was hoping for Moscow, which backs the Asad regime Has reacted furiously immediately announcing that Syria's air defences would be strengthened Sarah rains Fred has been following the day's events from Moscow and sent this report."},
#  {'SummaryProb': Decimal('0.0073'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('563.41'),
#   'nwords': 4,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.45',
#   'speakerId': 's0001',
#   'startTime': Decimal('562.83'),
#   'trans': 'Why do you have.'},
#  {'SummaryProb': Decimal('0.0061'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('563.71'),
#   'nwords': 2,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.46',
#   'speakerId': 's0001',
#   'startTime': Decimal('563.43'),
#   'trans': 'Well done.'},
#  {'SummaryProb': Decimal('0.1433'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': 582,
#   'nwords': 41,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.47',
#   'speakerId': 's0001',
#   'startTime': Decimal('565.76'),
#   'trans': "Russia's response to the U.S. missile strike was swift and strong first Vladimir Putin called it an act of aggression, t. v. bulletins were then filled with voiceless of condemnation Russia insists, there's no evidence Syrian government troops used chemical weapons."},
#  {'SummaryProb': Decimal('0.056'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('589.66'),
#   'nwords': 23,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.48',
#   'speakerId': 's0001',
#   'startTime': Decimal('582.13'),
#   'trans': 'So the foreign Minister has compared to U.S action overnight to the invasion of Iraq, and suggested the aim, again, is regime change.'},
#  {'SummaryProb': Decimal('0.0205'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('593.82'),
#   'nwords': 12,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.49',
#   'speakerId': 's0001',
#   'startTime': Decimal('590.16'),
#   'trans': 'Others believe Donald trump was looking for a popularity boost back home.'},
#  {'SummaryProb': Decimal('0.0081'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('596.17'),
#   'nwords': 7,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.50',
#   'speakerId': 's0001',
#   'startTime': Decimal('594.09'),
#   'trans': 'One m. p. just love Nick enough.'},
#  {'SummaryProb': Decimal('0.461'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('641.81'),
#   'nwords': 112,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.51',
#   'speakerId': 's0001',
#   'startTime': Decimal('596.25'),
#   'trans': "Once that was a risky move, it's definitely that aggressive act against international law against a sovereign country without any evidence of the regime guilty of using chemical, I think the logical American domestic policies are prevail and brought us all to have quite a dangerous got their policy that ask it is someone at this, it is to date, the defence Ministry presented video footage from the airfield targeted the runway looks intact as de several fighter jets, but there's smouldering wreckage, and a lot of shrapnel in response Moscow says it's suspended an important information sharing deal with the U.S. meant to prevent accidents in the crowded skies over Syria."},
#  {'SummaryProb': Decimal('0.2633'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('665.64'),
#   'nwords': 70,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.52',
#   'speakerId': 's0001',
#   'startTime': Decimal('642.51'),
#   'trans': 'Russia had hoped, a new team in the white House could work with Moscow in Syria, where it claims to be fighting Terrorism, a common enemy, the tone of general eager can have today suggest that that has changed, and the others are going to start trying to give me administrations in America change their method of launching a horse has not changed since the bombing Yugoslavia, Iraq and Libya.'},
#  {'SummaryProb': Decimal('0.0487'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('673.33'),
#   'nwords': 20,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.53',
#   'speakerId': 's0001',
#   'startTime': Decimal('665.9'),
#   'trans': 'Once again, the protects is not objective investigation, but unfounded claims and twist the facts, with elections do next year.'},
#  {'SummaryProb': Decimal('0.0366'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('678.44'),
#   'nwords': 15,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.54',
#   'speakerId': 's0001',
#   'startTime': Decimal('673.36'),
#   'trans': 'Vladimir Putin could look to gain from this politically stepping up talk of external enemies.'},
#  {'SummaryProb': Decimal('0.1074'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('693.26'),
#   'nwords': 39,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.55',
#   'speakerId': 's0001',
#   'startTime': Decimal('678.44'),
#   'trans': 'Once again, presenting himself as the safe, strong choice in uncertain times, the Chief casualty event could well be the relationship with America, Muscat once claimed high hopes for Donald trump the strike on Syria is a reality check.'},
#  {'SummaryProb': Decimal('0.5414'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('735.71'),
#   'nwords': 105,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.56',
#   'speakerId': 's0001',
#   'startTime': Decimal('693.94'),
#   'trans': "Sarah Rainford in Moscow and before her, we had from Aly mud ball in Washington, but what's been the reaction in the region, faddy have Cora is an analyst at the Royal Institute of International Affairs here in London than Damon asked him what effect are u. s. strike would have on the attitude of Iran, one of the major players in the conflict, ought to get her support of the Asad regime, I think a bolster Iran's calculation that they have to stick with a Parrot and not give him is the strategic guarantor of her interest in the area, and in their region."},
#  {'SummaryProb': Decimal('0.1433'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('768.26'),
#   'nwords': 42,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.57',
#   'speakerId': 's0001',
#   'startTime': Decimal('737.52'),
#   'trans': 'How will that support show itself already, they are providing weapons for Hezbollah from Lebanon to fight in the ceria will there be More of that fighters and other, Turkey, of course, is very much opposed to the continued Presidency a batter.'},
#  {'SummaryProb': Decimal('0.1255'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('793.36'),
#   'nwords': 50,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.58',
#   'speakerId': 's0001',
#   'startTime': Decimal('769.49'),
#   'trans': "Will there be an escalation of Turkish limited, it's been so far checkmated quite effectively by Russia, Iran and the United States, not dull, Turkey will be cheering could be recent U.S. that the U.S. attack against the cubs horses in Syria and get anything get turtle will are gone."},
#  {'SummaryProb': Decimal('0.069'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('808.36'),
#   'nwords': 28,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.59',
#   'speakerId': 's0001',
#   'startTime': Decimal('793.37'),
#   'trans': "Do you like potato or two to enlarge this attack ultimate lead in order to accelerate the, so what's your analysis of what the U.S. can do next."},
#  {'SummaryProb': Decimal('0.0355'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('812.44'),
#   'nwords': 16,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.60',
#   'speakerId': 's0001',
#   'startTime': Decimal('808.51'),
#   'trans': "Is it, it's going to say, this is just a limited strike, because a chemical weapons."},
#  {'SummaryProb': Decimal('0.01'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('813.5'),
#   'nwords': 3,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.61',
#   'speakerId': 's0001',
#   'startTime': Decimal('812.71'),
#   'trans': "And that's it."},
#  {'SummaryProb': Decimal('0.0541'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('820.11'),
#   'nwords': 19,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.62',
#   'speakerId': 's0001',
#   'startTime': Decimal('813.5'),
#   'trans': "If that's the case, there will be more images won't there of civilian suffering as the Syrian army attacks."},
#  {'SummaryProb': Decimal('0.1298'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('858.34'),
#   'nwords': 50,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.63',
#   'speakerId': 's0001',
#   'startTime': Decimal('820.4'),
#   'trans': 'So is the United States now in the position to continue to act, or is it a one off art institutions Arthur seems to be a one off a tractor work limited in include every morsel of Asad from, so how warmly would you advise those in opposition, the bus.'},
#  {'SummaryProb': Decimal('0.0402'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('865.87'),
#   'nwords': 18,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.64',
#   'speakerId': 's0001',
#   'startTime': Decimal('858.45'),
#   'trans': "I'll are sad to see this as an opportunity for an end to his regime, not here yet."},
#  {'SummaryProb': Decimal('0.2738'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('902.64'),
#   'nwords': 77,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.65',
#   'speakerId': 's0001',
#   'startTime': Decimal('865.91'),
#   'trans': "I think that this was a very limited their strike, the fact also that unites States did in one brush up beforehand, the bodice attack, which we wait and see, because we've been dear Buddy had Cora and analyst at the London based Royal Institute of International Affairs, so just how big a shift is this in U.S. regional policy, a question for our defence and diplomatic correspondent Jonathan Marcus, that's still very much to be seen."},
#  {'SummaryProb': Decimal('0.1219'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('923.56'),
#   'nwords': 63,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.66',
#   'speakerId': 's0001',
#   'startTime': Decimal('902.64'),
#   'trans': "Mister trump has said that the chemical weapons attack, and the Americans, of course, still insist that that is what it was, has changed his view on Syria, we've not yet had a coherent American policy or programme, or you no idea of how it will work with its allies to achieve a piece, not just in Syria, but in the wider region."},
#  {'SummaryProb': Decimal('0.1974'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('950.57'),
#   'nwords': 78,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.67',
#   'speakerId': 's0001',
#   'startTime': Decimal('923.82'),
#   'trans': "The troubled ministrations approach has been very much to focus on the struggle against so called bias, Sir, whether this really marks that kind of shift in American policy, or whether this isn't a more limited thing simply the Americans as Donald trump said in the wake of the attack reinforcing this red line that my Obama did not enforce the prohibition against the use of chemical weapons and showing and demonstrating that, if countries to use them."},
#  {'SummaryProb': Decimal('0.0062'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('952.02'),
#   'nwords': 4,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.68',
#   'speakerId': 's0001',
#   'startTime': Decimal('950.7'),
#   'trans': 'There will be consequences.'},
#  {'SummaryProb': Decimal('0.194'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('969.44'),
#   'nwords': 59,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.69',
#   'speakerId': 's0001',
#   'startTime': Decimal('952.18'),
#   'trans': "It's certainly that, whether it is anything that message I can has gone out loud and clear, both the Russians and to the Syrians, but whether it's anything more than that will obviously have to wait and see that was Jonathan Marcus, you're listening to global news, the most important stories and the best interviews, an on the spot."},
#  {'SummaryProb': Decimal('0.1009'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('978.23'),
#   'nwords': 30,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.70',
#   'speakerId': 's0001',
#   'startTime': Decimal('969.44'),
#   'trans': "Reporting from the B.B.C. world service, and remember that every weekend, you can hear a review Of the week's main new stories and why they matter that's in the world."},
#  {'SummaryProb': Decimal('0.0432'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('981.46'),
#   'nwords': 14,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.71',
#   'speakerId': 's0001',
#   'startTime': Decimal('978.23'),
#   'trans': 'This week, with Peter hunt in the chair for the latest addition on air.'},
#  {'SummaryProb': Decimal('0.0228'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('984.33'),
#   'nwords': 9,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.72',
#   'speakerId': 's0001',
#   'startTime': Decimal('981.46'),
#   'trans': 'This weekend and available to download from our website.'},
#  {'SummaryProb': Decimal('0.1357'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('998.46'),
#   'nwords': 41,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.73',
#   'speakerId': 's0001',
#   'startTime': Decimal('985.38'),
#   'trans': "It's been a day of protest in South Africa, some of them demanded that President Jacob Zuma step down, I don't think there's anything to be neutral about them is this is guys crazy can be pleased, or just them together."},
#  {'SummaryProb': Decimal('0.0065'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1000.02'),
#   'nwords': 3,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.74',
#   'speakerId': 's0001',
#   'startTime': Decimal('999.25'),
#   'trans': 'Things are happening.'},
#  {'SummaryProb': Decimal('0.0129'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1006.24'),
#   'nwords': 18,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.75',
#   'speakerId': 's0001',
#   'startTime': Decimal('1000.34'),
#   'trans': 'There are actually two scarier how does Zoomer good people who spoke against him for twenty four hours.'},
#  {'SummaryProb': Decimal('0.0349'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1013.21'),
#   'nwords': 21,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.76',
#   'speakerId': 's0001',
#   'startTime': Decimal('1006.71'),
#   'trans': 'How does he get them to change the tune that is scaring you said, do we want Jacob Zuma goodbye, ed.'},
#  {'SummaryProb': Decimal('0.0146'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1015.58'),
#   'nwords': 8,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.77',
#   'speakerId': 's0001',
#   'startTime': Decimal('1013.38'),
#   'trans': 'Always step down, but we need some action.'},
#  {'SummaryProb': Decimal('0.0355'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1025.24'),
#   'nwords': 33,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.78',
#   'speakerId': 's0001',
#   'startTime': Decimal('1015.7'),
#   'trans': "I think he's got away with a lot of these in Heather Becca from my lot off, but I think with the tank at eighteen in especially yesterday's news, with all the bends."},
#  {'SummaryProb': Decimal('0.0126'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1030.07'),
#   'nwords': 11,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.79',
#   'speakerId': 's0001',
#   'startTime': Decimal('1026.11'),
#   'trans': "Today, they'll downgrade it, we definitely head enough as a country."},
#  {'SummaryProb': Decimal('0.0421'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1038.74'),
#   'nwords': 22,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.80',
#   'speakerId': 's0001',
#   'startTime': Decimal('1030.62'),
#   'trans': "Others rallied in Mister Zoomer's support and in Johannesburg police had to keep rival demonstrators apart with tear gas and rubber bullets."},
#  {'SummaryProb': Decimal('0.1505'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1054.94'),
#   'nwords': 48,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.81',
#   'speakerId': 's0001',
#   'startTime': Decimal('1039.17'),
#   'trans': "The protests to own response to my Zoomer's sacking of a respected finance Minister Pravin Gordon, which led to the country's credit rating being cut to junk status, the B.B.C.'s carne sharp is in Durban in KwaZulu nor tunnel so were a big protests all over the country."},
#  {'SummaryProb': Decimal('0.0414'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1060.05'),
#   'nwords': 12,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.82',
#   'speakerId': 's0001',
#   'startTime': Decimal('1055.44'),
#   'trans': 'Absolutely you saw protests in Johannesburg, people turned Out in their thousands.'},
#  {'SummaryProb': Decimal('0.1423'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1089.83'),
#   'nwords': 92,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.83',
#   'speakerId': 's0001',
#   'startTime': Decimal('1060.05'),
#   'trans': "They were a protest in the centre of Johannesburg, and that was largely by the democratic Alliance, you also saw people who were marching us part of save South Africa, two words Pretorius, so it seemed to be one big gang, but it was separate, in the sense that one was not necessarily an allegiance towards the democratic Alliance, but people from all walks of life, and also A.N.C. supporters who were now saying that President Zuma had to go in Capetown there, people turned out in their thousands there, it's interesting."},
#  {'SummaryProb': Decimal('0.0574'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1100.35'),
#   'nwords': 32,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.84',
#   'speakerId': 's0001',
#   'startTime': Decimal('1089.83'),
#   'trans': "You say that there were A.N.C. members who were protesting against Mister Zoomer, because some of the more high profile, members of his party have now given him, they're backing haven't they."},
#  {'SummaryProb': Decimal('0.0626'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1102.67'),
#   'nwords': 5,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.85',
#   'speakerId': 's0001',
#   'startTime': Decimal('1100.51'),
#   'trans': "How security, he's very secure."},
#  {'SummaryProb': Decimal('0.0306'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1106.98'),
#   'nwords': 11,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.86',
#   'speakerId': 's0001',
#   'startTime': Decimal('1102.67'),
#   'trans': "He's surrounded by people he trusts, he is put into position."},
#  {'SummaryProb': Decimal('0.0152'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1112.27'),
#   'nwords': 20,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.87',
#   'speakerId': 's0001',
#   'startTime': Decimal('1106.98'),
#   'trans': "Now people that he's very close to her, we could go during the funeral of the late, I'm at guitar."},
#  {'SummaryProb': Decimal('0.0484'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1124.01'),
#   'nwords': 39,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.88',
#   'speakerId': 's0001',
#   'startTime': Decimal('1112.28'),
#   'trans': "Don't we saw that people were speaking out against President Zuma, they've made a u. turn, just to give us an idea, carne, while the these protest had been going on pro and anti how febrile is the atmosphere."},
#  {'SummaryProb': Decimal('0.0359'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1129.85'),
#   'nwords': 19,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.89',
#   'speakerId': 's0001',
#   'startTime': Decimal('1124.01'),
#   'trans': 'Do you think this is something that could turn ugly, I just witnessed a press conference on the television.'},
#  {'SummaryProb': Decimal('0.0551'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1140.14'),
#   'nwords': 32,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.90',
#   'speakerId': 's0001',
#   'startTime': Decimal('1129.85'),
#   'trans': "Just now, in one of the A.N.C. Minister said that we should be given it, giving President Zuma a chance, but it wasn't nice as an M.P. herself To have integrity questioned."},
#  {'SummaryProb': Decimal('0.0088'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1143.16'),
#   'nwords': 9,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.91',
#   'speakerId': 's0001',
#   'startTime': Decimal('1140.35'),
#   'trans': 'So a lot of people reaching digging very deep.'},
#  {'SummaryProb': Decimal('0.0368'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1151.87'),
#   'nwords': 24,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.92',
#   'speakerId': 's0001',
#   'startTime': Decimal('1143.16'),
#   'trans': "It seems that's what the press conference reflected, and I think there's a general sense, though, that, despite these tensions, despite what happened today."},
#  {'SummaryProb': Decimal('0.2631'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1186.16'),
#   'nwords': 88,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.93',
#   'speakerId': 's0001',
#   'startTime': Decimal('1152.64'),
#   'trans': "The President Zuma will not goal that he's M.P.s will be there in very strongly surrounding him, and this will not change anything, but definitely South Africans who protested today felt that are winds of change had now started within the country carnie shop in KwaZulu lunar time events in Syria have rather overshadowed President trumps talks in Florida, with the Chinese President, she doing paying, they've been meeting for a second day with U.S. Chinese trade and security concerns about North Korea are high on the agenda."},
#  {'SummaryProb': Decimal('0.2874'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1209.11'),
#   'nwords': 57,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.94',
#   'speakerId': 's0001',
#   'startTime': Decimal('1186.62'),
#   'trans': "As a China editor carry Gracie reports, the missile attack on Syria will have upset the Chinese strict sense of Protocol, the Florida summit began with President drums grandchildren singing a Chinese song to Presidents she ain't his wife, but even before the dinner plates were cleared the host had created an awkward challenge for his guest."},
#  {'SummaryProb': Decimal('0.8851'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1270.88'),
#   'nwords': 158,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.95',
#   'speakerId': 's0001',
#   'startTime': Decimal('1209.61'),
#   'trans': "China's position on Syria is much closer to Russia's than to the U.S and the Chinese government will guess that the timing of the American missile strike was a blunt message, but without more robust Chinese help pond dismantling Kim Jong ends nuclear programme the next target for pre empty of American military action might be North Korea in Chinese Protocol sudden moves disrupting set piece occasions are Avoided wherever possible, and in private, NA she is likely to be angry, but in public, he stuck to his script about the virtues of co operation, while his host insisted they'd formed an outstanding relationship and made great progress, as the two Presidents went into their final lunch, there were no specifics, though, and amidst the continuing aftermath of the U.S. missile strike on Syria, all the issues which devil, the U.S., China relationship have been kicked down the road for President trumps visit to China later this year."},
#  {'SummaryProb': Decimal('0.0864'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1282.28'),
#   'nwords': 35,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.96',
#   'speakerId': 's0001',
#   'startTime': Decimal('1271.6'),
#   'trans': "I'll try an editor carry Gracie the b. b. c. has learnt that nearly half of the houses built after the devastating earthquake in the two years ago, are of poor quality and wouldn't survive."},
#  {'SummaryProb': Decimal('0.2067'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1304.54'),
#   'nwords': 58,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.97',
#   'speakerId': 's0001',
#   'startTime': Decimal('1282.28'),
#   'trans': "Another major quake nearly nine thousand people died during the earthquake, and a million homes were damaged, so why a substandard homes still being built Girish Arnie, he's a South Asia, the way the reconstruction skiing works, the government gives money to people to build their own houses, or some charities are getting involved in building the houses."},
#  {'SummaryProb': Decimal('0.046'),
#   'classId': 'transcript',
#   'conv': '20170407230200globalnewspodcast',
#   'endTime': Decimal('1312.77'),
#   'nwords': 27,
#   'sid': '20170407230200globalnewspodcast.s0001.sentence.98',
#   'speakerId': 's0001',
#   'startTime': Decimal('1304.8'),
# ...
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('559.02'),
#   'nwords': 2,
#   'sid': '20170407140000newshour.s0001.sentence.44',
#   'speakerId': 's0001',
#   'startTime': Decimal('558.71'),
#   'trans': "There's debris."},
#  {'SummaryProb': Decimal('0.0135'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('559.64'),
#   'nwords': 2,
#   'sid': '20170407140000newshour.s0001.sentence.45',
#   'speakerId': 's0001',
#   'startTime': Decimal('559.06'),
#   'trans': 'Many thanks.'},
#  {'SummaryProb': Decimal('0.078'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('569.79'),
#   'nwords': 25,
#   'sid': '20170407140000newshour.s0001.sentence.46',
#   'speakerId': 's0001',
#   'startTime': Decimal('559.64'),
#   'trans': 'That was a lucky break freelance so jealous, who works for Syrian state t. v. and international media speaking, there from the Syrian capital, Damascus.'},
#  {'SummaryProb': Decimal('0.087'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('576.75'),
#   'nwords': 22,
#   'sid': '20170407140000newshour.s0001.sentence.47',
#   'speakerId': 's0001',
#   'startTime': Decimal('569.79'),
#   'trans': "There has, though, been backing for the strikes from Syrian rebel groups all those some argued that they didn't go far enough."},
#  {'SummaryProb': Decimal('0.4061'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('607.74'),
#   'nwords': 68,
#   'sid': '20170407140000newshour.s0001.sentence.48',
#   'speakerId': 's0001',
#   'startTime': Decimal('576.76'),
#   'trans': "For, as it happens, the spokeswoman for the Syrian opposition, Hi negotiations Committee, but smart Marnie has been in Washington this week for talks with officials from the trump administration, which she's surprised at the U.S. missile strikes, I think that we were first surprised Donald trump's personal reaction to the attack that moment on, it was obvious, the whole machine, whereas emulsion to prepare for a response."},
#  {'SummaryProb': Decimal('0.1023'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('614.74'),
#   'nwords': 18,
#   'sid': '20170407140000newshour.s0001.sentence.49',
#   'speakerId': 's0001',
#   'startTime': Decimal('608.03'),
#   'trans': 'And I think what we have seen is quite spectacular, because all of the administration and the garden.'},
#  {'SummaryProb': Decimal('0.1271'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('633.23'),
#   'nwords': 48,
#   'sid': '20170407140000newshour.s0001.sentence.50',
#   'speakerId': 's0001',
#   'startTime': Decimal('614.85'),
#   'trans': "In particular, who had Klan speak, they're over at the last six years for options in, yeah, we understood the attack would be limited, that it would be a symbolic strike, but a strong message to a sad, and I think that is what we are looking for."},
#  {'SummaryProb': Decimal('0.6268'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('692.06'),
#   'nwords': 120,
#   'sid': '20170407140000newshour.s0001.sentence.51',
#   'speakerId': 's0001',
#   'startTime': Decimal('633.26'),
#   'trans': "To be honest, I don't think we are looking for the Terry regime change in a violent and for a sad, not that he doesn't deserve her just seal islands because we believed that we need to go for, or a deadly transition you saved the emotional response from President trump to chemical weapons attacks on civilians struck you as being a turning point on what he might do, but up until that point in your talks with administration officials, did you feel that you were still dealing with an administration, though, was very relaxed about President Asad remaining Syria's leader in previous visits, it was obvious that you all could only catch the attention of people in the administration."},
#  {'SummaryProb': Decimal('0.05'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('693.29'),
#   'nwords': 3,
#   'sid': '20170407140000newshour.s0001.sentence.52',
#   'speakerId': 's0001',
#   'startTime': Decimal('692.24'),
#   'trans': 'If you entered.'},
#  {'SummaryProb': Decimal('0.5114'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('741.93'),
#   'nwords': 121,
#   'sid': '20170407140000newshour.s0001.sentence.53',
#   'speakerId': 's0001',
#   'startTime': Decimal('693.29'),
#   'trans': "From the perspective of how your fight Isis, this was the only concern, and they had no space at all in their conversation to discuss a sad, there was nothing else but to the fight against Isis, and it was remarkable, but anything we wanted to say, they had to come through that lens, and suddenly this attack has taken the whole administration off track in a way that put them in a position where they are now desperate to hear about options for what you do with a start, and that is where I think it opens the opportunity for the moderate opposition, he's sent its vision everything it has always advocated as the reasonable options for a transition interior."},
#  {'SummaryProb': Decimal('0.1178'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('757.32'),
#   'nwords': 40,
#   'sid': '20170407140000newshour.s0001.sentence.54',
#   'speakerId': 's0001',
#   'startTime': Decimal('742.15'),
#   'trans': "I think we are finally now going to be heard On what we have to that was her best Muck at Marnie's spokeswoman for the Syrian opposition, Hi negotiations Committee speaking to us from Washington, d. c. n. due care."},
#  {'SummaryProb': Decimal('0.0524'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('770.12'),
#   'nwords': 34,
#   'sid': '20170407140000newshour.s0001.sentence.55',
#   'speakerId': 's0001',
#   'startTime': Decimal('757.33'),
#   'trans': "Now, for all the latest developments on the U.S. missile attacks on the Syrian reaction from around the world on our website at BBC dot com forward slash, news, and you'll see it there."},
#  {'SummaryProb': Decimal('0.1558'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('786.81'),
#   'nwords': 20,
#   'sid': '20170407140000newshour.s0001.sentence.56',
#   'speakerId': 's0001',
#   'startTime': Decimal('770.42'),
#   'trans': 'On the front page coming up what message to these U.S. missile strike send to the rest of the world.'},
#  {'SummaryProb': Decimal('0.0195'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('789.14'),
#   'nwords': 5,
#   'sid': '20170407140000newshour.s0001.sentence.57',
#   'speakerId': 's0001',
#   'startTime': Decimal('786.96'),
#   'trans': 'Perhaps the one clear messages.'},
#  {'SummaryProb': Decimal('0.0304'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('797.36'),
#   'nwords': 22,
#   'sid': '20170407140000newshour.s0001.sentence.58',
#   'speakerId': 's0001',
#   'startTime': Decimal('789.55'),
#   'trans': "We are not in Obama country any more, you can't carry anything, one way or another, but I'm much less risk averse."},
#  {'SummaryProb': Decimal('0.0069'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('800.3'),
#   'nwords': 6,
#   'sid': '20170407140000newshour.s0001.sentence.59',
#   'speakerId': 's0001',
#   'startTime': Decimal('798.45'),
#   'trans': 'And our latest headlines this hour.'},
#  {'SummaryProb': Decimal('0.2065'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('821.25'),
#   'nwords': 61,
#   'sid': '20170407140000newshour.s0001.sentence.60',
#   'speakerId': 's0001',
#   'startTime': Decimal('800.3'),
#   'trans': "Russia's says Syrian air defences will be strengthened in response to a U.S. missile attack on an air base, which has been condemned by the Kremlin NATO has expressed support for the U.S. action blaming the Syrian government for using chemical weapons and some news just end police in the Swedish capital Stockholm have sealed off part of the city centre."},
#  {'SummaryProb': Decimal('0.0698'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('824.21'),
#   'nwords': 7,
#   'sid': '20170407140000newshour.s0001.sentence.61',
#   'speakerId': 's0001',
#   'startTime': Decimal('821.25'),
#   'trans': 'After a truck was driven into pedestrians.'},
#  {'SummaryProb': Decimal('0.0233'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('829.3'),
#   'nwords': 12,
#   'sid': '20170407140000newshour.s0001.sentence.62',
#   'speakerId': 's0001',
#   'startTime': Decimal('824.21'),
#   'trans': "It's not clear, if the action was deliberate and initial reports say."},
#  {'SummaryProb': Decimal('0.0114'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('831.5'),
#   'nwords': 5,
#   'sid': '20170407140000newshour.s0001.sentence.63',
#   'speakerId': 's0001',
#   'startTime': Decimal('829.33'),
#   'trans': 'Several people have been injured.'},
#  {'SummaryProb': Decimal('0.2557'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('862.49'),
#   'nwords': 57,
#   'sid': '20170407140000newshour.s0001.sentence.64',
#   'speakerId': 's0001',
#   'startTime': Decimal('840.44'),
#   'trans': 'This is Julian Marshall with news, a live from the B.B.C. in London reaction from members of the U.S. Congress has re awakened the divisions of twenty thirteen, when President Obama tried to get set their support for strikes against Syria after the deaths of some fifteen hundred Civilians in a chemical weapons, attack the previous year.'},
#  {'SummaryProb': Decimal('0.1008'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('869.43'),
#   'nwords': 19,
#   'sid': '20170407140000newshour.s0001.sentence.65',
#   'speakerId': 's0001',
#   'startTime': Decimal('862.49'),
#   'trans': 'Mister Obama or describe the use of chemical weapons has a red line, which, if crossed would be punished.'},
#  {'SummaryProb': Decimal('0.0617'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('878.33'),
#   'nwords': 20,
#   'sid': '20170407140000newshour.s0001.sentence.66',
#   'speakerId': 's0001',
#   'startTime': Decimal('869.97'),
#   'trans': 'John Allen as a retired U.S. marine Gemmel who previously led the international coalition to counter so called Islamic state.'},
#  {'SummaryProb': Decimal('0.0592'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('885.85'),
#   'nwords': 18,
#   'sid': '20170407140000newshour.s0001.sentence.67',
#   'speakerId': 's0001',
#   'startTime': Decimal('878.33'),
#   'trans': "He's previously advocated such retaliation against President Asad, so I put it to him, he must be pleased."},
#  {'SummaryProb': Decimal('0.0056'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('886.96'),
#   'nwords': 4,
#   'sid': '20170407140000newshour.s0001.sentence.68',
#   'speakerId': 's0001',
#   'startTime': Decimal('886.08'),
#   'trans': "I'm a troll reply."},
#  {'SummaryProb': Decimal('0.0153'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('893.34'),
#   'nwords': 19,
#   'sid': '20170407140000newshour.s0001.sentence.69',
#   'speakerId': 's0001',
#   'startTime': Decimal('886.96'),
#   'trans': 'There were pleased to had what I would say is that this was something that was long in coming.'},
#  {'SummaryProb': Decimal('0.0198'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('911.15'),
#   'nwords': 47,
#   'sid': '20170407140000newshour.s0001.sentence.70',
#   'speakerId': 's0001',
#   'startTime': Decimal('893.49'),
#   'trans': "And it was certainly a necessary step, I think several things and putting side, on notice that, do you mind, it States was simply not going to tolerate this with the Russians on notice that they're advocacy buttery mustard has a limit as far as you can."},
#  {'SummaryProb': Decimal('0.0098'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('926.29'),
#   'nwords': 30,
#   'sid': '20170407140000newshour.s0001.sentence.71',
#   'speakerId': 's0001',
#   'startTime': Decimal('912.39'),
#   'trans': "I also think that we shouldn't the coincidence that we're having a summit with President g. of China, right now, which is another picture of a problem state, North Korea."},
#  {'SummaryProb': Decimal('0.0774'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('953.26'),
#   'nwords': 83,
#   'sid': '20170407140000newshour.s0001.sentence.72',
#   'speakerId': 's0001',
#   'startTime': Decimal('926.35'),
#   'trans': "So I like my guess would be that there are messages moving in all directions to some of our partners looks that we will support you to some of allies have corsets that we're going to take a different approach and a certain other targets that there are limits to American patients, and I think that those are very powerful, very important messages to be conveyed at this particular moment to see these Missal strikes snot oni has punitive, but deterrent as well."},
#  {'SummaryProb': Decimal('0.019'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('970.18'),
#   'nwords': 37,
#   'sid': '20170407140000newshour.s0001.sentence.73',
#   'speakerId': 's0001',
#   'startTime': Decimal('953.83'),
#   'trans': 'Certainly, Of course, that conversation will involve here, I think over the next several days will be whether the streets, intends to pursue, as a matter of policy, military punitive military action with respect to humanitarian issues.'},
#  {'SummaryProb': Decimal('0.0062'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('972.12'),
#   'nwords': 5,
#   'sid': '20170407140000newshour.s0001.sentence.74',
#   'speakerId': 's0001',
#   'startTime': Decimal('971.03'),
#   'trans': 'We have done this before.'},
#  {'SummaryProb': Decimal('0.0115'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('979.92'),
#   'nwords': 25,
#   'sid': '20170407140000newshour.s0001.sentence.75',
#   'speakerId': 's0001',
#   'startTime': Decimal('972.2'),
#   'trans': "It's not something that's unknown to us, but to make a key to enunciate earlier miss administration, appears to be a direction for a policy."},
#  {'SummaryProb': Decimal('0.0112'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('986.12'),
#   'nwords': 14,
#   'sid': '20170407140000newshour.s0001.sentence.76',
#   'speakerId': 's0001',
#   'startTime': Decimal('980.76'),
#   'trans': "Well, I'm sure invoke Madame insignificant amount of discussion over here on this issue."},
#  {'SummaryProb': Decimal('0.0614'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('1006.13'),
#   'nwords': 49,
#   'sid': '20170407140000newshour.s0001.sentence.77',
#   'speakerId': 's0001',
#   'startTime': Decimal('986.3'),
#   'trans': "I mean, you were among those who criticise President Obama for failing to enforce his own red line against President Assad's government for using poison gas in Damascus in twenty thirteen, why do you feel the President trump has been able to do what President Obama failed to do."},
#  {'SummaryProb': Decimal('0.0314'),
#   'classId': 'transcript',
#   'conv': '20170407140000newshour',
#   'endTime': Decimal('1031.47'),
#   'nwords': 68,
#   'sid': '20170407140000newshour.s0001.sentence.78',
#   'speakerId': 's0001',
#   'startTime': Decimal('1006.92'),
#   'trans': "That's a question, best left to the two of them to express her own views on the issue, but I think at this particular moment, President trouble was who was clear in many ways that his view of the use of force was different than the view of his predecessor was dramatically differ, and if you're going to make comments like that, and you're confronted with the reality."},
#  ...]

# %%
cols = list(speakerInfo[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
#df1 is the dataFrame of June 23rd
df1 = pd.DataFrame(rows, index = indices, columns = cols)
df1 = df1.convert_objects(convert_numeric=True)
# Out:
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if sys.path[0] == '':

# %%
#clean df1
del df1['classId']
del df1['conv']
del df1['sid']
del df1['SummaryProb']
del df1['trans']
df1
# Out:
#      speakerId  nwords  startTime  endTime
# 0        s0001      83       6.77    37.62
# 1        s0001       5      37.87    39.21
# 2        s0001       2      39.30    39.69
# 3        s0001       4      41.00    42.19
# 4        s0001      37      42.36    54.49
# 5        s0001      55      57.70    76.54
# 6        s0001      31      76.54    85.82
# 7        s0001      18      86.20    91.46
# 8        s0001     100      96.73   135.11
# 9        s0001       3     135.25   135.85
# 10       s0001       4     137.20   138.39
# 11       s0001       8     138.56   140.81
# 12       s0001       5     141.54   143.21
# 13       s0001      20     143.25   150.43
# 14       s0001      36     150.43   159.46
# 15       s0001       5     159.46   161.12
# 16       s0001     122     161.12   204.40
# 17       s0001      43     204.63   219.85
# 18       s0001      17     220.01   228.08
# 19       s0001       7     228.60   231.53
# 20       s0001      98     231.53   265.63
# 21       s0001      15     265.94   270.02
# 22       s0001       7     270.02   272.02
# 23       s0001      36     272.24   282.01
# 24       s0001      18     282.01   289.27
# 25       s0001       7     289.45   290.85
# 26       s0001       9     291.66   294.12
# 27       s0001      78     294.26   319.32
# 28       s0001      11     319.82   322.35
# 29       s0001      19     322.38   328.46
# ...        ...     ...        ...      ...
# 9713     s0001      13    1149.66  1152.54
# 9714     s0001      25    1152.63  1160.10
# 9715     s0001      20    1160.47  1165.69
# 9716     s0001      20    1165.69  1172.56
# 9717     s0001      33    1172.56  1182.87
# 9718     s0001       3    1183.38  1183.98
# 9719     s0001      77    1183.98  1209.81
# 9720     s0001       8    1210.05  1213.42
# 9721     s0001      10    1213.45  1215.97
# 9722     s0001      15    1216.60  1220.63
# 9723     s0001      56    1220.63  1238.02
# 9724     s0001      63    1238.25  1260.70
# 9725     s0001      37    1260.99  1271.71
# 9726     s0001      21    1271.71  1278.59
# 9727     s0001       6    1278.62  1281.33
# 9728     s0001      26    1281.56  1289.80
# 9729     s0001      18    1289.80  1296.59
# 9730     s0001      30    1297.03  1306.98
# 9731     s0001      24    1306.98  1314.50
# 9732     s0001      15    1314.50  1320.94
# 9733     s0001      83    1321.65  1347.00
# 9734     s0001      20    1347.00  1354.80
# 9735     s0001      23    1354.90  1362.26
# 9736     s0001      11    1362.52  1367.19
# 9737     s0001       8    1367.19  1369.53
# 9738     s0001      70    1370.14  1393.93
# 9739     s0001      12    1394.38  1398.23
# 9740     s0001      30    1398.26  1406.07
# 9741     s0001       7    1406.29  1408.05
# 9742     s0001      18    1408.08  1412.25
#
# [9743 rows x 4 columns]

# %%
#calculate in sentence level the average time for different speakers speak out a word
df1['time']=df1['endTime']-df1['startTime']
df1['average_time']=df1['time']/df1['nwords']
df1
# Out:
#      speakerId  nwords  startTime  endTime   time  average_time
# 0        s0001      83       6.77    37.62  30.85      0.371687
# 1        s0001       5      37.87    39.21   1.34      0.268000
# 2        s0001       2      39.30    39.69   0.39      0.195000
# 3        s0001       4      41.00    42.19   1.19      0.297500
# 4        s0001      37      42.36    54.49  12.13      0.327838
# 5        s0001      55      57.70    76.54  18.84      0.342545
# 6        s0001      31      76.54    85.82   9.28      0.299355
# 7        s0001      18      86.20    91.46   5.26      0.292222
# 8        s0001     100      96.73   135.11  38.38      0.383800
# 9        s0001       3     135.25   135.85   0.60      0.200000
# 10       s0001       4     137.20   138.39   1.19      0.297500
# 11       s0001       8     138.56   140.81   2.25      0.281250
# 12       s0001       5     141.54   143.21   1.67      0.334000
# 13       s0001      20     143.25   150.43   7.18      0.359000
# 14       s0001      36     150.43   159.46   9.03      0.250833
# 15       s0001       5     159.46   161.12   1.66      0.332000
# 16       s0001     122     161.12   204.40  43.28      0.354754
# 17       s0001      43     204.63   219.85  15.22      0.353953
# 18       s0001      17     220.01   228.08   8.07      0.474706
# 19       s0001       7     228.60   231.53   2.93      0.418571
# 20       s0001      98     231.53   265.63  34.10      0.347959
# 21       s0001      15     265.94   270.02   4.08      0.272000
# 22       s0001       7     270.02   272.02   2.00      0.285714
# 23       s0001      36     272.24   282.01   9.77      0.271389
# 24       s0001      18     282.01   289.27   7.26      0.403333
# 25       s0001       7     289.45   290.85   1.40      0.200000
# 26       s0001       9     291.66   294.12   2.46      0.273333
# 27       s0001      78     294.26   319.32  25.06      0.321282
# 28       s0001      11     319.82   322.35   2.53      0.230000
# 29       s0001      19     322.38   328.46   6.08      0.320000
# ...        ...     ...        ...      ...    ...           ...
# 9713     s0001      13    1149.66  1152.54   2.88      0.221538
# 9714     s0001      25    1152.63  1160.10   7.47      0.298800
# 9715     s0001      20    1160.47  1165.69   5.22      0.261000
# 9716     s0001      20    1165.69  1172.56   6.87      0.343500
# 9717     s0001      33    1172.56  1182.87  10.31      0.312424
# 9718     s0001       3    1183.38  1183.98   0.60      0.200000
# 9719     s0001      77    1183.98  1209.81  25.83      0.335455
# 9720     s0001       8    1210.05  1213.42   3.37      0.421250
# 9721     s0001      10    1213.45  1215.97   2.52      0.252000
# 9722     s0001      15    1216.60  1220.63   4.03      0.268667
# 9723     s0001      56    1220.63  1238.02  17.39      0.310536
# 9724     s0001      63    1238.25  1260.70  22.45      0.356349
# 9725     s0001      37    1260.99  1271.71  10.72      0.289730
# 9726     s0001      21    1271.71  1278.59   6.88      0.327619
# 9727     s0001       6    1278.62  1281.33   2.71      0.451667
# 9728     s0001      26    1281.56  1289.80   8.24      0.316923
# 9729     s0001      18    1289.80  1296.59   6.79      0.377222
# 9730     s0001      30    1297.03  1306.98   9.95      0.331667
# 9731     s0001      24    1306.98  1314.50   7.52      0.313333
# 9732     s0001      15    1314.50  1320.94   6.44      0.429333
# 9733     s0001      83    1321.65  1347.00  25.35      0.305422
# 9734     s0001      20    1347.00  1354.80   7.80      0.390000
# 9735     s0001      23    1354.90  1362.26   7.36      0.320000
# 9736     s0001      11    1362.52  1367.19   4.67      0.424545
# 9737     s0001       8    1367.19  1369.53   2.34      0.292500
# 9738     s0001      70    1370.14  1393.93  23.79      0.339857
# 9739     s0001      12    1394.38  1398.23   3.85      0.320833
# 9740     s0001      30    1398.26  1406.07   7.81      0.260333
# 9741     s0001       7    1406.29  1408.05   1.76      0.251429
# 9742     s0001      18    1408.08  1412.25   4.17      0.231667
#
# [9743 rows x 6 columns]

# %%
#find out how many different speakers 
df1['speakerId'].value_counts()
# Out:
# s0001    9743
# Name: speakerId, dtype: int64

# %% [markdown]
# Find all JSON files on June 22nd which is the day before "Vote Leave" and all files on June 24th which is the day after "Vote Leave" and  print their indexs.

# %%
#Indexs for April 2nd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170414230100globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170408023000theworldthisweek.extsumm.asrsent.json") + 1,"]")
#Indexs for April 3rd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170421230500globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170415043000theworldthisweek.extsumm.asrsent.json") + 1,"]")

#Indexs for April 4rd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170430222100globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170422033000theworldthisweek.extsumm.asrsent.json") + 1,"]")
# Out:
# [ 734 : 810 ]
# [ 669 : 734 ]
# [ 588 : 669 ]

# %%
########input these indexs and merge these files into one dataFrame####
#for April 2nd week
speakerInfo0 = []
for item in urls[734:810]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo0.append(segments[num])
        
#for April 3rd week
speakerInfo2 = []
for item in urls[669:734]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo2.append(segments[num])    
#for April 4th week
speakerInfo3 = []
for item in urls[588:669]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo3.append(segments[num])    
speakerInfo3
# Out:
# [{'SummaryProb': Decimal('0.2059'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('28.8'),
#   'nwords': 56,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.1',
#   'speakerId': 's0001',
#   'startTime': Decimal('7.59'),
#   'trans': "This is the B.B.C. for details of a complete range of programmes go to B.B.C. world service dot com forward slash, Welcome to the latest global news compiled in the early hours of Monday, the first of, may I'm Jackie learned up with a selection of highlights from across B.B.C. world service news today coming up."},
#  {'SummaryProb': Decimal('0.0589'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('35.48'),
#   'nwords': 18,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.2',
#   'speakerId': 's0001',
#   'startTime': Decimal('28.83'),
#   'trans': 'President trump describes Kim Jong un as a smart cookie, but adds a warning on Pyongyang nuclear programme.'},
#  {'SummaryProb': Decimal('0.0571'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('45.24'),
#   'nwords': 33,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.3',
#   'speakerId': 's0001',
#   'startTime': Decimal('35.69'),
#   'trans': "If he doesn't know clear test, I will not be happy, and I can tell you, also, I don't believe that the President, China will be happy either not happy any military action."},
#  {'SummaryProb': Decimal('0.3021'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('74.98'),
#   'nwords': 88,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.4',
#   'speakerId': 's0001',
#   'startTime': Decimal('45.27'),
#   'trans': "I don't know. mean, also in the podcast, a leading figure in world sport is resigning all his football rolls after being linked to a corruption scandal, a Swiss national has been arrested in Germany, for allegedly spying on a major operation into tax fraud and later, if I was arrested oxygen for me, there's no while you on that, it's not how I wanna climb, we look back at the achievements of leash deck, one of the world's best known mountaineers who's been killed on Mount Everest."},
#  {'SummaryProb': Decimal('0.0493'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('83.01'),
#   'nwords': 21,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.5',
#   'speakerId': 's0001',
#   'startTime': Decimal('75.68'),
#   'trans': "But first President trump says he's not ruling out military action against North Korea, if the country pursues its nuclear programme."},
#  {'SummaryProb': Decimal('0.4057'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('118.34'),
#   'nwords': 100,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.6',
#   'speakerId': 's0001',
#   'startTime': Decimal('83.39'),
#   'trans': "In an interview on the C.B.S. network Mister trump also warned that a conflict involving Pyongyang could kill millions of people, he called attempts To rein in North Korea, a chess game, and said he hoped China, its main ally would persuade Pyongyang to abandon its nuclear ambitions and speaking on meet the press my trump described to the North Korean leader Kim Jong urn like this, with obviously very tough people, and particularly the generals and others, and a very young age, she was able to assume power, a lot of people, I'm sure, tried to take power away."},
#  {'SummaryProb': Decimal('0.0086'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('120.66'),
#   'nwords': 8,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.7',
#   'speakerId': 's0001',
#   'startTime': Decimal('118.34'),
#   'trans': 'Whether it was his uncle or anybody else.'},
#  {'SummaryProb': Decimal('0.0097'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('123.43'),
#   'nwords': 7,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.8',
#   'speakerId': 's0001',
#   'startTime': Decimal('121.3'),
#   'trans': 'And he was able to do it.'},
#  {'SummaryProb': Decimal('0.1668'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('147.17'),
#   'nwords': 71,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.9',
#   'speakerId': 's0001',
#   'startTime': Decimal('123.43'),
#   'trans': "So, obviously, he's a pretty smart cookie Mister trump did not rule out military action against North Korea, if further nuclear weapons tests were carried out, I would not be happy if he doesn't know clear test, I will not be happy, and I can tell you, also, I don't believe that the President of China, who is a very respected man will be happy either not having any military action."},
#  {'SummaryProb': Decimal('0.1124'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('165.98'),
#   'nwords': 52,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.10',
#   'speakerId': 's0001',
#   'startTime': Decimal('147.2'),
#   'trans': "I don't know our correspondent in Washington is never Taufiq and she began with my trance positive comments towards China and Presidents see President trump has outlined all options are still on the table, but the administration says they definitely prefer diplomatic resolution and China as North Korea's main ally is key."},
#  {'SummaryProb': Decimal('0.0516'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('173.8'),
#   'nwords': 27,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.11',
#   'speakerId': 's0001',
#   'startTime': Decimal('165.98'),
#   'trans': "Do that, and we've seen really the to readers in constant contact, since they met in the last three weeks, and Mara lager and present in Tramp."},
#  {'SummaryProb': Decimal('0.0448'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('180.54'),
#   'nwords': 25,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.12',
#   'speakerId': 's0001',
#   'startTime': Decimal('173.8'),
#   'trans': "In this interview, said that he now respects, NA She's got to know him, and that they have a very good and very special relationship."},
#  {'SummaryProb': Decimal('0.0897'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('190.63'),
#   'nwords': 36,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.13',
#   'speakerId': 's0001',
#   'startTime': Decimal('180.54'),
#   'trans': "So, it's a dramatic shift from what we've seen during the campaign, labelling China as a, currency manipulator, and he did say that he thinks the present, she is helping to increase pressure with North Korea."},
#  {'SummaryProb': Decimal('0.0281'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('197.26'),
#   'nwords': 28,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.14',
#   'speakerId': 's0001',
#   'startTime': Decimal('190.63'),
#   'trans': 'So they clearly see them as a partner, and I think it was a really interesting Jackie was his comment that he sees co operation and North Korea.'},
#  {'SummaryProb': Decimal('0.0269'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('202.63'),
#   'nwords': 18,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.15',
#   'speakerId': 's0001',
#   'startTime': Decimal('197.26'),
#   'trans': 'More important than treat, because he says, millions of lives are at risk for a potential nuclear conflict.'},
#  {'SummaryProb': Decimal('0.2189'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('220.89'),
#   'nwords': 66,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.16',
#   'speakerId': 's0001',
#   'startTime': Decimal('202.63'),
#   'trans': "So he's clearly willing to be softer on China on claims of currency manipulation in order to resolve this issue, and he called him a, smart, cookie, what do you make of the comments about Kim Jong un he has, I think it was really interesting to hear him say that he had earlier in the week, said, you know, people have questioned whether he's insane."},
#  {'SummaryProb': Decimal('0.1479'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('236.4'),
#   'nwords': 61,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.17',
#   'speakerId': 's0001',
#   'startTime': Decimal('220.89'),
#   'trans': "And NA he thinks that he can really comment on that he might not be insane, but this time he went further and actually complimented him, saying he was thrown into power, at a very young age, that he's dealing with tough general's tough people on the regime that he was a smart cookie for being able to stay in power."},
#  {'SummaryProb': Decimal('0.0232'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('239.04'),
#   'nwords': 11,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.18',
#   'speakerId': 's0001',
#   'startTime': Decimal('236.58'),
#   'trans': 'You know, I think it reflects some of the others sentiment.'},
#  {'SummaryProb': Decimal('0.8965'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('298.86'),
#   'nwords': 182,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.19',
#   'speakerId': 's0001',
#   'startTime': Decimal('239.07'),
#   'trans': "We've heard me off step, the Secretary of state Rex teller Sen has said He doesn't think North Korean leader may be as crazy as what he said, as his reputation suggests, and I think all of this is kind of an effort of the administration to also reason with the North Korean reader to trader, you know, show him that there is a path that could be in his self interest to go away from your colourisation never Taufiq in Washington are, you may have noticed that Donald trump marked one hundred days, as President of the U.S on Saturday that milestone is traditionally a time to reflect on achievement setbacks and appointments and some of my trumps appointments are seen as somewhat on Orthodox among the most remarked upon a his daughter Ivanka and her husband, Jared Kushner my Commissioner has no prior government experience, but he's now in charge of a number of high profile portfolios in President trumps administration aged thirty six his career has been in property, but now her senior advisor to the Commander in Chief."},
#  {'SummaryProb': Decimal('0.1049'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('309.56'),
#   'nwords': 27,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.20',
#   'speakerId': 's0001',
#   'startTime': 299,
#   'trans': "He's responsible for getting rid of bureaucracy in the white House resolving the Israeli, Palestinian conflict and his lead adviser on relations with China, Mexico and Canada."},
#  {'SummaryProb': Decimal('0.0331'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('316.58'),
#   'nwords': 21,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.21',
#   'speakerId': 's0001',
#   'startTime': Decimal('310.06'),
#   'trans': "So who exactly is Jared Krishna the b. b. c. former North America's editor mark mardell is taken a closer look."},
#  {'SummaryProb': Decimal('0.0801'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('342.01'),
#   'nwords': 51,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.22',
#   'speakerId': 's0001',
#   'startTime': Decimal('323.58'),
#   'trans': "This curiously maudlin ditty is a banker trump and Gerard cushion as wedding song, a ceremony which cemented two dynasties, perhaps the couple weren't the only ones waiting on their own team, the marriage Presented double trump with her son in law, who's now his go to guy get up here."},
#  {'SummaryProb': Decimal('0.0409'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('346.38'),
#   'nwords': 12,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.23',
#   'speakerId': 's0001',
#   'startTime': Decimal('342.4'),
#   'trans': "Now, some of trump's original almost enthusiastic supporters on the hard, right."},
#  {'SummaryProb': Decimal('0.0903'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('354.3'),
#   'nwords': 21,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.24',
#   'speakerId': 's0001',
#   'startTime': Decimal('346.41'),
#   'trans': 'Are suspicious of what Gerrit does and why he does it, the provocative conservative commentator and early trump supporter Ann Coulter.'},
#  {'SummaryProb': Decimal('0.2761'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('369.86'),
#   'nwords': 47,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.25',
#   'speakerId': 's0001',
#   'startTime': Decimal('354.64'),
#   'trans': "Author of the left's plan to turn America into a third world hellhole says, it's not personal, very nice lovely, very impressed he could be the best person for the job, but you can't hire you kids, because they can't be fired more than first among equals."},
#  {'SummaryProb': Decimal('0.0382'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('374.87'),
#   'nwords': 13,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.26',
#   'speakerId': 's0001',
#   'startTime': Decimal('370.2'),
#   'trans': "It's like a banana Republic bringing your kid and family will find out."},
#  {'SummaryProb': Decimal('0.1594'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('387.31'),
#   'nwords': 31,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.27',
#   'speakerId': 's0001',
#   'startTime': Decimal('374.87'),
#   'trans': "He's at the heart of this story, Jay rancour, that's their couple name, provide a soupcon of sophistication smoothly groomed beautiful use in a Court, that's more King Midas than Camelot."},
#  {'SummaryProb': Decimal('0.0407'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('389.96'),
#   'nwords': 8,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.28',
#   'speakerId': 's0001',
#   'startTime': Decimal('387.77'),
#   'trans': "They've been a fixture of the glossy magazines."},
#  {'SummaryProb': Decimal('0.0847'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('404.66'),
#   'nwords': 38,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.29',
#   'speakerId': 's0001',
#   'startTime': Decimal('390.2'),
#   'trans': "Last year, elle decor gushed about the couple's upper Eastside apartment, and it's Lindsay Alderman light fixtures and candlesticks by Geoff Zimmerman in the white House amid the balding billionaires and a leader who made vulgarity of virtue."},
#  {'SummaryProb': Decimal('0.242'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('432.47'),
#   'nwords': 63,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.30',
#   'speakerId': 's0001',
#   'startTime': Decimal('404.95'),
#   'trans': "Their sleekness stands out Lizzie widdicombe is editor of the new Yorker magazines talk of the town and watches them closely, they both have a noticeable level of Polish physically on us, and in both their cases reason tation seems to be a very conscious, it's often said that Iran softens the bread aggressive loud image of her father and makes it palatable."},
#  {'SummaryProb': Decimal('0.0309'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('436.59'),
#   'nwords': 11,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.31',
#   'speakerId': 's0001',
#   'startTime': Decimal('432.79'),
#   'trans': 'And do you think Gerhard Kushner does that politically for trump.'},
#  {'SummaryProb': Decimal('0.1223'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('452.98'),
#   'nwords': 47,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.32',
#   'speakerId': 's0001',
#   'startTime': Decimal('436.65'),
#   'trans': "That's a great way of putting it, he has beer in the link from the trunk campaign to while street and emerged as a power broker trump and Kushner are both bridge and tunnel guys trump from the outer borough of Queens cushion from out of state."},
#  {'SummaryProb': Decimal('0.2191'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('463.71'),
#   'nwords': 33,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.33',
#   'speakerId': 's0001',
#   'startTime': Decimal('453.01'),
#   'trans': "New Jersey, but what's the golden boy, the Crown Prince actually like Ken curse and editor of the new York observer, which Kushner owned, until recently, has been close to him for years."},
#  {'SummaryProb': Decimal('0.1772'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('473.4'),
#   'nwords': 37,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.34',
#   'speakerId': 's0001',
#   'startTime': Decimal('463.75'),
#   'trans': "Well, as young man, Gerhard wasn't too different from, how are s today, he was a serious guy, even when he was in College, he was attempting business deals and pulling them off, but he's also Fund."},
#  {'SummaryProb': Decimal('0.1149'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('487.24'),
#   'nwords': 45,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.35',
#   'speakerId': 's0001',
#   'startTime': Decimal('473.47'),
#   'trans': 'I mean, we do normal friends stuff to replace boraton hangout author Gabriel Sherman wrote an early profile for new York magazine when Gerald was just twenty eight, he is, in many ways, the exact opposite of Donald trump when you spend time with him.'},
#  {'SummaryProb': Decimal('0.0393'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('495.48'),
#   'nwords': 19,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.36',
#   'speakerId': 's0001',
#   'startTime': Decimal('487.24'),
#   'trans': "He's incredibly controlled, he says, almost as little as possible, tries to be polite and as controversial as possible."},
#  {'SummaryProb': Decimal('0.2468'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('514.05'),
#   'nwords': 53,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.37',
#   'speakerId': 's0001',
#   'startTime': Decimal('495.48'),
#   'trans': "And it's striking that someone with this much drive in power, and someone who's capable of being, let's be Frank ruthless in terms of getting what he wants, he presents a very friendly and mild mannered face Gerhard Kushner a property billionaire is not just the son in law of a property billionaire."},
#  {'SummaryProb': Decimal('0.1014'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('521.04'),
#   'nwords': 17,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.38',
#   'speakerId': 's0001',
#   'startTime': Decimal('514.2'),
#   'trans': "He's also the son of A property billionaire Charlie Kushner a property millionaire, who went to jail."},
#  {'SummaryProb': Decimal('0.2058'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('534.17'),
#   'nwords': 35,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.39',
#   'speakerId': 's0001',
#   'startTime': Decimal('521.36'),
#   'trans': "It was ugly, I family feud, which went thermo nuclear as the row spiralled Charlie was jailed for tax evasion and deception, Gerhard's close friend Ken Curzon suggests the trauma, was the making of him."},
#  {'SummaryProb': Decimal('0.117'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': 551,
#   'nwords': 51,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.40',
#   'speakerId': 's0001',
#   'startTime': Decimal('534.37'),
#   'trans': 'This is a guy, when he was twenty four or twenty five through circumstance us was made, the sea, a giant sprawling complex company Nadal, if handled that in emergency basis are beautifully, but grew the company moved her to new York was very far sighted and original in his thinking.'},
#  {'SummaryProb': Decimal('0.0538'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('557.79'),
#   'nwords': 21,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.41',
#   'speakerId': 's0001',
#   'startTime': Decimal('551.24'),
#   'trans': "Here's Gabriel Sherman again without question, I think it is still, in many ways, the defining event of Jerry Krishna's life."},
#  {'SummaryProb': Decimal('0.0353'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('565.97'),
#   'nwords': 25,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.42',
#   'speakerId': 's0001',
#   'startTime': Decimal('557.82'),
#   'trans': 'Growing up, the family always Thatcher Kushner would run for political Office and become a major figure in America, but much further down the road.'},
#  {'SummaryProb': Decimal('0.0479'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('574.63'),
#   'nwords': 26,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.43',
#   'speakerId': 's0001',
#   'startTime': Decimal('566.23'),
#   'trans': 'And when Charlie cushion went to prison Jerry Krishna was required in his early twenties to start that climb to power from a much early age.'},
#  {'SummaryProb': Decimal('0.0972'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('581.48'),
#   'nwords': 19,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.44',
#   'speakerId': 's0001',
#   'startTime': Decimal('575.12'),
#   'trans': "He's in charge of job creation, information technology, getting rid of bureaucracy, dealing with war Veterans an opiate addiction."},
#  {'SummaryProb': Decimal('0.0389'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('583.42'),
#   'nwords': 7,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.45',
#   'speakerId': 's0001',
#   'startTime': Decimal('581.74'),
#   'trans': 'Oh, and peace in the Middle East.'},
#  {'SummaryProb': Decimal('0.0188'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('586.68'),
#   'nwords': 9,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.46',
#   'speakerId': 's0001',
#   'startTime': Decimal('583.57'),
#   'trans': 'If you cared brittas peace in the Middle East.'},
#  {'SummaryProb': Decimal('0.3531'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('608.38'),
#   'nwords': 65,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.47',
#   'speakerId': 's0001',
#   'startTime': Decimal('586.75'),
#   'trans': "Nobody can the U.S. papers have been full of stories of white House feuding between the ex bribe art editor hard right nationalist ideologue Steve Benham and Kushner a picture of the meeting to discuss the strike on Syria, says it all Kushner sits in The very centre of the table, topped by trump Bannon's crammed somewhere in a seat behind the action Gabriel Sherman."},
#  {'SummaryProb': Decimal('0.0722'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('619.21'),
#   'nwords': 36,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.48',
#   'speakerId': 's0001',
#   'startTime': Decimal('608.65'),
#   'trans': "What's clear is that durer Kushner is flexing their power and influence that comes from being a Member of the trump family and durer Kushner knows that it's very unlikely that Donald trump what fire him."},
#  {'SummaryProb': Decimal('0.0368'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('625.61'),
#   'nwords': 16,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.49',
#   'speakerId': 's0001',
#   'startTime': Decimal('619.51'),
#   'trans': 'And so he is using that loveridge to wedge and drive, Steve, then into the sidelines.'},
#  {'SummaryProb': Decimal('0.0126'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('626.63'),
#   'nwords': 5,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.50',
#   'speakerId': 's0001',
#   'startTime': Decimal('625.79'),
#   'trans': 'What about his own future.'},
#  {'SummaryProb': Decimal('0.0851'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('632.92'),
#   'nwords': 20,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.51',
#   'speakerId': 's0001',
#   'startTime': Decimal('626.63'),
#   'trans': 'Does he want to move one day into the next door Office Gerard Kushner J.K., President of the United States.'},
#  {'SummaryProb': Decimal('0.0415'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('634.14'),
#   'nwords': 3,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.52',
#   'speakerId': 's0001',
#   'startTime': Decimal('633.07'),
#   'trans': "Here's Gabriel Sherman."},
#  {'SummaryProb': Decimal('0.0415'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('640.5'),
#   'nwords': 17,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.53',
#   'speakerId': 's0001',
#   'startTime': Decimal('634.14'),
#   'trans': 'Again, I think that wants to be, NA in terms of having that influence over world Affairs.'},
#  {'SummaryProb': Decimal('0.1168'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('657.69'),
#   'nwords': 50,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.54',
#   'speakerId': 's0001',
#   'startTime': Decimal('640.5'),
#   'trans': "Now, I don't think you're a Christian or necessarily want to subject himself to the scrutiny in the accountability and all the indignities that Comp with running for President in the trump Presidency began with high expectations of the extraordinary if it is settling down into a more conventional groove."},
#  {'SummaryProb': Decimal('0.0082'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('661.08'),
#   'nwords': 12,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.55',
#   'speakerId': 's0001',
#   'startTime': Decimal('658.04'),
#   'trans': "You may have the President's super smooth son in law to blame."},
#  {'SummaryProb': Decimal('0.0523'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('678.4'),
#   'nwords': 24,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.56',
#   'speakerId': 's0001',
#   'startTime': Decimal('668.17'),
#   'trans': "That report by mark mardell after years of financial and political scandals football's world governing body has been trying to reassert its moral authority."},
#  {'SummaryProb': Decimal('0.2929'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('703.96'),
#   'nwords': 74,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.57',
#   'speakerId': 's0001',
#   'startTime': Decimal('678.58'),
#   'trans': 'Indeed Reefers, President, recently declared that the crisis was over, but the spotlight has fallen on the organisation again with the resignation of one of its senior officials, a day after he denied claims linking him to a fraud case Richard Conway is a sports news correspondent, And he told us more about shaker murdo far had also, he is the most powerful, one of the most powerful sports officials around at the moment.'},
#  {'SummaryProb': Decimal('0.0042'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('705.4'),
#   'nwords': 6,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.58',
#   'speakerId': 's0001',
#   'startTime': Decimal('703.96'),
#   'trans': "He's a leading figure within fee."},
#  {'SummaryProb': Decimal('0.053'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('730.09'),
#   'nwords': 68,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.59',
#   'speakerId': 's0001',
#   'startTime': Decimal('705.56'),
#   'trans': "He's a big person within the international Olympic movement, but he is now had to resign all his positions within football, because of this link, which he vigorously denies to a bribery case that came before a U.S. Court last week, so the chances are most fans will have not have herds will not have heard of shake a He is a man who lives in the shadows."},
#  {'SummaryProb': Decimal('0.0077'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('732.33'),
#   'nwords': 5,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.60',
#   'speakerId': 's0001',
#   'startTime': Decimal('730.2'),
#   'trans': "He doesn't want the limelight."},
#  {'SummaryProb': Decimal('0.1084'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('744.82'),
#   'nwords': 47,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.61',
#   'speakerId': 's0001',
#   'startTime': Decimal('732.38'),
#   'trans': 'He is pulling the strings behind the scenes, but those days have now gone within football is clinging on to his role within the Olympic movement, for now, but it stays within footballer over now, you mentioned this U.S. Court case tell us more about the scandal.'},
#  {'SummaryProb': Decimal('0.0329'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('757.5'),
#   'nwords': 26,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.62',
#   'speakerId': 's0001',
#   'startTime': Decimal('745.39'),
#   'trans': 'Yes, at this involved Richard lie, who is qualm football official, he admitted in U.S. courts last week that he took nine hundred fifty thousand dollars.'},
#  {'SummaryProb': Decimal('0.0091'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('759.58'),
#   'nwords': 4,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.63',
#   'speakerId': 's0001',
#   'startTime': Decimal('757.64'),
#   'trans': 'Now in his testimony.'},
#  {'SummaryProb': Decimal('0.0141'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('762.62'),
#   'nwords': 9,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.64',
#   'speakerId': 's0001',
#   'startTime': Decimal('759.58'),
#   'trans': "He identified, but did not name shake, I'll quit."},
#  {'SummaryProb': Decimal('0.0541'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('781.67'),
#   'nwords': 58,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.65',
#   'speakerId': 's0001',
#   'startTime': Decimal('762.97'),
#   'trans': 'He talked about some of the money had come from a high ranking official a thief, a man who was a Member of the Kuwait football Association and the Olympic Council of Asian that jigsaw identifies shake our commodes, he released a statement shortly after, saying he was aware of the speculation that he vigorously denied any wrongdoing.'},
#  {'SummaryProb': Decimal('0.0077'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('783.31'),
#   'nwords': 4,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.66',
#   'speakerId': 's0001',
#   'startTime': Decimal('781.87'),
#   'trans': 'That has now changed.'},
#  {'SummaryProb': Decimal('0.0165'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('787.46'),
#   'nwords': 10,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.67',
#   'speakerId': 's0001',
#   'startTime': Decimal('783.31'),
#   'trans': "He's notified and the I.O.C. give his intentions to resign."},
#  {'SummaryProb': Decimal('0.1433'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('824.11'),
#   'nwords': 101,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.68',
#   'speakerId': 's0001',
#   'startTime': Decimal('787.69'),
#   'trans': "All his football positions, he says that it's in the best interests of the game that he does that fee for President shanny infant has given his reaction, and he says that he's taken note of the situation and says that he thanks for notifying them and says it is perhaps in the best interests for Sheikh awkward to stand aside, that's a sign, perhaps, of the relief from some within feet of the trick I could've walked away relatively quietly any damage from this from this resignation can be contained, as you say, he is denying any wrongdoing at all."},
#  {'SummaryProb': Decimal('0.0195'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('827.04'),
#   'nwords': 11,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.69',
#   'speakerId': 's0001',
#   'startTime': Decimal('824.39'),
#   'trans': 'How does he do you think come under pressure to resign.'},
#  {'SummaryProb': Decimal('0.0022'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('829.09'),
#   'nwords': 10,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.70',
#   'speakerId': 's0001',
#   'startTime': Decimal('827.04'),
#   'trans': "Now, why, why do you think he's made the decision."},
#  {'SummaryProb': Decimal('0.0198'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('836.37'),
#   'nwords': 22,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.71',
#   'speakerId': 's0001',
#   'startTime': Decimal('830.05'),
#   'trans': "This is, it's an interesting time at the moment they are heading into their annual Congress in Bahrain, in two weeks' time."},
#  {'SummaryProb': Decimal('0.6917'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('884.71'),
#   'nwords': 149,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.72',
#   'speakerId': 's0001',
#   'startTime': Decimal('836.65'),
#   'trans': "It is two years from those dawn raids in Zurich, where a number, a few for officials were arrested for fraud and bribery allegations, then those Court case, or some of them are still going on, but he's very keen to draw a line under the fared as President as talked in recent weeks about the crisis within which, of course, doctor for many years, being over this case involving shake awkward one of its leading officials, even though he denies any wrongdoing is embarrassing for them, and I think they will Again, welcome the position for him to stand aside, but nevertheless, it does present some problems for them still clearly questions about its governors process and about the people who were connected with this, a sports news correspondent Richard Conway, you're listening to global news, the most important stories and the best interviews, and on the spot."},
#  {'SummaryProb': Decimal('0.0803'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('893.08'),
#   'nwords': 29,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.73',
#   'speakerId': 's0001',
#   'startTime': Decimal('884.71'),
#   'trans': "Reporting from the B.B.C. world service, and remember that every weekend, you can hear a review of the week's main new stories and why they matter in the world."},
#  {'SummaryProb': Decimal('0.0352'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('894.78'),
#   'nwords': 6,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.74',
#   'speakerId': 's0001',
#   'startTime': Decimal('893.08'),
#   'trans': "This week, it's broadcast at weekends."},
#  {'SummaryProb': Decimal('0.4083'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('930.56'),
#   'nwords': 91,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.75',
#   'speakerId': 's0001',
#   'startTime': Decimal('894.9'),
#   'trans': "And it's also available to download from our website, a Swiss national has been arrested in the German financial capital, Frankfurt on suspicion of spying, it's alleged he'd been monitoring German financial investigators since twenty twelve to find out who'd been selling them confidential details of tax evaders German tax authorities have reportedly paid millions of dollars to insiders in Swiss banks for lists of potential cheats causing friction between the Swiss and German governments are Europe editor Mike slanders told us what information had been released about the suspect, right."},
#  {'SummaryProb': Decimal('0.1619'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('955.74'),
#   'nwords': 79,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.76',
#   'speakerId': 's0001',
#   'startTime': Decimal('930.55'),
#   'trans': "Well, what's coming from the highest Court in germolene cars, Rela, is that he's called, Daniel em, that's all they're saying he's fifty four years at Swiss citizen, and he was arrested in Frankfurt financial capital, on the basis of an arrest warrant that was issued last December, so they've obviously had their eye on him for some time, and when he was arrested several homes and Offices were also raided, he's accused of spying for a foreign power."},
#  {'SummaryProb': Decimal('0.1175'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('973.57'),
#   'nwords': 55,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.77',
#   'speakerId': 's0001',
#   'startTime': Decimal('955.74'),
#   'trans': "Since the start of the twenty twelve that's official, he's been put under formal investigation and what the papers are saying is to be spied on German tax inspectors to find out who was selling them confidential data about Swiss Bank accounts, so how has tax evasion, the whole issue of tax evasion actually affected."},
#  {'SummaryProb': Decimal('0.3014'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1004.17'),
#   'nwords': 98,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.78',
#   'speakerId': 's0001',
#   'startTime': Decimal('973.57'),
#   'trans': 'Relations between Switzerland and Germany, very badly hermit was a quite a major issue in the last election in Germany, in twenty thirteen, Switzerland and Germany, actually had signed a deal on what they call, withholding tax, and the idea was, they would claw back money from Swiss Bank accounts undeclared account surreptitiously and make some tax came that way, but the that was voted down by the social Democrats in Parliament, because they insisted that any wrongdoers tax evaders should be maimed and punished publicly not paying tax on the quiet, so that was one major issue.'},
#  {'SummaryProb': Decimal('0.7736'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1057.44'),
#   'nwords': 155,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.79',
#   'speakerId': 's0001',
#   'startTime': Decimal('1004.37'),
#   'trans': "I would, to be fair, Switzerland has made efforts to dilute the banking sequence of secrecy, signed an agreement with the E.U. and twenty fifteen on banking transparency, that's an annual exchange of information, but what it really objects to his people making money out of data that they've stolen, the first prosecution goes back to two thousand seven, a guy called scene, a la poor who work for trilly Swiss, and he was caught copying data by hand and selling it on a Europe Editor Mike Sanders the names of thousands of streams hills and meadows are causing a political row in South Tyrol, Italy's mainly German speaking province, the roots of the dispute date back to the fascist era, when the region once part of Austria was annexed by Italy, after the first world war, many place names in German were replaced by Italian names in an attempt to Italian eyes, the province."},
#  {'SummaryProb': Decimal('0.0666'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1065.72'),
#   'nwords': 22,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.80',
#   'speakerId': 's0001',
#   'startTime': Decimal('1057.83'),
#   'trans': 'Political parties have been wrangling over which names should be kept and old resentments are resurfacing Bethany Bell reports from South Tyrol.'},
#  {'SummaryProb': Decimal('0.0549'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1088.93'),
#   'nwords': 46,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.81',
#   'speakerId': 's0001',
#   'startTime': Decimal('1071.42'),
#   'trans': "This is the over egg and ski resort in the Italian Alps and has a fantastic view of the craggy Dolomite mountains with snow on the peak, its official name in Italian is sunflower, but I haven't seen that name on any signs here at all."},
#  {'SummaryProb': Decimal('0.0605'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1104.96'),
#   'nwords': 36,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.82',
#   'speakerId': 's0001',
#   'startTime': Decimal('1089.1'),
#   'trans': "People here say almost no one calls it, that not even the Italians just over geographical place names and South Tyrol, a complicated, and that's due in no small part to a man called Hector, Aye."},
#  {'SummaryProb': Decimal('0.2326'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1139.22'),
#   'nwords': 76,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.83',
#   'speakerId': 's0001',
#   'startTime': Decimal('1104.97'),
#   'trans': "Ptolemy and Italian nationalist and a fashion known to some as the gravedigger of South Tyrol and a compact showed the Governor's South Tyrol says Tolen they invented around eight thousand Italian geographical place names to replace the German ones, the nineteen twenties there was this changing off name subduing the fascist period, done by Mussolini, and this person into Ptolemy invented Italian names for all the place was so quiet or German or Latin names."},
#  {'SummaryProb': Decimal('0.0335'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1148.85'),
#   'nwords': 24,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.84',
#   'speakerId': 's0001',
#   'startTime': Decimal('1139.26'),
#   'trans': 'Originally, just to show that this was an Italian region, just to make it Italian, and this was a crime, but life goes on.'},
#  {'SummaryProb': Decimal('0.0185'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1156.59'),
#   'nwords': 21,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.85',
#   'speakerId': 's0001',
#   'startTime': Decimal('1148.85'),
#   'trans': "We know it's one hundred years ago, and so we have now a debate on how to deal with this situation."},
#  {'SummaryProb': Decimal('0.0415'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1170.65'),
#   'nwords': 30,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.86',
#   'speakerId': 's0001',
#   'startTime': Decimal('1159.19'),
#   'trans': 'Political parties have so far failed to find agreement on which name should be officially recognised in future, and the row has inflamed old resentments between German and Italian speaker.'},
#  {'SummaryProb': Decimal('0.013'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1174.83'),
#   'nwords': 8,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.87',
#   'speakerId': 's0001',
#   'startTime': Decimal('1171.53'),
#   'trans': 'Some groups want all the Ptolemy names removed.'},
#  {'SummaryProb': Decimal('0.0132'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1176.82'),
#   'nwords': 6,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.88',
#   'speakerId': 's0001',
#   'startTime': Decimal('1174.96'),
#   'trans': "Stefan's Elgar, it's from the zoo."},
#  {'SummaryProb': Decimal('0.0897'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1196.03'),
#   'nwords': 57,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.89',
#   'speakerId': 's0001',
#   'startTime': Decimal('1176.82'),
#   'trans': "Do you order sky height or small opposition party, the once independence from Italy, I ask offer she isthmus kipper tuck everything that fascism, dude, with the aim of rewriting South Tyrolean history, with the aim of making South to all Italian, it's not, it never was as a cultural crime and has no right to exist."},
#  {'SummaryProb': Decimal('0.0646'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1206.81'),
#   'nwords': 24,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.90',
#   'speakerId': 's0001',
#   'startTime': Decimal('1196.75'),
#   'trans': 'We want these names to go no more Ptolemy names, a compact come, says no Italian names are towns or cities will be removed.'},
#  {'SummaryProb': Decimal('0.156'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1236.17'),
#   'nwords': 82,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.91',
#   'speakerId': 's0001',
#   'startTime': Decimal('1206.97'),
#   'trans': "But his party says Tyler maze names of hills, woods and meadows which aren't used by Italians nowadays should go, we say, let's use the name, which aren't really used by the people, because obviously, we have to use all the original German had lead in named, of course, we have to use the Italian names to who originated where fascists inventions, but in the meantime, just to names of places for the people living here foot Italian speaking people Living here."},
#  {'SummaryProb': Decimal('0.0178'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1242.26'),
#   'nwords': 10,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.92',
#   'speakerId': 's0001',
#   'startTime': Decimal('1236.25'),
#   'trans': 'We want to give this job to Commissioner composed scientists.'},
#  {'SummaryProb': Decimal('0.0142'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1248.31'),
#   'nwords': 17,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.93',
#   'speakerId': 's0001',
#   'startTime': Decimal('1242.5'),
#   'trans': "Just look, which I'll do the names were used by the people, and this is our position."},
#  {'SummaryProb': Decimal('0.0296'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1260.72'),
#   'nwords': 29,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.94',
#   'speakerId': 's0001',
#   'startTime': Decimal('1248.32'),
#   'trans': "I think it's the only position to keep on to live in peace together, but that proposal has upset some Italian speakers concerned about German dominance in the province."},
#  {'SummaryProb': Decimal('0.0483'),
#   'classId': 'transcript',
#   'conv': '20170430222100globalnewspodcast',
#   'endTime': Decimal('1274.62'),
#   'nwords': 32,
#   'sid': '20170430222100globalnewspodcast.s0001.sentence.95',
#   'speakerId': 's0001',
#   'startTime': Decimal('1261.1'),
#   'trans': "Alessandro woozy from the outer adage in a quarry party says no Italian place name should be removed, Aw, now are probably McEnery didn't channel four, we strongly condemn this, he says."},
# ...
#   'speakerId': 's0001',
#   'startTime': Decimal('2707.61'),
#   'trans': "What is about to take place, what They're really completing four, it is all ascendancy in the heavyweight so Chi knock outs, never been against an to show that he really is the surreal field, as they call the heavyweight many years his senior inexperience, I actually Josh was British rival Tyson fury, he was in the wilderness with mental health really put himself on the map."},
#  {'SummaryProb': Decimal('0.0172'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2753.08'),
#   'nwords': 6,
#   'sid': '20170429210000newshour.s0001.sentence.200',
#   'speakerId': 's0001',
#   'startTime': Decimal('2751.52'),
#   'trans': "What was bloody Mick, let's go."},
#  {'SummaryProb': Decimal('0.0472'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2760.35'),
#   'nwords': 18,
#   'sid': '20170429210000newshour.s0001.sentence.201',
#   'speakerId': 's0001',
#   'startTime': Decimal('2753.29'),
#   'trans': 'This is the redemption set him off to a long and decorated career weight champion of the world.'},
#  {'SummaryProb': Decimal('0.2327'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2799.67'),
#   'nwords': 98,
#   'sid': '20170429210000newshour.s0001.sentence.202',
#   'speakerId': 's0001',
#   'startTime': Decimal('2760.39'),
#   'trans': "Almost dictate to the site, a seven a side, these two men different styles like the next, let's go, it's a machine like defensive points, a very big man, he has a fantastic jab is quite expensively more includes the holes and tie, and then in the late surrounds generally lets is big right hand, which is very powerful go an all much more straightforward fighter, he comes out caiptean quiet in the first few minutes of a fight, and then he lets his very big explosive or your whole arms attacked his opponent, you liked that them."},
#  {'SummaryProb': Decimal('0.0221'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2806.11'),
#   'nwords': 11,
#   'sid': '20170429210000newshour.s0001.sentence.203',
#   'speakerId': 's0001',
#   'startTime': Decimal('2803.36'),
#   'trans': "We don't know what is going to happen in this fight."},
#  {'SummaryProb': Decimal('0.1607'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2835.14'),
#   'nwords': 51,
#   'sid': '20170429210000newshour.s0001.sentence.204',
#   'speakerId': 's0001',
#   'startTime': Decimal('2806.25'),
#   'trans': "I don't care how old many great imponderable why so much interest in the bout darres about nineteen thousand people packing into Wembley stadium in London, a million expected to tune in in the U.K. alone, to the televised stir about what you've got here, Mick's interested, he came to prominence."},
#  {'SummaryProb': Decimal('0.1115'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2854.82'),
#   'nwords': 44,
#   'sid': '20170429210000newshour.s0001.sentence.205',
#   'speakerId': 's0001',
#   'startTime': Decimal('2835.14'),
#   'trans': 'Of course, I did years ago, There was unknown intensity as a kind of a Ciro, if you like, a neophyte heavyweight in getting his arms raised in the final against the previous Olympic champion the Italian Robert Cameron, and it became a hero.'},
#  {'SummaryProb': Decimal('0.0935'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2890.12'),
#   'nwords': 62,
#   'sid': '20170429210000newshour.s0001.sentence.206',
#   'speakerId': 's0001',
#   'startTime': Decimal('2854.82'),
#   'trans': "Overnight in great Britain remembered as the man he on remand in reading jail some likeable fellow, they're not loud mouth, she's very respectful with opponents, and I think grandmother Waterloo is, and not just fight fans warmed to the fact of this very likeable eight months in the public that we are perhaps witnessing something special emerging in the sporting landscape."},
#  {'SummaryProb': Decimal('0.033'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2895.05'),
#   'nwords': 10,
#   'sid': '20170429210000newshour.s0001.sentence.207',
#   'speakerId': 's0001',
#   'startTime': Decimal('2890.15'),
#   'trans': 'We had a slumbering heavyweight division under he clip shows.'},
#  {'SummaryProb': Decimal('0.0659'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2912.25'),
#   'nwords': 40,
#   'sid': '20170429210000newshour.s0001.sentence.208',
#   'speakerId': 's0001',
#   'startTime': Decimal('2895.05'),
#   'trans': "Now, the Mayor of Kiev's was also heavyweight champion blood in his older brother, but the world when he was dominating for a decade, Vladimir, and now it feels like we are Gareth Davies boxing correspondent of the daily Telegraph."},
#  {'SummaryProb': Decimal('0.0086'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2921.33'),
#   'nwords': 19,
#   'sid': '20170429210000newshour.s0001.sentence.209',
#   'speakerId': 's0001',
#   'startTime': Decimal('2912.25'),
#   'trans': 'Newspapers, speaking from just outside Wembley stadium where that boxing contests between tits and Joshua is about to begin.'},
#  {'SummaryProb': Decimal('0.0066'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2921.9'),
#   'nwords': 2,
#   'sid': '20170429210000newshour.s0001.sentence.210',
#   'speakerId': 's0001',
#   'startTime': Decimal('2921.36'),
#   'trans': "That's it."},
#  {'SummaryProb': Decimal('0.0006'),
#   'classId': 'transcript',
#   'conv': '20170429210000newshour',
#   'endTime': Decimal('2924.04'),
#   'nwords': 5,
#   'sid': '20170429210000newshour.s0001.sentence.211',
#   'speakerId': 's0001',
#   'startTime': Decimal('2922.19'),
#   'trans': 'From this edition of news.'},
#  {'SummaryProb': Decimal('0.4562'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('52.47'),
#   'nwords': 94,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.1',
#   'speakerId': 's0001',
#   'startTime': Decimal('0.09'),
#   'trans': "You're listening to the six o'clock news podcast from B.B.C. radio four B.B.C. news at six o'clock this is Neil, sleet, good evening, our E.U. leaders have unanimously adopted what they call a firm and fair breaks its strategy, they focused on the rights of E.U. citizens and challenged Theresa made to come up with a serious response, the Prime Minister said she'll ensure that Scotland and the U.K. flourish together if she wins the election Scotland's first Minister Nicola sturgeon said she would not, in her words, let the Tories drag Scotland backwards."},
#  {'SummaryProb': Decimal('0.242'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('70.68'),
#   'nwords': 43,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.2',
#   'speakerId': 's0001',
#   'startTime': Decimal('53.11'),
#   'trans': 'Jeremy Corbin has contrasted his leadership skills with Theresa may, accusing her of slipping into a presidential bunker mentality head teachers have voted overwhelmingly to oppose the expansion of grammar schools in England in sport, Sunderland, have been relegated from the premier League.'},
#  {'SummaryProb': Decimal('0.6721'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('116.38'),
#   'nwords': 127,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.3',
#   'speakerId': 's0001',
#   'startTime': Decimal('72.5'),
#   'trans': 'European Union leaders meeting without Theresa may in Brussels have unanimously adopted their Brax it strategy in a very public display of unity, the document which will shape the talks for the next two years, received the formal backing of the leaders, just minutes after they sat down for a working lunch they greeted their decision with a round of applause, the President of the European Council, Donald Tusk, who was chairing the discussion described the E.U. stance as firm and fair, our Europe correspondent Kevin Connelly reports from Brussels, NA e. use leaders came together in a spirit of unanimity and efficiency, But not necessarily sweetness and light from the outgoing French President Francois lon that his last summit came this blunt assessment of what breaks.'},
#  {'SummaryProb': Decimal('0.037'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('127.23'),
#   'nwords': 31,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.4',
#   'speakerId': 's0001',
#   'startTime': Decimal('116.38'),
#   'trans': "It is going to mean for the U.K., you're a creep Oh boy, there will necessarily be a price and a cost for the United Kingdom to have made their choice."},
#  {'SummaryProb': Decimal('0.0304'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('132.45'),
#   'nwords': 19,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.5',
#   'speakerId': 's0001',
#   'startTime': Decimal('127.5'),
#   'trans': 'This is not punitive, but the E.U. will defend it interests and tomorrow, the U.K. will be worse off.'},
#  {'SummaryProb': Decimal('0.0114'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('136.78'),
#   'nwords': 13,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.6',
#   'speakerId': 's0001',
#   'startTime': Decimal('132.48'),
#   'trans': 'Outside you, then it is a Member of the E.U. position on breaks.'},
#  {'SummaryProb': Decimal('0.0999'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('163.52'),
#   'nwords': 69,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.7',
#   'speakerId': 's0001',
#   'startTime': Decimal('136.78'),
#   'trans': "It is now clear, no trade talks until this satisfactory progress on citizens' rights, the size of Britain's departure bill and the future of the Irish border, and the E.U. to decide what's a satisfactory progress means the E.U. Commission President Jean Claude Yonkers seems to doubt that the quality of their preparations is being matched on the British side, I have the impression sometimes their power to France."},
#  {'SummaryProb': Decimal('0.0074'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': 174,
#   'nwords': 24,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.8',
#   'speakerId': 's0001',
#   'startTime': Decimal('163.52'),
#   'trans': "Not all of them, wouldn't go under estimate the technical difficulties to face this single room and not simple question, are fictions are right."},
#  {'SummaryProb': Decimal('0.003'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('176.44'),
#   'nwords': 5,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.9',
#   'speakerId': 's0001',
#   'startTime': Decimal('174.25'),
#   'trans': "He's in, for they cooked."},
#  {'SummaryProb': Decimal('0.056'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('199.46'),
#   'nwords': 67,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.10',
#   'speakerId': 's0001',
#   'startTime': Decimal('176.44'),
#   'trans': "There's, of twenty five different questions which have to be sorts of this will take time, part of the use purpose of this summit was the demonstrated unity on the break that issue, the President of the E.U. Council, Donald Tusk, so that was illustrated by the speed with which the negotiating guidelines had been agreed on a surprising thing cos of us face after Four minutes."},
#  {'SummaryProb': Decimal('0.0136'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('205.84'),
#   'nwords': 10,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.11',
#   'speakerId': 's0001',
#   'startTime': Decimal('200.6'),
#   'trans': "It's something promising European unity on brakes, it is absolute."},
#  {'SummaryProb': Decimal('0.0171'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('214.24'),
#   'nwords': 26,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.12',
#   'speakerId': 's0001',
#   'startTime': Decimal('205.87'),
#   'trans': 'For now, at least at the stage when issues are being discussed, in principle, that may present any future British Prime Minister with a real challenge.'},
#  {'SummaryProb': Decimal('0.4111'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('244.21'),
#   'nwords': 93,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.13',
#   'speakerId': 's0001',
#   'startTime': Decimal('215.09'),
#   'trans': "In response to the Brussels announcement, the brakes, it Secretary David Davis said, both sides wanted the negotiations to be conducted in a spirit of goodwill, but he warned, they would be the most complex that U.K. had faced in her lifetime, a correspondent Chris Morris assesses what today's summit tells us about the European approach to the talks ahead, the negotiating guidelines approved by E.U. leaders haven't changed all that much in the past month or telling indication that their claim to have a unified position on Brecht's it has real substance."},
#  {'SummaryProb': Decimal('0.0159'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('254.9'),
#   'nwords': 31,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.14',
#   'speakerId': 's0001',
#   'startTime': Decimal('244.66'),
#   'trans': 'The other twenty seven countries do see a common purpose in sticking together and, if anything, the main changes in language on a financial settlement on the rights of E.U. citizens.'},
#  {'SummaryProb': Decimal('0.0193'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('260.55'),
#   'nwords': 20,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.15',
#   'speakerId': 's0001',
#   'startTime': Decimal('254.9'),
#   'trans': 'In the U.K toughen up the conditions for the rest of the E.U., says the U.K. will have to meet.'},
#  {'SummaryProb': Decimal('0.01'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('264.8'),
#   'nwords': 11,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.16',
#   'speakerId': 's0001',
#   'startTime': Decimal('261.08'),
#   'trans': 'Of course there are differences of emphasis in different national capitals.'},
#  {'SummaryProb': Decimal('0.0206'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('269.01'),
#   'nwords': 11,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.17',
#   'speakerId': 's0001',
#   'startTime': Decimal('265.05'),
#   'trans': 'Poland is understandably pressing hardest about the rights of its citizens.'},
#  {'SummaryProb': Decimal('0.0212'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('276.93'),
#   'nwords': 28,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.18',
#   'speakerId': 's0001',
#   'startTime': Decimal('269.01'),
#   'trans': 'In the U.K., because there are so many of them, the Dutch are eager to start talks on future trade relations with the U.K. sooner rather than later.'},
#  {'SummaryProb': Decimal('0.0099'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('281.8'),
#   'nwords': 15,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.19',
#   'speakerId': 's0001',
#   'startTime': Decimal('277.28'),
#   'trans': 'But they also want to ensure that the U.K. pays it divorce bill in full.'},
#  {'SummaryProb': Decimal('0.0409'),
#   'classId': 'transcript',
#   'conv': '20170429171500sixoclocknews',
#   'endTime': Decimal('290.37'),
#   'nwords': 25,
#   'sid': '20170429171500sixoclocknews.s0001.sentence.20',
#   'speakerId': 's0001',
#   'startTime': Decimal('282.68'),
#   'trans': 'For now, the Emphasis on unity is real and the determination that the y. you will negotiate in the same manner, should not be underestimated.'},
#  ...]

# %%
#for April 2nd week
cols = list(speakerInfo0[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo0):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
#df0 is the dataFrame of April 2nd week
df0 = pd.DataFrame(rows, index = indices, columns = cols)
df0.convert_objects(convert_numeric=True)
#clean df0
del df0['classId']
del df0['conv']
del df0['sid']
del df0['SummaryProb']
del df0['trans']

#calculate in sentence level the average time for different speakers speak out a word
df0['time']=df0['endTime']-df0['startTime']
df0['average_time']=df0['time']/df0['nwords']
df0=df0.convert_objects(convert_numeric=True)
#find out how many different speakers
#df0['speakerId'].value_counts()
#df0.dtypes
# Out:
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   del sys.path[0]
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# speakerId        object
# nwords            int64
# startTime       float64
# endTime         float64
# time            float64
# average_time    float64
# dtype: object

# %%
#for April 3rd week
cols = list(speakerInfo2[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo2):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
    
#df2 is the dataFrame of April 2nd week
df2 = pd.DataFrame(rows, index = indices, columns = cols)
df2=df2.convert_objects(convert_numeric=True)
#clean df2
del df2['classId']
del df2['conv']
del df2['sid']
del df2['SummaryProb']
del df2['trans']

#calculate in sentence level the average time for different speakers speak out a word
df2['time']=df2['endTime']-df2['startTime']
df2['average_time']=df2['time']/df2['nwords']
#find out how many different speakers
#df2['speakerId'].value_counts()
df2
# Out:
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#      speakerId  nwords  startTime  endTime   time  average_time
# 0        s0001      35       7.59    22.04  14.45      0.412857
# 1        s0001      90      22.04    52.32  30.28      0.336444
# 2        s0001      19      52.32    58.45   6.13      0.322632
# 3        s0001      11      58.84    62.29   3.45      0.313636
# 4        s0001      26      62.58    74.32  11.74      0.451538
# 5        s0001       4      74.51    75.65   1.14      0.285000
# 6        s0001     162      75.84   131.48  55.64      0.343457
# 7        s0001      48     131.48   147.63  16.15      0.336458
# 8        s0001      23     147.63   155.38   7.75      0.336957
# 9        s0001      23     155.77   163.60   7.83      0.340435
# 10       s0001       5     163.60   164.86   1.26      0.252000
# 11       s0001      60     165.19   184.93  19.74      0.329000
# 12       s0001      21     185.91   191.37   5.46      0.260000
# 13       s0001      19     191.54   198.09   6.55      0.344737
# 14       s0001      66     198.28   218.60  20.32      0.307879
# 15       s0001       9     219.56   221.39   1.83      0.203333
# 16       s0001      44     221.57   235.08  13.51      0.307045
# 17       s0001      29     235.08   242.92   7.84      0.270345
# 18       s0001     216     243.33   321.22  77.89      0.360602
# 19       s0001       4     321.29   322.19   0.90      0.225000
# 20       s0001      38     322.19   332.47  10.28      0.270526
# 21       s0001      98     332.48   363.99  31.51      0.321531
# 22       s0001      64     364.09   387.22  23.13      0.361406
# 23       s0001      97     387.22   424.66  37.44      0.385979
# 24       s0001      51     425.20   440.02  14.82      0.290588
# 25       s0001      71     440.09   465.72  25.63      0.360986
# 26       s0001      76     466.65   492.43  25.78      0.339211
# 27       s0001     235     492.46   575.74  83.28      0.354383
# 28       s0001      12     575.79   579.80   4.01      0.334167
# 29       s0001      24     579.80   587.37   7.57      0.315417
# ...        ...     ...        ...      ...    ...           ...
# 9747     s0001      31    1100.82  1112.53  11.71      0.377742
# 9748     s0001      45    1112.83  1131.86  19.03      0.422889
# 9749     s0001      15    1131.86  1136.94   5.08      0.338667
# 9750     s0001      63    1137.62  1162.98  25.36      0.402540
# 9751     s0001       7    1163.44  1166.66   3.22      0.460000
# 9752     s0001      18    1167.21  1173.09   5.88      0.326667
# 9753     s0001       2    1173.09  1173.72   0.63      0.315000
# 9754     s0001      25    1174.19  1183.91   9.72      0.388800
# 9755     s0001      41    1184.59  1199.04  14.45      0.352439
# 9756     s0001      39    1199.62  1212.66  13.04      0.334359
# 9757     s0001      16    1212.87  1217.75   4.88      0.305000
# 9758     s0001      26    1218.40  1229.59  11.19      0.430385
# 9759     s0001      45    1229.59  1247.51  17.92      0.398222
# 9760     s0001      15    1247.51  1251.49   3.98      0.265333
# 9761     s0001       4    1251.49  1252.38   0.89      0.222500
# 9762     s0001      86    1252.62  1282.82  30.20      0.351163
# 9763     s0001      16    1282.87  1289.90   7.03      0.439375
# 9764     s0001      41    1290.26  1303.31  13.05      0.318293
# 9765     s0001      18    1303.31  1309.91   6.60      0.366667
# 9766     s0001       7    1309.91  1311.84   1.93      0.275714
# 9767     s0001      12    1312.21  1315.56   3.35      0.279167
# 9768     s0001      17    1315.89  1322.03   6.14      0.361176
# 9769     s0001      38    1322.04  1332.62  10.58      0.278421
# 9770     s0001      12    1333.12  1335.33   2.21      0.184167
# 9771     s0001      71    1335.56  1359.88  24.32      0.342535
# 9772     s0001      26    1360.50  1370.29   9.79      0.376538
# 9773     s0001      36    1370.31  1384.28  13.97      0.388056
# 9774     s0001       7    1385.43  1386.84   1.41      0.201429
# 9775     s0001      29    1386.84  1395.05   8.21      0.283103
# 9776     s0001      24    1395.57  1401.76   6.19      0.257917
#
# [9777 rows x 6 columns]

# %%
#for April 4th week
cols = list(speakerInfo3[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo3):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
    
#df3 is the dataFrame of April 4th week
df3 = pd.DataFrame(rows, index = indices, columns = cols)
df3=df3.convert_objects(convert_numeric=True)
#clean df3
del df3['classId']
del df3['conv']
del df3['sid']
del df3['SummaryProb']
del df3['trans']

#calculate in sentence level the average time for different speakers speak out a word
df3['time']=df3['endTime']-df3['startTime']
df3['average_time']=df3['time']/df3['nwords']
#find out how many different speakers
df3['speakerId'].value_counts()
# Out:
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# s0001    11283
# Name: speakerId, dtype: int64

# %% [markdown]
# Convert these three dataFrames into three new dataFrame which is group by
# "speakerId" and insert a column named "date" and the column "speed" is set up with the mean of average time of different speakers.
#
# After that merge these three new dataFrames into one dataFrame named df_total.

# %% [markdown]
# 2.how large and complex is it?

# %%
#dataFrame on April 1st week
data1=df1['average_time'].groupby(df1['speakerId']).sum()/df1['speakerId'].value_counts()
df_data1 = pd.DataFrame(data1,columns=['speed'])
df_data1.reset_index(level=0, inplace=True)
df_data1['date']='201704_1st'

#dataFrame on April 2nd week

#print(type(data1[0]))

#print(type(df_data1['speed'][0]))
# data1
data0=df0['average_time'].groupby(df0['speakerId']).sum()/df0['speakerId'].value_counts()
df_data0 = pd.DataFrame(data0,columns=['speed'])
df_data0.reset_index(level=0, inplace=True)
df_data0['date']='201704_2nd'
#df_data0

#dataFrame on April 3rd week
data2=df2['average_time'].groupby(df2['speakerId']).sum()/df2['speakerId'].value_counts()
df_data2 = pd.DataFrame(data2,columns=['speed'])
df_data2.reset_index(level=0, inplace=True)
df_data2['date']='201704_3rd'

#dataFrame on April 4th week
data3=df3['average_time'].groupby(df3['speakerId']).sum()/df3['speakerId'].value_counts()
df_data3 = pd.DataFrame(data3,columns=['speed'])
df_data3.reset_index(level=0, inplace=True)
df_data3['date']='201704_4th'
#merge these three dataFrames into one dataFrame

a = np.array(df_data1)
b = np.array(df_data0)
c = np.array(df_data2)
d = np.array(df_data3)
df_total_april=np.vstack ((a,b,c,d))
df_total_april=pd.DataFrame(df_total_april,columns=['speakerId','speed','date'])

df_total_april = df_total_april.convert_objects(convert_numeric=True)
df_total_april
#df_data1
# Out:
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:39: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   speakerId     speed        date
# 0     s0001  0.340782  201704_1st
# 1     s0001  0.348334  201704_2nd
# 2     s0001  0.342539  201704_3rd
# 3     s0001  0.342319  201704_4th

# %%
#Indexs for May 1st week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170507231000globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170501054100bestoftoday.extsumm.asrsent.json") + 1,"]")
#Indexs for May 2nd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170514230100globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170508055000bestoftoday.extsumm.asrsent.json") + 1,"]")
#Indexs for May 3rd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170521230300globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170515003800worldbusinessreport.extsumm.asrsent.json") + 1,"]")

#Indexs for May 4rd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170531225000globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170522004500worldbusinessreport.extsumm.asrsent.json") + 1,"]")
# Out:
# [ 516 : 588 ]
# [ 447 : 516 ]
# [ 372 : 447 ]
# [ 264 : 372 ]

# %%
########input these indexs and merge these files into one dataFrame####
#for May 1st week
speakerInfo0 = []
for item in urls[516:588]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo0.append(segments[num])
        
#for May 2nd week
speakerInfo1 = []
for item in urls[447:516]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo1.append(segments[num])
        
#for May 3rd week
speakerInfo2 = []
for item in urls[372:447]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo2.append(segments[num])    
#for May 4th week
speakerInfo3 = []
for item in urls[264:372]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo3.append(segments[num])    
speakerInfo3
# Out:
# [{'SummaryProb': Decimal('0.2999'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('31.96'),
#   'nwords': 64,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.1',
#   'speakerId': 's0001',
#   'startTime': Decimal('7.59'),
#   'trans': 'This is the B.B.C. for details of a complete range of programmes go to B.B.C. world service dot com forward slash, Welcome to the latest global news compiled in the early hours of Thursday, the first of June and Valerie Sanderson, with a selection of highlights from across B.B.C. world service news today coming up in Afghanistan, the feeling what just lay it out.'},
#  {'SummaryProb': Decimal('0.0383'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('45.95'),
#   'nwords': 43,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.2',
#   'speakerId': 's0001',
#   'startTime': Decimal('31.97'),
#   'trans': "Quick, most of the people, saying, it's one of the biggest bit day, maybe since forty to fifty years as the country reels from a massive blast that killed ninety people and injured hundreds more we assess, who may have been behind it."},
#  {'SummaryProb': Decimal('0.0872'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('57.99'),
#   'nwords': 34,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.3',
#   'speakerId': 's0001',
#   'startTime': Decimal('46.37'),
#   'trans': 'Also in this podcast is President trump about to pull America out of the Paris climate deal or breast surgeon in England, who carried out unnecessary operations on patients is jailed for fifteen years.'},
#  {'SummaryProb': Decimal('0.4011'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('83.7'),
#   'nwords': 72,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.4',
#   'speakerId': 's0001',
#   'startTime': Decimal('58.03'),
#   'trans': "If you have somebody that drugs, then mutilates people, which he's been found guilty of, I find that a dark chilling crime, we're in Paris, following a very unusual marriage, and despite the constant negative presque Afr F.A. quite a trump tweet has got people scratching their heads, but first, a huge bomb blast, which killed ninety people and injured hundreds more in the Afghan capital Kabul has drawn a worldwide condemnation."},
#  {'SummaryProb': Decimal('0.4716'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('113.9'),
#   'nwords': 76,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.5',
#   'speakerId': 's0001',
#   'startTime': Decimal('83.99'),
#   'trans': "Most of the casualties were Afghans on their way to work or school, but foreign nationals, were also injured, including several U.S. citizens, NA Ashraf Danny described The attack as a crime against humanity and to pomfret reports the dawn hidden in a sewage tanker exploded at a busy intersection on the edge of Campbell's green zone, home to foreign embassies and the Afghan government, it was extremely powerful felt right across the city blowing out."},
#  {'SummaryProb': Decimal('0.0532'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('120.28'),
#   'nwords': 20,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.6',
#   'speakerId': 's0001',
#   'startTime': Decimal('113.9'),
#   'trans': 'Windows and doors across a wide area, reducing the German Embassy close by to the bare shell of a builder.'},
#  {'SummaryProb': Decimal('0.2214'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('145.23'),
#   'nwords': 62,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.7',
#   'speakerId': 's0001',
#   'startTime': Decimal('122.25'),
#   'trans': 'Whatever the intended target, it was ordinary Afghan citizens who bore the brunt of the blast the explosion came in the heart of the rush hour, the streets were packed with people I spoke to an Office worker Abdel Waheed who said it sounded like an earthquake ready huge explosion from, you know any was the feeling what just lay it out.'},
#  {'SummaryProb': Decimal('0.0212'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('154.31'),
#   'nwords': 26,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.8',
#   'speakerId': 's0001',
#   'startTime': Decimal('145.25'),
#   'trans': "Quick and we thought the smog, or just go wearing that Kabul totally into that data and weary laid that big, it's some weird in that."},
#  {'SummaryProb': Decimal('0.0123'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('154.66'),
#   'nwords': 4,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.9',
#   'speakerId': 's0001',
#   'startTime': Decimal('154.31'),
#   'trans': 'What do you do.'},
#  {'SummaryProb': Decimal('0.0787'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('168.76'),
#   'nwords': 36,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.10',
#   'speakerId': 's0001',
#   'startTime': Decimal('154.71'),
#   'trans': "What a Hardman addiction Missy and gentlemen, is he a lot of people have said, it was the biggest explosion cabble has had for a long time, exactly, most of the people, saying, this isn't it."},
#  {'SummaryProb': Decimal('0.1435'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('189.16'),
#   'nwords': 49,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.11',
#   'speakerId': 's0001',
#   'startTime': Decimal('168.79'),
#   'trans': "It's one of the biggest bit, the very much bed explosion from the cupboard people, maybe since forty to fifty years cameras outside hospitals captured scores of people arriving blood streaming down the faces of the walking wounded and crowds of anxious relatives, trying to find their loved ones."},
#  {'SummaryProb': Decimal('0.0462'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('197.53'),
#   'nwords': 24,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.12',
#   'speakerId': 's0001',
#   'startTime': Decimal('189.73'),
#   'trans': 'Diane panic and emergency Coordinator at a medical centre, close to the blast said staff moved quickly to treat the victims within five minutes.'},
#  {'SummaryProb': Decimal('0.0383'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('201.66'),
#   'nwords': 15,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.13',
#   'speakerId': 's0001',
#   'startTime': Decimal('197.53'),
#   'trans': "We had more than one hundred people marking banging guard gates total, I've been inside."},
#  {'SummaryProb': Decimal('0.0736'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('207.97'),
#   'nwords': 17,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.14',
#   'speakerId': 's0001',
#   'startTime': Decimal('202.48'),
#   'trans': 'Luckily, most of them, but our walking wounded you try a for, followed by an aunt facility.'},
#  {'SummaryProb': Decimal('0.1099'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('221.27'),
#   'nwords': 34,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.15',
#   'speakerId': 's0001',
#   'startTime': Decimal('208.42'),
#   'trans': "And verily received the Celia's whilst amputations there that they had trauma penetrating injury stall by the parts and the Eiger are running in the four operas salty at the procedures and saved lives."},
#  {'SummaryProb': Decimal('0.2707'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('246.51'),
#   'nwords': 64,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.16',
#   'speakerId': 's0001',
#   'startTime': Decimal('222.53'),
#   'trans': 'An Afghan driver working for the B.B.C. Mohammed nazir was among the people killed the Taliban denied responsibility for the bombing the attack has been widely condemned by the Afghan government and by foreign governments and showing complete disregard for human life, the Afghan intelligence service accused a militant group called the her cunny or being behind the blast, with the backing of Pakistan.'},
#  {'SummaryProb': Decimal('0.1113'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('258.78'),
#   'nwords': 34,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.17',
#   'speakerId': 's0001',
#   'startTime': Decimal('246.8'),
#   'trans': 'So who are the her carne, I asked out South Asia regional editor give mcgivern he her carne network is a militant group, which is affiliated to the Afghan Taliban and works with them.'},
#  {'SummaryProb': Decimal('0.0527'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('267.13'),
#   'nwords': 30,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.18',
#   'speakerId': 's0001',
#   'startTime': Decimal('258.78'),
#   'trans': "Essentially, some people call it, so one of the military arms, they're based in the East of the country, and they're based in that border area between Afghanistan and Pakistan."},
#  {'SummaryProb': Decimal('0.1724'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('283.25'),
#   'nwords': 50,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.19',
#   'speakerId': 's0001',
#   'startTime': Decimal('267.32'),
#   'trans': "So Afghanistan and the Afghan government has, for a while blamed the Pakistanis for giving safe haven to groups like the her carne network, Pakistan, of course, is always in the past denied that its support Any sort of cross border militancy other players in the frame, too, aren't there."},
#  {'SummaryProb': Decimal('0.0813'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('291.58'),
#   'nwords': 29,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.20',
#   'speakerId': 's0001',
#   'startTime': Decimal('283.61'),
#   'trans': "Yes, I know, one of the things that's confusing about this is that we have now the Afghan government basically saying, we believe this was the her carne network."},
#  {'SummaryProb': Decimal('0.0377'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('295.69'),
#   'nwords': 14,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.21',
#   'speakerId': 's0001',
#   'startTime': Decimal('291.69'),
#   'trans': "And yet, we've also had the Taliban saying we deny any sort of involvement."},
#  {'SummaryProb': Decimal('0.2703'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('318.83'),
#   'nwords': 84,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.22',
#   'speakerId': 's0001',
#   'startTime': Decimal('295.85'),
#   'trans': "Now, it could be that the Afghan government is wrong, and its intelligence, or that it's gone into a pattern quite quickly a narrative that it has of blaming Pakistan, which is politically expedient for it, or it could be that, for various reasons, including, perhaps a number of civilian casualties on the impact this will have on public opinion that the Taliban was involved in it, but has decided to distance itself also in the picture, then we've got the Islamic state group."},
#  {'SummaryProb': Decimal('0.0522'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('325.81'),
#   'nwords': 23,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.23',
#   'speakerId': 's0001',
#   'startTime': Decimal('318.94'),
#   'trans': 'So, another militant group, not engaged with the Taliban in their scent arrival of the Taliban based in the East of the country.'},
#  {'SummaryProb': Decimal('0.2443'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('349.69'),
#   'nwords': 74,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.24',
#   'speakerId': 's0001',
#   'startTime': Decimal('326.12'),
#   'trans': "We know that, in the past, they have carried out some very high profile attacks in Kabul, and we also know, of course, that it's less than seven weeks since the U.S. dropped that very powerful bomb on I.S. areas, trying to attack some of their underground networks, it was called the mother of all bombs are tremendously powerful explosive and so some people have thought, well, this is a massive bomb in Kabul."},
#  {'SummaryProb': Decimal('0.8896'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('393.67'),
#   'nwords': 158,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.25',
#   'speakerId': 's0001',
#   'startTime': Decimal('349.82'),
#   'trans': "Perhaps this could be responding to that, and trying to make a Similar point saying this is a massive response to the sort of expose were used against us, but we may never know, we may not, and one of the difficulties is we had thought that perhaps the Islamic state would respond within hours, and say that, yes, it had been involved in this, if indeed it was involved, but very often we get these claims for militant groups, and they may be given for all sorts of very complicated political reasons, it doesn't mean that when the Taliban says, we didn't do something, it necessarily didn't, it doesn't mean that when, for example, I s. says, even if they came forward and said, yes, we did do it, but they necessarily did, so it's very hard, it takes a long time for intelligence service to unravel what happens, and the real truth often only comes out."},
#  {'SummaryProb': Decimal('0.1272'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('410.42'),
#   'nwords': 46,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.26',
#   'speakerId': 's0001',
#   'startTime': Decimal('393.82'),
#   'trans': 'Years later, when we get leaks from intelligence with hindsight, German gibbering when the Paris climate change agreement was signed by almost two hundred countries in twenty fifteen it was hailed as a huge step forward in efforts to cut carbon emissions and curb global warming.'},
#  {'SummaryProb': Decimal('0.0636'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('417.79'),
#   'nwords': 23,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.27',
#   'speakerId': 's0001',
#   'startTime': Decimal('410.74'),
#   'trans': 'The U.S. under President Obama was a signatory, but the current occupant of the white House says, the agreement is bad for business.'},
#  {'SummaryProb': Decimal('0.0359'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('427.06'),
#   'nwords': 30,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.28',
#   'speakerId': 's0001',
#   'startTime': Decimal('418.13'),
#   'trans': "Now, U.S. media are widely reporting that President trump will pull out of the Paris, a Court, for his part, my trump only says he'll make an announcement very soon."},
#  {'SummaryProb': Decimal('0.1692'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('445.02'),
#   'nwords': 48,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.29',
#   'speakerId': 's0001',
#   'startTime': Decimal('427.74'),
#   'trans': "The European Union's energy, Commissioner, Is a matter of self kovic, he says, if Mister trump does decide to withdraw the U.S., Europe will take up the reins of leadership, he had very strong economic case we have first talk supporter of our population and people carry on."},
#  {'SummaryProb': Decimal('0.0285'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('457.83'),
#   'nwords': 17,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.30',
#   'speakerId': 's0001',
#   'startTime': Decimal('446.09'),
#   'trans': 'I think, despite all of this possible Roebuck of U.S. administration of the economic factors would prevail.'},
#  {'SummaryProb': Decimal('0.1049'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('470.32'),
#   'nwords': 35,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.31',
#   'speakerId': 's0001',
#   'startTime': Decimal('458.01'),
#   'trans': 'In the end, about Europe is ready for their leader sheep people definitely, but what would a U.S. withdrawal mean exactly what impact would it have, Jennifer Morgan is a veteran activist on climate change.'},
#  {'SummaryProb': Decimal('0.0504'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('477.3'),
#   'nwords': 18,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.32',
#   'speakerId': 's0001',
#   'startTime': Decimal('470.46'),
#   'trans': "She's currently an Executive Director at Greenpeace, international, and she's book to the B.B.C.'s ten francs, the Paris."},
#  {'SummaryProb': Decimal('0.0432'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('479.81'),
#   'nwords': 7,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.33',
#   'speakerId': 's0001',
#   'startTime': Decimal('477.37'),
#   'trans': "I'm an accord requires a few things."},
#  {'SummaryProb': Decimal('0.6241'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('520.58'),
#   'nwords': 105,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.34',
#   'speakerId': 's0001',
#   'startTime': Decimal('479.84'),
#   'trans': "It requires countries to act and reduce their omissions by her targets that they put for themselves, and to report on those target, which in the U.S case, just to be clear, is what between at least twenty six percent cut in omissions two thousand five omissions by twenty twenty right, I exactly, I'm so there is a series of domestic measures that the Obama administration, put in place to reduce emissions in the energy sector, r. and r. and there was know would no longer, I'll be part of the Paris agreements, countries also agreed to supervise climate finding, I'm stew or developing countries."},
#  {'SummaryProb': Decimal('0.1091'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('531.6'),
#   'nwords': 32,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.35',
#   'speakerId': 's0001',
#   'startTime': Decimal('521.74'),
#   'trans': "So that would not want to be the case, I'm going to Paris acquired and then, finally, I think, a big one, it's there, there's An overarching goal, basically to move away."},
#  {'SummaryProb': Decimal('0.2882'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('552.92'),
#   'nwords': 54,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.36',
#   'speakerId': 's0001',
#   'startTime': Decimal('532.44'),
#   'trans': "I thought, yours and will chose your carbon economy ends that would no longer be a guiding long term goal over the U.S., but what about the argument that Donald trump, he's a man, he's come from business, he listens to business leaders and business is increasingly pouring its money in to clean fuels."},
#  {'SummaryProb': Decimal('0.0559'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('558.8'),
#   'nwords': 16,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.37',
#   'speakerId': 's0001',
#   'startTime': Decimal('552.92'),
#   'trans': 'So he might just follow the money without an international record, telling him where to go.'},
#  {'SummaryProb': Decimal('0.0497'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('563.62'),
#   'nwords': 11,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.38',
#   'speakerId': 's0001',
#   'startTime': Decimal('560.14'),
#   'trans': "I think it's true that this is where business is going."},
#  {'SummaryProb': Decimal('0.0245'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('565.71'),
#   'nwords': 7,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.39',
#   'speakerId': 's0001',
#   'startTime': Decimal('563.69'),
#   'trans': 'This is where the innovation is happening.'},
#  {'SummaryProb': Decimal('0.0607'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('571.21'),
#   'nwords': 18,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.40',
#   'speakerId': 's0001',
#   'startTime': Decimal('565.71'),
#   'trans': 'This is where the jobs are, which is good, but climate change is a problem, and it needs.'},
#  {'SummaryProb': Decimal('0.1864'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('591.28'),
#   'nwords': 60,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.41',
#   'speakerId': 's0001',
#   'startTime': Decimal('571.21'),
#   'trans': "Everybody to be working together to solve it, and what the carrots are cordon it drives through a away set of steps were country stew meat emission reduction targets and then increased overtime, until we get to that there coral economy, and that's part of a global packed in a way takes care of each other to solve this problem."},
#  {'SummaryProb': Decimal('0.0553'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('601.49'),
#   'nwords': 25,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.42',
#   'speakerId': 's0001',
#   'startTime': Decimal('591.73'),
#   'trans': "All the signals are at the moment that other major signatories to the Paris climate records are going to push full steam ahead, aren't they."},
#  {'SummaryProb': Decimal('0.0131'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('603.22'),
#   'nwords': 2,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.43',
#   'speakerId': 's0001',
#   'startTime': Decimal('602.45'),
#   'trans': "That's correct."},
#  {'SummaryProb': Decimal('0.0909'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('611.51'),
#   'nwords': 29,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.44',
#   'speakerId': 's0001',
#   'startTime': Decimal('603.43'),
#   'trans': "No one, no country has said, they're going to move back, we've just heard, the European Union say they are going to provide leadership, China has been very clear."},
#  {'SummaryProb': Decimal('0.0445'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('615.82'),
#   'nwords': 12,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.45',
#   'speakerId': 's0001',
#   'startTime': Decimal('611.53'),
#   'trans': 'Since the beginning of the year, that they take their responsibilities seriously.'},
#  {'SummaryProb': Decimal('0.0785'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('625.21'),
#   'nwords': 29,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.46',
#   'speakerId': 's0001',
#   'startTime': Decimal('615.82'),
#   'trans': "They're investing in renewables, India, I just told chance, A miracle, or a day ago that India will stay on and the g. six countries made that very clear."},
#  {'SummaryProb': Decimal('0.0422'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('627.76'),
#   'nwords': 7,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.47',
#   'speakerId': 's0001',
#   'startTime': Decimal('625.57'),
#   'trans': 'Last week, in which case I wonder.'},
#  {'SummaryProb': Decimal('0.0253'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('630.23'),
#   'nwords': 11,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.48',
#   'speakerId': 's0001',
#   'startTime': Decimal('627.94'),
#   'trans': 'I mean, clearly, you would say that it would be regrettable.'},
#  {'SummaryProb': Decimal('0.1583'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('644.6'),
#   'nwords': 37,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.49',
#   'speakerId': 's0001',
#   'startTime': Decimal('630.23'),
#   'trans': 'Were the U.S. to pull out formally from climate change, he called, but how much difference practically would make to that effort to curb climate change, it would make the long term goals are harder to achieve.'},
#  {'SummaryProb': Decimal('0.116'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('660.96'),
#   'nwords': 39,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.50',
#   'speakerId': 's0001',
#   'startTime': Decimal('644.6'),
#   'trans': "Obviously, because the U.S. is still the second largest polluter, but I think, more importantly, it's just a, it's a step of moral your reprehensible moral whack of moral authority or moral responsibility on behalf of the United States."},
#  {'SummaryProb': Decimal('0.3367'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('686.74'),
#   'nwords': 79,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.51',
#   'speakerId': 's0001',
#   'startTime': Decimal('660.99'),
#   'trans': "And so I think it, in the end, it will be against the U.S. national interest, not to be part of that you were asked to send the signal to countries and people around the world that are experiencing, you can tax right now is, there's a bit of a while to be nice, it's a slap in the face, it really breathtaking actively irresponsible vandalism, I think, although we don't precisely know where the U.S. will end up."},
#  {'SummaryProb': Decimal('0.0107'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('691.53'),
#   'nwords': 20,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.52',
#   'speakerId': 's0001',
#   'startTime': Decimal('686.74'),
#   'trans': "I mean, it may well say he's putting out a record, but it's planning to crack on in other ways."},
#  {'SummaryProb': Decimal('0.0248'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('694.51'),
#   'nwords': 4,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.53',
#   'speakerId': 's0001',
#   'startTime': Decimal('693.29'),
#   'trans': 'It could do that.'},
#  {'SummaryProb': Decimal('0.083'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('705.43'),
#   'nwords': 29,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.54',
#   'speakerId': 's0001',
#   'startTime': Decimal('694.75'),
#   'trans': 'Oh, but I think we owe a global agreement animal time lower or approaches on something like climate changes to work together on a shared leadership way to achieve.'},
#  {'SummaryProb': Decimal('0.0407'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('708.63'),
#   'nwords': 9,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.55',
#   'speakerId': 's0001',
#   'startTime': Decimal('705.63'),
#   'trans': 'You know, these types Of climate disasters from happening.'},
#  {'SummaryProb': Decimal('0.263'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('732.34'),
#   'nwords': 71,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.56',
#   'speakerId': 's0001',
#   'startTime': Decimal('709.04'),
#   'trans': "And my hunch is that they wouldn't be doing as much as their promised to do want carrots, if they were to pull out, Jennifer Morgan of Greenpeace, international, with just a week to go until the British general election, has been a live televised debate with one particularly glaring omission, the Prime Minister Theresa may didn't take part sending the home Secretary amber Rudd to represent the ruling conservative party."},
#  {'SummaryProb': Decimal('0.162'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('752.67'),
#   'nwords': 58,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.57',
#   'speakerId': 's0001',
#   'startTime': Decimal('732.34'),
#   'trans': "Instead, and it was only earlier on Wednesday, that the labour leader, Jeremy carbon said he would go after previously insisting he'd only do so if the Prime Minister appeared to all this excitement before the debate had even started a political correspondent Rob Watson told be seized him Franks, that it had been a pretty lively discussion."},
#  {'SummaryProb': Decimal('0.1221'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('776.7'),
#   'nwords': 86,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.58',
#   'speakerId': 's0001',
#   'startTime': 753,
#   'trans': "I guess one thing that you would say is, that's pretty unwieldy, having seven politicians, I was thinking that just around a dinner table in the Watson family when there are four of us things can get pretty tricky to follow the arguments, you can imagine what it's like with seven politicians have been one feature, of course, has the other part is the opposition parties, ganging up on the Conservatives with a sort of anti austerity message and you wouldn't be surprised to hear that."},
#  {'SummaryProb': Decimal('0.0466'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('792.13'),
#   'nwords': 47,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.59',
#   'speakerId': 's0001',
#   'startTime': Decimal('776.7'),
#   'trans': "The other thing that's come up is the absence of, yes, you guessed it, Theresa may, and in his opening statement, the liberal Democrat leader Tim Farron highlighted her absence, With a pointed attack on her policy to charge homeowners for social care dubbed the dementia tax."},
#  {'SummaryProb': Decimal('0.0208'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('794.37'),
#   'nwords': 8,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.60',
#   'speakerId': 's0001',
#   'startTime': Decimal('792.69'),
#   'trans': 'Where do you think Theresa may is tonight.'},
#  {'SummaryProb': Decimal('0.0221'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('796.01'),
#   'nwords': 6,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.61',
#   'speakerId': 's0001',
#   'startTime': Decimal('794.87'),
#   'trans': 'Take a look out your window.'},
#  {'SummaryProb': Decimal('0.0212'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('798.99'),
#   'nwords': 14,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.62',
#   'speakerId': 's0001',
#   'startTime': Decimal('796.19'),
#   'trans': "She might be out, they're sizing up your House to pave your social care."},
#  {'SummaryProb': Decimal('0.0562'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('808.11'),
#   'nwords': 26,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.63',
#   'speakerId': 's0001',
#   'startTime': Decimal('800.12'),
#   'trans': "Why do you think she call this election, she wants five years as Prime Minister, and she thinks you'll give it to her, no questions asked."},
#  {'SummaryProb': Decimal('0.2626'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('837.31'),
#   'nwords': 83,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.64',
#   'speakerId': 's0001',
#   'startTime': Decimal('808.33'),
#   'trans': "Literally, even if she brings in a dementia tucks sucks you kids teachers and mix their Lunches, while she's at it, we can all agree that is a rubbish that was Tim Farron talking about this so called dementia attacks robbed in terms of the coming Conservatives, they've been trying to frame this election has being all about bricks it, how is that playing in this debate, there was a big question about skills, and it turned out to come down to immigration."},
#  {'SummaryProb': Decimal('0.0101'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('848.12'),
#   'nwords': 33,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.65',
#   'speakerId': 's0001',
#   'startTime': Decimal('837.34'),
#   'trans': 'And again, amber Rudd, he was there for the conservative party said, look, we will try to manage migration, but she was criticised repeatedly about the Conservatives and ability to meet those targets.'},
#  {'SummaryProb': Decimal('0.0106'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('855.14'),
#   'nwords': 25,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.66',
#   'speakerId': 's0001',
#   'startTime': Decimal('848.39'),
#   'trans': 'I mean, all the other speakers, pretty much said that emigration had been a good thing, which, of course, has somewhat, in contrast to water.'},
#  {'SummaryProb': Decimal('0.2662'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('876.79'),
#   'nwords': 74,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.67',
#   'speakerId': 's0001',
#   'startTime': Decimal('855.17'),
#   'trans': 'Public opinion polls tell us about the way British voters feel about things, but anyway, it was the UKIP leader Paul nuttal who promoted his plan for a points based immigration system for last week, it was announced That a city the size of hall came to this country cousin on the ballot paper that I got in the Bank on a hold of a city the size of hole came to this country.'},
#  {'SummaryProb': Decimal('0.0223'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('880.55'),
#   'nwords': 9,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.68',
#   'speakerId': 's0001',
#   'startTime': Decimal('877.58'),
#   'trans': "That's what your Birmingham over a five year period."},
#  {'SummaryProb': Decimal('0.028'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('881.64'),
#   'nwords': 2,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.69',
#   'speakerId': 's0001',
#   'startTime': Decimal('880.72'),
#   'trans': "It's unsustainable."},
#  {'SummaryProb': Decimal('0.0433'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('888.15'),
#   'nwords': 22,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.70',
#   'speakerId': 's0001',
#   'startTime': Decimal('881.65'),
#   'trans': 'What we need to do is we need to reduce immigration, and we do it by having an Australian points based system.'},
#  {'SummaryProb': Decimal('0.0259'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('891.05'),
#   'nwords': 10,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.71',
#   'speakerId': 's0001',
#   'startTime': Decimal('888.15'),
#   'trans': "So, if you've got the skills that this country needs."},
#  {'SummaryProb': Decimal('0.0494'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('899.69'),
#   'nwords': 14,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.72',
#   'speakerId': 's0001',
#   'startTime': Decimal('891.22'),
#   'trans': 'Yes, please come here and wait, we have to get the population under control.'},
#  {'SummaryProb': Decimal('0.0295'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('906.12'),
#   'nwords': 13,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.73',
#   'speakerId': 's0001',
#   'startTime': Decimal('900.56'),
#   'trans': 'That was not all talking, I guess also Rob this debate is happening.'},
#  {'SummaryProb': Decimal('0.0417'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('911.98'),
#   'nwords': 15,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.74',
#   'speakerId': 's0001',
#   'startTime': Decimal('906.62'),
#   'trans': 'Still, in the shadow of the terrible events of Manchester, very much so very much.'},
#  {'SummaryProb': Decimal('0.0868'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('932.13'),
#   'nwords': 65,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.75',
#   'speakerId': 's0001',
#   'startTime': Decimal('911.98'),
#   'trans': 'So there was a question about what would all the panellists do to protect the U.K., and I guess on that, I suppose, there is broad agreement that people say that you have to have an intelligence led approach to these matters, I guess, perhaps, that was one of the, as well as perhaps a bit less falling out and Jeremy called himself a meaning.'},
#  {'SummaryProb': Decimal('0.0556'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('941.74'),
#   'nwords': 27,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.76',
#   'speakerId': 's0001',
#   'startTime': Decimal('932.4'),
#   'trans': "What do you think lies behind his decision to turn up not quite unannounced, but with little notice what's your estimate of how he's doing so far."},
#  {'SummaryProb': Decimal('0.0155'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('944.92'),
#   'nwords': 8,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.77',
#   'speakerId': 's0001',
#   'startTime': Decimal('943.13'),
#   'trans': 'Look, the reason he decided to show up.'},
#  {'SummaryProb': Decimal('0.0059'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('947.46'),
#   'nwords': 11,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.78',
#   'speakerId': 's0001',
#   'startTime': Decimal('944.92'),
#   'trans': 'I think was pretty clear that he had nothing to lose.'},
#  {'SummaryProb': Decimal('0.007'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('948.97'),
#   'nwords': 6,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.79',
#   'speakerId': 's0001',
#   'startTime': Decimal('947.49'),
#   'trans': 'I mean, he was the underdog.'},
#  {'SummaryProb': Decimal('0.0152'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('960.49'),
#   'nwords': 44,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.80',
#   'speakerId': 's0001',
#   'startTime': Decimal('949.18'),
#   'trans': "Here's an opportunity to appear on nationwide television in the U.K. at Hopefully it from his point of view, reach millions of voters, and also, of course, to be able to taunts Theresa may, with, where are you off your policies are so great."},
#  {'SummaryProb': Decimal('0.0029'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('962.24'),
#   'nwords': 7,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.81',
#   'speakerId': 's0001',
#   'startTime': Decimal('960.79'),
#   'trans': "Why aren't you here to defend them."},
#  {'SummaryProb': Decimal('0.0654'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('976.2'),
#   'nwords': 46,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.82',
#   'speakerId': 's0001',
#   'startTime': Decimal('962.24'),
#   'trans': "He also used the opportunity to challenge amber Rudd and the conservative government's record on welfare to make, if you like an anti austerity point, I would just say, their sense of amber Rudd seem so confident, but this is a country at ease with itself."},
#  {'SummaryProb': Decimal('0.0489'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('993.26'),
#   'nwords': 21,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.83',
#   'speakerId': 's0001',
#   'startTime': Decimal('976.37'),
#   'trans': 'Have you been to a food Bank, have you seen people sleeping did I say liked articles your government of Quorn.'},
#  {'SummaryProb': Decimal('0.0198'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('995.04'),
#   'nwords': 6,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.84',
#   'speakerId': 's0001',
#   'startTime': Decimal('993.61'),
#   'trans': 'I sat at Lee on benefit.'},
#  {'SummaryProb': Decimal('0.2133'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1018.2'),
#   'nwords': 72,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.85',
#   'speakerId': 's0001',
#   'startTime': Decimal('995.95'),
#   'trans': "Applause there for Jeremy Corbin, I guess, Rob, sometimes with these debates, often with these debates, it can peep at the party that is lucky or unlucky enough to be in government finds itself ganged up on is what's happening in the course of this debate, I think that's a pretty shrewd observation that's precisely what's been happening and what amber Rudd has done is I guess it's a two pronged response."},
#  {'SummaryProb': Decimal('0.0264'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1033.09'),
#   'nwords': 55,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.86',
#   'speakerId': 's0001',
#   'startTime': Decimal('1018.2'),
#   'trans': "First of all, there was quite a neat moments in the debates where everyone was shouting at each other, and she said, that's what I mean, that's what reason amazement by a coalition of chaos, rather than having a conservative governments that was quite effective specially seeing as everyone else started arguing at that point."},
#  {'SummaryProb': Decimal('0.0088'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1038.27'),
#   'nwords': 14,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.87',
#   'speakerId': 's0001',
#   'startTime': Decimal('1033.42'),
#   'trans': 'And the second point, I guess, is the defence of austerity, This will resonate.'},
#  {'SummaryProb': Decimal('0.0189'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1052.06'),
#   'nwords': 52,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.88',
#   'speakerId': 's0001',
#   'startTime': Decimal('1039.06'),
#   'trans': "Maybe some of the people who were there at Cambridge in the debate, the people watching on television, where she made the point, and that's the point that I guess Conservatives make the world over, which is lurk countries all over the world have got it's a horrible problems within with debts."},
#  {'SummaryProb': Decimal('0.0063'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1058.52'),
#   'nwords': 24,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.89',
#   'speakerId': 's0001',
#   'startTime': Decimal('1052.07'),
#   'trans': "So, while it's lovely to talk about spending more on welfare, and this, that and the other, we have to live within our means."},
#  {'SummaryProb': Decimal('0.1104'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1070.86'),
#   'nwords': 41,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.90',
#   'speakerId': 's0001',
#   'startTime': Decimal('1058.52'),
#   'trans': "And I NA suspect an awful lot of people watching at home will have said, it's painful, but we kind of agreed Rob Watson, you're listening to global news, the most important stories and the best interviews, and on the spot."},
#  {'SummaryProb': Decimal('0.0312'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1075.35'),
#   'nwords': 12,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.91',
#   'speakerId': 's0001',
#   'startTime': Decimal('1070.86'),
#   'trans': 'Reporting from the B.B.C. world service still to come on this podcast.'},
#  {'SummaryProb': Decimal('0.022'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1080.52'),
#   'nwords': 12,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.92',
#   'speakerId': 's0001',
#   'startTime': Decimal('1075.63'),
#   'trans': "The plan demolition of some apartment blocks in Moscow, it's angering residents."},
#  {'SummaryProb': Decimal('0.3034'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1106.48'),
#   'nwords': 63,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.93',
#   'speakerId': 's0001',
#   'startTime': Decimal('1080.56'),
#   'trans': "They don't respect might, maybe if I wrote about the right of what property something, but what so that they don't respect the arsenal portaloo something that can be compared with the revolution of nineteen seventeen, but first, a British breast surgeon who devastated the lives of ten people by subjecting them to unnecessary operations, has been sentenced to fifteen years in jail."},
#  {'SummaryProb': Decimal('0.163'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1132.54'),
#   'nwords': 69,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.94',
#   'speakerId': 's0001',
#   'startTime': Decimal('1106.84'),
#   'trans': "The Court heard that to get consent for the operations in Patterson had invented or deliberately exaggerated the risk that his patients would develop cancer, a correspondent for Maggie reports from Nottingham Crown Court victim impact statements, which were read out in Court Patterson's patients describe the long lasting effects of his operations, one Carol Johnson described a surgeon, as a monster who'd left her feeling violated and vulnerable."},
#  {'SummaryProb': Decimal('0.0484'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1135.44'),
#   'nwords': 10,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.95',
#   'speakerId': 's0001',
#   'startTime': Decimal('1132.95'),
#   'trans': 'Another Patricia Welsh said when I look in the mirror.'},
#  {'SummaryProb': Decimal('0.0086'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1139.56'),
#   'nwords': 16,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.96',
#   'speakerId': 's0001',
#   'startTime': Decimal('1135.62'),
#   'trans': 'I see a victim of Mister Paterson who took away part of me as a woman.'},
#  {'SummaryProb': Decimal('0.5235'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1184.37'),
#   'nwords': 131,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.97',
#   'speakerId': 's0001',
#   'startTime': Decimal('1140.34'),
#   'trans': "In every case, he lighting his patients and persuaded them to go under the knife when there was no need to another victim John Ingram, who had a double mistake to me spoke outside Court, the climbs were cruel and chilling, when I think of the amount of people he drugged and mutilated stepping away from the fact that he was a consultant surgeon if you have somebody that drugs, then mutilates for their own ends, which has been found guilty of, I find that a dark in chilling, it's not clear what Patterson's motives were police believe it could have been for financial gain his patients have said he liked to play God sentencing him Mister justice Jeremy Baker told Patterson that he manipulated patients, believing that he was untouchable."},
#  {'SummaryProb': Decimal('0.0296'),
#   'classId': 'transcript',
#   'conv': '20170531225000globalnewspodcast',
#   'endTime': Decimal('1187.17'),
#   'nwords': 8,
#   'sid': '20170531225000globalnewspodcast.s0001.sentence.98',
#   'speakerId': 's0001',
#   'startTime': Decimal('1184.94'),
#   'trans': 'Although the maximum sentence could have been life.'},
#  {'SummaryProb': Decimal('0.0382'),
#   'classId': 'transcript',
# ...
#  {'SummaryProb': Decimal('0.067'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('951.45'),
#   'nwords': 26,
#   'sid': '20170531140000newshour.s0001.sentence.81',
#   'speakerId': 's0001',
#   'startTime': Decimal('941.19'),
#   'trans': 'Moreover, the Committee set up my hot headed there, it has already said that there is a kiss made out for an independent fact finding him.'},
#  {'SummaryProb': Decimal('0.0134'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('955.39'),
#   'nwords': 10,
#   'sid': '20170531140000newshour.s0001.sentence.82',
#   'speakerId': 's0001',
#   'startTime': Decimal('951.86'),
#   'trans': 'So I cannot see where the resistance, as coming from.'},
#  {'SummaryProb': Decimal('0.0086'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('957.96'),
#   'nwords': 11,
#   'sid': '20170531140000newshour.s0001.sentence.83',
#   'speakerId': 's0001',
#   'startTime': Decimal('955.46'),
#   'trans': 'Are you clear that you will be able to go there.'},
#  {'SummaryProb': Decimal('0.0621'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('971.1'),
#   'nwords': 32,
#   'sid': '20170531140000newshour.s0001.sentence.84',
#   'speakerId': 's0001',
#   'startTime': Decimal('958.74'),
#   'trans': "Clear that we're we to get the best possible assistance from the Secretariat of the human rights Commission, they will be in a position to persuade them to allow us to go."},
#  {'SummaryProb': Decimal('0.2552'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1009.66'),
#   'nwords': 88,
#   'sid': '20170531140000newshour.s0001.sentence.85',
#   'speakerId': 's0001',
#   'startTime': Decimal('971.33'),
#   'trans': "I see, so if I'm saying, says, you know what, don't come, you can't go well, you're right, because being U.N. fact finding body, you know the un always functions in NA co-ordination with local authorities, and we have no intention of going there's Sir up to, but would the inquiry will proceed as you are aware, there are several refugees on the borders outside the country, and in some these With my dim members, we will have to also interviewed the refugees who fled the country, right."},
#  {'SummaryProb': Decimal('0.3564'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1047.32'),
#   'nwords': 112,
#   'sid': '20170531140000newshour.s0001.sentence.86',
#   'speakerId': 's0001',
#   'startTime': Decimal('1009.66'),
#   'trans': "So, you're saying, you will be able to do something, even if you're not there, but certainly, because that's our man day attend, we intend to go ahead with that I meant it and just on the situation of the ring goes, what can you tell us that is your basic idea is you're going into it, for people who are not familiar with what's happening to that Community, I think their biggest problem is that they have been rendered stateless, there has been intense why islands, is what I read, both from the investigation down, but the U.N., as also from the interim report, of course, therefore, it calls for benchmarking."},
#  {'SummaryProb': Decimal('0.0506'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1061.42'),
#   'nwords': 37,
#   'sid': '20170531140000newshour.s0001.sentence.87',
#   'speakerId': 's0001',
#   'startTime': Decimal('1047.4'),
#   'trans': "What's going on over there against the international conventions which my Mara has also signed, so it's a very serious matter rich chords for the attention of international Community, which is the reason by the human rights."},
#  {'SummaryProb': Decimal('0.2029'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1081.98'),
#   'nwords': 56,
#   'sid': '20170531140000newshour.s0001.sentence.88',
#   'speakerId': 's0001',
#   'startTime': Decimal('1061.42'),
#   'trans': "Commission has set up this fact finding that was Indira tracing there in Delhi, or plan to pull down, thousands of apartment blocks dating back to the Soviet area has infuriated pupil in Moscow, some of whom have taken to the streets to protest biggest demolition project ever seen in Russia's capital is about to start."},
#  {'SummaryProb': Decimal('0.0569'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1090.09'),
#   'nwords': 28,
#   'sid': '20170531140000newshour.s0001.sentence.89',
#   'speakerId': 's0001',
#   'startTime': Decimal('1081.98'),
#   'trans': 'And he targets apartment blocks that went up in the sixties under Nikita Khrushchev, but they plan to demolish them has angered many of the people living there.'},
#  {'SummaryProb': Decimal('0.0349'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1094.54'),
#   'nwords': 13,
#   'sid': '20170531140000newshour.s0001.sentence.90',
#   'speakerId': 's0001',
#   'startTime': Decimal('1090.09'),
#   'trans': "They say they weren't consulted and now fear they will be forcibly rehoused."},
#  {'SummaryProb': Decimal('0.3152'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1118.13'),
#   'nwords': 63,
#   'sid': '20170531140000newshour.s0001.sentence.91',
#   'speakerId': 's0001',
#   'startTime': Decimal('1094.54'),
#   'trans': "To Anonymous city outskirts, it's the latest issue, there's brought Russians out and protests in recent weeks, and a potential headache for the authorities there a presidential elections next year, a correspondent in Moscow is Sarah range, this is more like masturbate we heard planetary construction, but there we have it with a hole, a leg and nastier brought their flat in Moscow."},
#  {'SummaryProb': Decimal('0.1783'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1146.42'),
#   'nwords': 69,
#   'sid': '20170531140000newshour.s0001.sentence.92',
#   'speakerId': 's0001',
#   'startTime': Decimal('1118.16'),
#   'trans': "Eighteen months ago, now they're four bedroomed family home is on the list to be flattened, they moved here to have more space for their children, their Corgi and the piano, but this spring, Moscow's Mayor announce that thousands of blocks like this would be demolished his Office calls it a massive renovation programme for Moscow's older and more dilapidated housing, but for this family, it was a shock."},
#  {'SummaryProb': Decimal('0.0867'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1158.93'),
#   'nwords': 38,
#   'sid': '20170531140000newshour.s0001.sentence.93',
#   'speakerId': 's0001',
#   'startTime': Decimal('1146.45'),
#   'trans': "We were sure of the brick House at all love it, Dutch leg end nastier a software developers, they're members of Prussia's Middle class that grew and grew wealthier in the first years of Vladimir Putin's long rule."},
#  {'SummaryProb': Decimal('0.0121'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1160.41'),
#   'nwords': 3,
#   'sid': '20170531140000newshour.s0001.sentence.94',
#   'speakerId': 's0001',
#   'startTime': Decimal('1159.05'),
#   'trans': "Now they're angry."},
#  {'SummaryProb': Decimal('0.5826'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1208.89'),
#   'nwords': 120,
#   'sid': '20170531140000newshour.s0001.sentence.95',
#   'speakerId': 's0001',
#   'startTime': Decimal('1160.57'),
#   'trans': "I just keep going to fire so wise to see, probably, in my opinion, to each other's like, where I like when that they don't respect might, maybe if I wrote, but the right of what property something, but the more that society stands, I, yes, I did, but just got the rest of us do nasty, I'm going here resisting this weekend, they Joined another street protest the crowds here, call the Mayor's Grand plan deportation not renovation, they fear they'll be sent to vast remote Cowal blocks to ant hills in Anonymous Moscow suburb, I'm just furious here in there. want to prevent their heaven means my own apartment at their feet or everything money surveyor, that's it."},
#  {'SummaryProb': Decimal('0.0066'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1209.77'),
#   'nwords': 3,
#   'sid': '20170531140000newshour.s0001.sentence.96',
#   'speakerId': 's0001',
#   'startTime': Decimal('1209.24'),
#   'trans': "We're going over."},
#  {'SummaryProb': Decimal('0.1291'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1229.74'),
#   'nwords': 53,
#   'sid': '20170531140000newshour.s0001.sentence.97',
#   'speakerId': 's0001',
#   'startTime': Decimal('1209.77'),
#   'trans': "Yes, the Williamite and speeches on stage with just as passionate very funny Marxist used to say that property was left this man took the crowds, but the theft of property, he says, he's worse, allowing people to privatise their homes was one of the most popular reforms in Russia, when communism collapsed."},
#  {'SummaryProb': Decimal('0.3135'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1263.18'),
#   'nwords': 84,
#   'sid': '20170531140000newshour.s0001.sentence.98',
#   'speakerId': 's0001',
#   'startTime': Decimal('1230.11'),
#   'trans': "Today, the rights to property is held dear, I play everybody jezza good image, the flat's been targeted for the brainchild of Nikita Khrushchev the Soviet leader, held in this old newsreel it weren't pretty, and many of the first were prefabs, but they were low rise and, crucially, then millions to leave behind communal housing and gain a space of their six decades on, so they left Kent from the city housing Office told me the buildings, and no longer fit for purpose."},
#  {'SummaryProb': Decimal('0.0162'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1264.14'),
#   'nwords': 3,
#   'sid': '20170531140000newshour.s0001.sentence.99',
#   'speakerId': 's0001',
#   'startTime': Decimal('1263.51'),
#   'trans': 'It did them.'},
#  {'SummaryProb': Decimal('0.0195'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1271.02'),
#   'nwords': 20,
#   'sid': '20170531140000newshour.s0001.sentence.100',
#   'speakerId': 's0001',
#   'startTime': Decimal('1265.64'),
#   'trans': "If we don't do anything about this houses, than in the next fifteen to twenty years, they will become dangerous."},
#  {'SummaryProb': Decimal('0.0289'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1279.26'),
#   'nwords': 22,
#   'sid': '20170531140000newshour.s0001.sentence.101',
#   'speakerId': 's0001',
#   'startTime': Decimal('1271.42'),
#   'trans': "We're talking about twenty five million square metres of housing stock, he cannot demolish that build new housing and move people overnight."},
#  {'SummaryProb': Decimal('0.0617'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1292.93'),
#   'nwords': 28,
#   'sid': '20170531140000newshour.s0001.sentence.102',
#   'speakerId': 's0001',
#   'startTime': Decimal('1279.52'),
#   'trans': "It takes time, so we need to start now Completely, but protest here, there's already forced the Mayor's Office to make some concessions, two thirds of all residents."},
#  {'SummaryProb': Decimal('0.0197'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1296.06'),
#   'nwords': 10,
#   'sid': '20170531140000newshour.s0001.sentence.103',
#   'speakerId': 's0001',
#   'startTime': Decimal('1292.93'),
#   'trans': 'Now have to agree before a building can be demolished.'},
#  {'SummaryProb': Decimal('0.0348'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1305.06'),
#   'nwords': 25,
#   'sid': '20170531140000newshour.s0001.sentence.104',
#   'speakerId': 's0001',
#   'startTime': Decimal('1296.18'),
#   'trans': "But critics have little faith in a fair, vote, and a Catalina showman, a political scientist says they're fierce reaction has worried, those in power."},
#  {'SummaryProb': Decimal('0.0349'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1312.15'),
#   'nwords': 20,
#   'sid': '20170531140000newshour.s0001.sentence.105',
#   'speakerId': 's0001',
#   'startTime': Decimal('1305.06'),
#   'trans': 'Here was just under a year to go to presidential elections are if you have tried to monopolise the media.'},
#  {'SummaryProb': Decimal('0.0612'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1325.13'),
#   'nwords': 38,
#   'sid': '20170531140000newshour.s0001.sentence.106',
#   'speakerId': 's0001',
#   'startTime': Decimal('1312.44'),
#   'trans': "If you have controlled the Lexus, and you will be on the way of what the people are really for me, there would be a relief thinking, what makes him happy, what makes them so you'll even environment."},
#  {'SummaryProb': Decimal('0.0451'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1334.71'),
#   'nwords': 23,
#   'sid': '20170531140000newshour.s0001.sentence.107',
#   'speakerId': 's0001',
#   'startTime': Decimal('1325.13'),
#   'trans': 'Of course, en surprise that includes Andy, O.K., and nastier this issue brought them and many Muscovites on to the streets in protest.'},
#  {'SummaryProb': Decimal('0.07'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1343.61'),
#   'nwords': 25,
#   'sid': '20170531140000newshour.s0001.sentence.108',
#   'speakerId': 's0001',
#   'startTime': Decimal('1334.74'),
#   'trans': "For the very first they climb to keep up the pressure, it's something important if something that they do just not to be ashamed of."},
#  {'SummaryProb': Decimal('0.0535'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1354.7'),
#   'nwords': 18,
#   'sid': '20170531140000newshour.s0001.sentence.109',
#   'speakerId': 's0001',
#   'startTime': Decimal('1343.87'),
#   'trans': "Not doing this, even if they have as one single chance you'll have to, and reporting from Moscow."},
#  {'SummaryProb': Decimal('0.2299'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1382.04'),
#   'nwords': 57,
#   'sid': '20170531140000newshour.s0001.sentence.110',
#   'speakerId': 's0001',
#   'startTime': Decimal('1354.7'),
#   'trans': "There that was Sarah raids, you're listening to a broadcast addition, a news, our available twice each day, straight after the live edition of the programme, and if you are enjoying that, then why not take a look at other podcast from B.B.C. world service, the documentary brings to life stories and investigations from across the globe."},
#  {'SummaryProb': Decimal('0.8897'),
#   'classId': 'transcript',
#   'conv': '20170531140000newshour',
#   'endTime': Decimal('1442.9'),
#   'nwords': 162,
#   'sid': '20170531140000newshour.s0001.sentence.111',
#   'speakerId': 's0001',
#   'startTime': Decimal('1382.25'),
#   'trans': "We've got witness first hand accounts from important moments in history, coming up next, what Happened to al kinda in the years after nine eleven, but first business and Bouba faces problems on two fronts, today is a sacked an engineer, accused of stealing secrets from the owner of Google alphabet, and the board is also reviewing today, a report into what's been alleged as a culture of sexual harassment in the company, Joanna put skirt is politicos tech reporter and, first of all, I asked us asked her to tell us more detail about this engineer who has been dismissed Anthony leavened ask year has been in a lot of trouble with blueberry lately, and with Google, so he's been accused of stealing around fourteen thousand internal documents he self driving car programme at Google, and he started at Luba astro going to audio another self, driving a company that was brought out by Hooper, and in February, Google, specifically way."},
#  ...]

# %%
#for May 1st week
cols = list(speakerInfo0[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo0):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
#df0 is the dataFrame of May 1st week
df0 = pd.DataFrame(rows, index = indices, columns = cols)
df0.convert_objects(convert_numeric=True)
#clean df0
del df0['classId']
del df0['conv']
del df0['sid']
del df0['SummaryProb']
del df0['trans']

#calculate in sentence level the average time for different speakers speak out a word
df0['time']=df0['endTime']-df0['startTime']
df0['average_time']=df0['time']/df0['nwords']
df0=df0.convert_objects(convert_numeric=True)
#find out how many different speakers
#df0['speakerId'].value_counts()
#df0.dtypes


#for May 2nd week
cols = list(speakerInfo1[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo1):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
#df1 is the dataFrame of May 2nd week
df1 = pd.DataFrame(rows, index = indices, columns = cols)
df1 = df1.convert_objects(convert_numeric=True)

#clean df1
del df1['classId']
del df1['conv']
del df1['sid']
del df1['SummaryProb']
del df1['trans']

#calculate in sentence level the average time for different speakers speak out a word
df1['time']=df1['endTime']-df1['startTime']
df1['average_time']=df1['time']/df1['nwords']


#for May 3rd week
cols = list(speakerInfo2[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo2):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
    
#df2 is the dataFrame of May 3rd week
df2 = pd.DataFrame(rows, index = indices, columns = cols)
df2=df2.convert_objects(convert_numeric=True)
#clean df2
del df2['classId']
del df2['conv']
del df2['sid']
del df2['SummaryProb']
del df2['trans']

#calculate in sentence level the average time for different speakers speak out a word
df2['time']=df2['endTime']-df2['startTime']
df2['average_time']=df2['time']/df2['nwords']
#find out how many different speakers
#df2['speakerId'].value_counts()



#for May 4th week
cols = list(speakerInfo3[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo3):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
    
#df3 is the dataFrame of May 4th week
df3 = pd.DataFrame(rows, index = indices, columns = cols)
df3=df3.convert_objects(convert_numeric=True)
#clean df3
del df3['classId']
del df3['conv']
del df3['sid']
del df3['SummaryProb']
del df3['trans']

#calculate in sentence level the average time for different speakers speak out a word
df3['time']=df3['endTime']-df3['startTime']
df3['average_time']=df3['time']/df3['nwords']
#find out how many different speakers
#df3['speakerId'].value_counts()


#dataFrame on April 1st week
data0=df0['average_time'].groupby(df0['speakerId']).sum()/df0['speakerId'].value_counts()
df_data0 = pd.DataFrame(data0,columns=['speed'])
df_data0.reset_index(level=0, inplace=True)
df_data0['date']='201705_1st'

#dataFrame on April 2nd week
data1=df1['average_time'].groupby(df1['speakerId']).sum()/df1['speakerId'].value_counts()
df_data1 = pd.DataFrame(data1,columns=['speed'])
df_data1.reset_index(level=0, inplace=True)
df_data1['date']='201705_2nd'

#dataFrame on April 3rd week
data2=df2['average_time'].groupby(df2['speakerId']).sum()/df2['speakerId'].value_counts()
df_data2 = pd.DataFrame(data2,columns=['speed'])
df_data2.reset_index(level=0, inplace=True)
df_data2['date']='201705_3rd'

#dataFrame on April 4th week
data3=df3['average_time'].groupby(df3['speakerId']).sum()/df3['speakerId'].value_counts()
df_data3 = pd.DataFrame(data3,columns=['speed'])
df_data3.reset_index(level=0, inplace=True)
df_data3['date']='201705_4th'
#merge these three dataFrames into one dataFrame
a = np.array(df_data0)
b = np.array(df_data1)
c = np.array(df_data2)
d = np.array(df_data3)
df_total_may=np.vstack ((a,b,c,d))
df_total_may=pd.DataFrame(df_total_may,columns=['speakerId','speed','date'])

df_total_may = df_total_may.convert_objects(convert_numeric=True)
df_total_may

#df_data1
# Out:
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   del sys.path[0]
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:69: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:98: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:144: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   speakerId     speed        date
# 0     s0001  0.339704  201705_1st
# 1     s0001  0.337357  201705_2nd
# 2     s0001  0.340001  201705_3rd
# 3     s0001  0.334182  201705_4th

# %%
#Indexs for May 1st week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170607151300worldbusinessreport.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170601013000theinquiry.extsumm.asrsent.json") + 1,"]")
#Indexs for May 2nd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170614230500globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170608092200bestoftoday.extsumm.asrsent.json") + 1,"]")
#Indexs for May 3rd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170621230500globalnewspodcast.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170615023000theinquiry.extsumm.asrsent.json") + 1,"]")

#Indexs for May 4rd week
print ("[", urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170627060900bestoftoday.extsumm.asrsent.json"),":",
       urls.index("http://data.cstr.ed.ac.uk/globalvox/extsumm/2017/20170622013000theinquiry.extsumm.asrsent.json") + 1,"]")
# Out:
# [ 193 : 264 ]
# [ 120 : 193 ]
# [ 48 : 120 ]
# [ 0 : 48 ]

# %%
########input these indexs and merge these files into one dataFrame####
#for June 1st week
speakerInfo0 = []
for item in urls[193:264]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo0.append(segments[num])
        
#for June 2nd week
speakerInfo1 = []
for item in urls[120:193]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo1.append(segments[num])
        
#for June 3rd week
speakerInfo2 = []
for item in urls[48:120]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo2.append(segments[num])    
#for June 4th week
speakerInfo3 = []
for item in urls[0:48]:      
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    
    for num in range(len(segments)):
        speakerInfo3.append(segments[num])    
speakerInfo3
# Out:
# [{'SummaryProb': Decimal('0.09'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('11.52'),
#   'nwords': 45,
#   'sid': '20170627060900bestoftoday.s0001.sentence.1',
#   'speakerId': 's0001',
#   'startTime': 0,
#   'trans': "You're listening to a podcast from the today programme on B.B.C. radio four shares in the company that made the cladding on the grim full Tower fell six per cent yesterday after it said it would stop selling the panels for use in tall buildings."},
#  {'SummaryProb': Decimal('0.9111'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('56.03'),
#   'nwords': 153,
#   'sid': '20170627060900bestoftoday.s0001.sentence.2',
#   'speakerId': 's0001',
#   'startTime': Decimal('11.77'),
#   'trans': "He's Dominic o'Connell with that, and the rest of this thanks think yes, this is a comet, which makes a Rinn a bomb panels, use the green filter the shares fell as much as a live in per cent and trading in York yesterday, the recovered to finish six per cent are konik is probably better known by its old name, the big aluminium make up, which was, it was forming a cover broke itself up last year, the company said yesterday, it would stop selling the flammable version of rain, one for use in higher in high rise buildings, regardless of local codes and regulations were land investment Director at invested an investment more, we haven't had the final investigation to the causes of the fire, but this is perhaps not a surprising reaction from this in new York the shares of a five month low and there's a number of implications."},
#  {'SummaryProb': Decimal('0.631'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('85.93'),
#   'nwords': 95,
#   'sid': '20170627060900bestoftoday.s0001.sentence.3',
#   'speakerId': 's0001',
#   'startTime': Decimal('56.03'),
#   'trans': "I suppose there's the, there's the loss of revenue from then stopping selling Renault bond, there's there's threat of legal action, and there's also the reputation or risk that we have had a statement in a company, which I think was some Way to address this reputation no risk from the company, but yes, it's a worrying time for investing in situations like this, we've seen time and time again wriggle almost, regardless of what the investigation finds lawyers acting for victims, tend to go after the people in the chain with the deepest pockets."},
#  {'SummaryProb': Decimal('0.3263'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('97.86'),
#   'nwords': 44,
#   'sid': '20170627060900bestoftoday.s0001.sentence.4',
#   'speakerId': 's0001',
#   'startTime': Decimal('86.16'),
#   'trans': "And that's probably not going to be the building company sense, all the panelling, it'll be the people, the very large cupboard, like a comic that made it, that's true, and that's, I think, is reflected in that the fall on the share price."},
#  {'SummaryProb': Decimal('0.0462'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('106.92'),
#   'nwords': 22,
#   'sid': '20170627060900bestoftoday.s0001.sentence.5',
#   'speakerId': 's0001',
#   'startTime': Decimal('97.86'),
#   'trans': "I mean, we've had a number of big companies that have been in the spotlight in terms of reputation all Desk thoughts."},
#  {'SummaryProb': Decimal('0.0218'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('108.43'),
#   'nwords': 6,
#   'sid': '20170627060900bestoftoday.s0001.sentence.6',
#   'speakerId': 's0001',
#   'startTime': Decimal('106.93'),
#   'trans': 'Fag and being one of them.'},
#  {'SummaryProb': Decimal('0.0674'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('113.56'),
#   'nwords': 10,
#   'sid': '20170627060900bestoftoday.s0001.sentence.7',
#   'speakerId': 's0001',
#   'startTime': Decimal('110.24'),
#   'trans': "And really, if they don't address these concerns of investors."},
#  {'SummaryProb': Decimal('0.0651'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('124.88'),
#   'nwords': 34,
#   'sid': '20170627060900bestoftoday.s0001.sentence.8',
#   'speakerId': 's0001',
#   'startTime': Decimal('113.56'),
#   'trans': "Early on, and then the the the situation can rumble on and really materially affect the share price we haven't actually seen that an iconic, yet we've just seen, a small, it's more awful."},
#  {'SummaryProb': Decimal('0.2925'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('139.9'),
#   'nwords': 53,
#   'sid': '20170627060900bestoftoday.s0001.sentence.9',
#   'speakerId': 's0001',
#   'startTime': Decimal('124.9'),
#   'trans': "It's not directly to do with the Grand hotel, but it is a strange side like this are konik does have a very odd recent history, the Chief Executive class kleinfeld through unknown in Europe, running's evens for a number of years got kicked out after writing a very strange letter didn't he."},
#  {'SummaryProb': Decimal('0.0763'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('146.86'),
#   'nwords': 14,
#   'sid': '20170627060900bestoftoday.s0001.sentence.10',
#   'speakerId': 's0001',
#   'startTime': Decimal('140.66'),
#   'trans': 'This is a later definitely worth reading hit it ultimately led to his demise.'},
#  {'SummaryProb': Decimal('0.22'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('167.56'),
#   'nwords': 61,
#   'sid': '20170627060900bestoftoday.s0001.sentence.11',
#   'speakerId': 's0001',
#   'startTime': Decimal('146.86'),
#   'trans': "He had to resign following the publication of this letter, which was sent to Eliot, which, as an activist hedge Fund manager that ornament thirteen percent of the company, this activist and Fund manager and has three of its own appointees on the board, and they are actively looking for a new sea, so it's had a chequered, yeah, few months."},
#  {'SummaryProb': Decimal('0.0025'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('169.11'),
#   'nwords': 3,
#   'sid': '20170627060900bestoftoday.s0001.sentence.12',
#   'speakerId': 's0001',
#   'startTime': Decimal('167.96'),
#   'trans': 'This particular company.'},
#  {'SummaryProb': Decimal('0.0711'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('176.97'),
#   'nwords': 25,
#   'sid': '20170627060900bestoftoday.s0001.sentence.13',
#   'speakerId': 's0001',
#   'startTime': Decimal('169.27'),
#   'trans': "So other market co op Bank looks too, of course, not put it, it's no longer up for sale, and it's looks like car Bank."},
#  {'SummaryProb': Decimal('0.0065'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('179.08'),
#   'nwords': 9,
#   'sid': '20170627060900bestoftoday.s0001.sentence.14',
#   'speakerId': 's0001',
#   'startTime': Decimal('176.97'),
#   'trans': 'Finally, is going to live to fight another day.'},
#  {'SummaryProb': Decimal('0.0448'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('183.17'),
#   'nwords': 15,
#   'sid': '20170627060900bestoftoday.s0001.sentence.15',
#   'speakerId': 's0001',
#   'startTime': Decimal('179.59'),
#   'trans': "Oh yes, that that I suppose that's good news, and no longer up for sale."},
#  {'SummaryProb': Decimal('0.0948'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('197.33'),
#   'nwords': 40,
#   'sid': '20170627060900bestoftoday.s0001.sentence.16',
#   'speakerId': 's0001',
#   'startTime': Decimal('183.18'),
#   'trans': "It's, it's managed to work with existing shareholders to find a weed, first of all, I am a separate its pension Fund liabilities and which are about eight billion Pounds and the co op itself carries her, she'll have that."},
#  {'SummaryProb': Decimal('0.1919'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('213.01'),
#   'nwords': 53,
#   'sid': '20170627060900bestoftoday.s0001.sentence.17',
#   'speakerId': 's0001',
#   'startTime': Decimal('198.34'),
#   'trans': "So there's the settling movement on that, and it looks as if they'll be able to sort things out without having to sell that I sell the company, this year, and we spoke yesterday about how activists and bases were gaining power in the market, and no company was too big to target."},
#  {'SummaryProb': Decimal('0.2593'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('234.66'),
#   'nwords': 66,
#   'sid': '20170627060900bestoftoday.s0001.sentence.18',
#   'speakerId': 's0001',
#   'startTime': Decimal('213.01'),
#   'trans': 'Well, along comes proof of that mislay of all companies, one of the largest makers of consumer goods in Europe is now under attack by an American activist, the point, this is the second company, we are all in Unilever and was the subject of a NA bit by craft science, it managed to rebuff that approach by Seeing it was going to increase its margins.'},
#  {'SummaryProb': Decimal('0.0064'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('235.92'),
#   'nwords': 9,
#   'sid': '20170627060900bestoftoday.s0001.sentence.19',
#   'speakerId': 's0001',
#   'startTime': Decimal('234.66'),
#   'trans': 'It was going to be a bit a dividend.'},
#  {'SummaryProb': Decimal('0.5402'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('265.19'),
#   'nwords': 98,
#   'sid': '20170627060900bestoftoday.s0001.sentence.20',
#   'speakerId': 's0001',
#   'startTime': Decimal('235.98'),
#   'trans': "I suspect we're going to see exactly the same form from Nestle and with perhaps don't know one another European giant also in the targets of activist Fund managers at all, it all makes it wants a good, great fun for from this is, thank you much Laura Lambie of investing wealth and looks like the Bank of England will do something about our collective addiction to borrowing when it releases its financial stability report in about three hours' time, personal debt has been growing quickly in the last six months, the has warned about in the past."},
#  {'SummaryProb': Decimal('0.3873'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('294.16'),
#   'nwords': 75,
#   'sid': '20170627060900bestoftoday.s0001.sentence.21',
#   'speakerId': 's0001',
#   'startTime': Decimal('265.28'),
#   'trans': "Oh, Carol is Chief economist at Aberdeen asset management Lucy goose, put it into some sort of historic context for us how bad it is our sort of collective addiction to it, we've seen a big pick her up in two forms of powering really indecent recent one is borrowing Fred approach you in the past year, that has risen to nearly nineteen billion, then credit card borrowing, which is kind of like a tick."},
#  {'SummaryProb': Decimal('0.0718'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('307.65'),
#   'nwords': 44,
#   'sid': '20170627060900bestoftoday.s0001.sentence.22',
#   'speakerId': 's0001',
#   'startTime': Decimal('294.15'),
#   'trans': "At the current on practices has picked up sharply, and in April, the latest Bank of England data showed a credit card pouring rating, it's farcis piece in eleven years, so should be, you should be worried about her, because interest rates are low."},
#  {'SummaryProb': Decimal('0.0271'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('309.4'),
#   'nwords': 8,
#   'sid': '20170627060900bestoftoday.s0001.sentence.23',
#   'speakerId': 's0001',
#   'startTime': Decimal('307.68'),
#   'trans': 'Can we support that level of boy, yes.'},
#  {'SummaryProb': Decimal('0.0125'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('310.05'),
#   'nwords': 4,
#   'sid': '20170627060900bestoftoday.s0001.sentence.24',
#   'speakerId': 's0001',
#   'startTime': Decimal('309.43'),
#   'trans': "The issue isn't it."},
#  {'SummaryProb': Decimal('0.1771'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('328.17'),
#   'nwords': 51,
#   'sid': '20170627060900bestoftoday.s0001.sentence.25',
#   'speakerId': 's0001',
#   'startTime': Decimal('310.1'),
#   'trans': "Yeah, it certainly is, I think there are three concerned, really, because you could argue that it's a sensible thing to allow consumers to, I hate hills, too, we have this acting as a cushion for a situation that had been hit by her in isn't shops, but the worries lie."},
#  {'SummaryProb': Decimal('0.1367'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('345.53'),
#   'nwords': 53,
#   'sid': '20170627060900bestoftoday.s0001.sentence.26',
#   'speakerId': 's0001',
#   'startTime': Decimal('328.41'),
#   'trans': 'What happens if and when interest rates rise because eventually, the, well, what happens if growth slows, both in the short term, or if we find a deterioration in the long run growth potential of the U.K. economy as sort of perhaps breaks it, then the final issue is this a car alone.'},
#  {'SummaryProb': Decimal('0.1193'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('366.77'),
#   'nwords': 58,
#   'sid': '20170627060900bestoftoday.s0001.sentence.27',
#   'speakerId': 's0001',
#   'startTime': Decimal('345.58'),
#   'trans': "In particular, it's a backed by an asset that is falling in value, where we've seen many these cardoons packaged together and sold on to investors as bond so securitisation for anyone who's worked in there for financial institution that was feeling around the ten if global financial crisis that has a resonant history NA does repeat itself."},
#  {'SummaryProb': Decimal('0.0068'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('368.35'),
#   'nwords': 6,
#   'sid': '20170627060900bestoftoday.s0001.sentence.28',
#   'speakerId': 's0001',
#   'startTime': Decimal('367.2'),
#   'trans': "It's a bit rich, isn't it."},
#  {'SummaryProb': Decimal('0.0588'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('378.76'),
#   'nwords': 39,
#   'sid': '20170627060900bestoftoday.s0001.sentence.29',
#   'speakerId': 's0001',
#   'startTime': Decimal('368.35'),
#   'trans': "At the Bank of England to warn about personal bit win whim, it's low interest rates that cause that hypo bit people have been incentivised to borrow by the Bank of England's own policy, and you've identified the conundrum."},
#  {'SummaryProb': Decimal('0.0205'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('383.56'),
#   'nwords': 11,
#   'sid': '20170627060900bestoftoday.s0001.sentence.30',
#   'speakerId': 's0001',
#   'startTime': Decimal('378.76'),
#   'trans': 'Here, the way in which we prevented a big financial crisis.'},
#  {'SummaryProb': Decimal('0.1308'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('401.22'),
#   'nwords': 46,
#   'sid': '20170627060900bestoftoday.s0001.sentence.31',
#   'speakerId': 's0001',
#   'startTime': Decimal('383.56'),
#   'trans': "Turning from a very deep recession into a depression, West to cut interest rates encourage households to, to NA borrow and to Spain, if, of course, at some point, that becomes concerning, I think the Bank Of England, it's become concerning now to just quickly Lisa."},
#  {'SummaryProb': Decimal('0.0778'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('416.22'),
#   'nwords': 36,
#   'sid': '20170627060900bestoftoday.s0001.sentence.32',
#   'speakerId': 's0001',
#   'startTime': Decimal('401.22'),
#   'trans': 'What do you think they might do today took terrain, Becca borrowing other possibility is that the referral immediately made in the aftermath of the referendum, when they cut the banks came her tickle ickle capital.'},
#  {'SummaryProb': Decimal('0.017'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('421.31'),
#   'nwords': 12,
#   'sid': '20170627060900bestoftoday.s0001.sentence.33',
#   'speakerId': 's0001',
#   'startTime': Decimal('416.31'),
#   'trans': "First, we meet refer Saturn, that's just retaining policy at the edges."},
#  {'SummaryProb': Decimal('0.0584'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('434.68'),
#   'nwords': 36,
#   'sid': '20170627060900bestoftoday.s0001.sentence.34',
#   'speakerId': 's0001',
#   'startTime': Decimal('421.91'),
#   'trans': 'Creating a little bit of grit in the system, and perhaps he make for a highlight the risks are too two households of becoming over extended and remind them that eventually interest rates will go up.'},
#  {'SummaryProb': Decimal('0.0018'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('435.83'),
#   'nwords': 4,
#   'sid': '20170627060900bestoftoday.s0001.sentence.35',
#   'speakerId': 's0001',
#   'startTime': Decimal('435.17'),
#   'trans': 'Thank you very much.'},
#  {'SummaryProb': Decimal('0.0199'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('438.46'),
#   'nwords': 8,
#   'sid': '20170627060900bestoftoday.s0001.sentence.36',
#   'speakerId': 's0001',
#   'startTime': Decimal('435.83'),
#   'trans': 'Lucy a cow, Chief economist Aberdeen asset management.'},
#  {'SummaryProb': Decimal('0.2378'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('453.67'),
#   'nwords': 54,
#   'sid': '20170627060900bestoftoday.s0001.sentence.37',
#   'speakerId': 's0001',
#   'startTime': Decimal('438.46'),
#   'trans': 'Well, here in the U.K., we had an epic banking crisis in two thousand eight, but was still comparatively mild compared with the one and Ireland whistle big state bail outs a prolonged and deep procession, in the end, a bail out of vinyl itself by the European Union and the international monetary Fund.'},
#  {'SummaryProb': Decimal('0.0468'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('456.3'),
#   'nwords': 8,
#   'sid': '20170627060900bestoftoday.s0001.sentence.38',
#   'speakerId': 's0001',
#   'startTime': Decimal('454.08'),
#   'trans': 'Ten years on, perhaps a return to normality.'},
#  {'SummaryProb': Decimal('0.3678'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('471.36'),
#   'nwords': 58,
#   'sid': '20170627060900bestoftoday.s0001.sentence.39',
#   'speakerId': 's0001',
#   'startTime': Decimal('456.3'),
#   'trans': "One son about this at the allied Irish Bank, one of the big ones that was bailed up will today, this that shares in London, Bernard Bernie is Chief Executive of allied Irish banks have been at a return, in part, to private ownership, but you're scum, and I suspect he's unlikely to get all its money back."},
#  {'SummaryProb': Decimal('0.0129'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('472.85'),
#   'nwords': 2,
#   'sid': '20170627060900bestoftoday.s0001.sentence.40',
#   'speakerId': 's0001',
#   'startTime': Decimal('472.41'),
#   'trans': 'Good morning.'},
#  {'SummaryProb': Decimal('0.0345'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('479.22'),
#   'nwords': 22,
#   'sid': '20170627060900bestoftoday.s0001.sentence.41',
#   'speakerId': 's0001',
#   'startTime': Decimal('472.85'),
#   'trans': 'Well, NA today is a very important start of the process for the next phase of the government getting his money back.'},
#  {'SummaryProb': Decimal('0.0121'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': 485,
#   'nwords': 17,
#   'sid': '20170627060900bestoftoday.s0001.sentence.42',
#   'speakerId': 's0001',
#   'startTime': Decimal('479.25'),
#   'trans': 'In total, the government put in about twenty point eight billion Euros into, B and to date.'},
#  {'SummaryProb': Decimal('0.058'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('495.93'),
#   'nwords': 38,
#   'sid': '20170627060900bestoftoday.s0001.sentence.43',
#   'speakerId': 's0001',
#   'startTime': Decimal('485.38'),
#   'trans': "If you take capital repaid coupons paid and what they'll get from the the I.P.O. at this stage at about ten billion recovered at this stage it on about three quarters of a Bank, I sort of worried."},
#  {'SummaryProb': Decimal('0.091'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('498.17'),
#   'nwords': 15,
#   'sid': '20170627060900bestoftoday.s0001.sentence.44',
#   'speakerId': 's0001',
#   'startTime': Decimal('495.93'),
#   'trans': 'I might have done might have nine, but they might get it all back then.'},
#  {'SummaryProb': Decimal('0.1772'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('509.14'),
#   'nwords': 45,
#   'sid': '20170627060900bestoftoday.s0001.sentence.45',
#   'speakerId': 's0001',
#   'startTime': Decimal('498.55'),
#   'trans': "It's within touching distance of the stage, which is obviously a great position compared to where we started, and I was saying, it was ten years ago, and some people might have might have forgotten what happened, what did go wrong with the Irish banks."},
#  {'SummaryProb': Decimal('0.0136'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('512.1'),
#   'nwords': 9,
#   'sid': '20170627060900bestoftoday.s0001.sentence.46',
#   'speakerId': 's0001',
#   'startTime': Decimal('509.14'),
#   'trans': 'Why were they particularly badly affected by the crisis.'},
#  {'SummaryProb': Decimal('0.0937'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('531.98'),
#   'nwords': 47,
#   'sid': '20170627060900bestoftoday.s0001.sentence.47',
#   'speakerId': 's0001',
#   'startTime': Decimal('513.12'),
#   'trans': 'Well, not a small, open economy, the scale of the indebtedness and economy was quite high, we it with a very fast rising property market, we probably collectively became overly exposed to that property market and the banks were thirty victims and part of that process themselves.'},
#  {'SummaryProb': Decimal('0.2172'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('551.98'),
#   'nwords': 66,
#   'sid': '20170627060900bestoftoday.s0001.sentence.48',
#   'speakerId': 's0001',
#   'startTime': Decimal('531.98'),
#   'trans': "So huge exposure to property, and then a collapsing economy led to a very significant banking crisis, I think, in some cases it as much as three quarters of the loans advance what some of the banks with work were regarded as non performing I.E. not not like her to get the money, the level of non performing lon's was was very high, across the board."},
#  {'SummaryProb': Decimal('0.0378'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('566.89'),
#   'nwords': 47,
#   'sid': '20170627060900bestoftoday.s0001.sentence.49',
#   'speakerId': 's0001',
#   'startTime': Decimal('552.56'),
#   'trans': "And, you know, in case we ended up with thirty billion of NA Performing loans and have a balance sheet of about ninety billion after a structuring so huge, huge level of loans, we've reduced that by about twenty billion at this stage, and across the system."},
#  {'SummaryProb': Decimal('0.4519'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('594.05'),
#   'nwords': 101,
#   'sid': '20170627060900bestoftoday.s0001.sentence.50',
#   'speakerId': 's0001',
#   'startTime': Decimal('567.15'),
#   'trans': "You've seen similar level of reduction, so you're not getting through those non performing answers when one of the key elements of restructuring the banks, do you think that the banking system in Europe as alert at Smiths have we have, we did have this new Bank resolution regime, but just yesterday, we saw the Italian government telling taxpayer having to having to put perhaps up to seventeen billion Euros into bearing out to a telling banks, not quite what the Beijing was how it was meant to work helping until basins, or is it just another turn in the cycle."},
#  {'SummaryProb': Decimal('0.0371'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('601.73'),
#   'nwords': 24,
#   'sid': '20170627060900bestoftoday.s0001.sentence.51',
#   'speakerId': 's0001',
#   'startTime': Decimal('594.74'),
#   'trans': 'I mean, I think, for Ireland, we, we adopted a very sort of aggressive approach of trying to recognise the size of the problem.'},
#  {'SummaryProb': Decimal('0.033'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('610.16'),
#   'nwords': 37,
#   'sid': '20170627060900bestoftoday.s0001.sentence.52',
#   'speakerId': 's0001',
#   'startTime': Decimal('601.73'),
#   'trans': "Back in two thousand and ten thousand eleven and make sure we are dressed as I am, that's what we did in the heavy as well, you have to take it on, except how bad it is."},
#  {'SummaryProb': Decimal('0.0109'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('612.21'),
#   'nwords': 9,
#   'sid': '20170627060900bestoftoday.s0001.sentence.53',
#   'speakerId': 's0001',
#   'startTime': Decimal('610.16'),
#   'trans': 'And get through us, and then you can rebuild.'},
#  {'SummaryProb': Decimal('0.0135'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('614.75'),
#   'nwords': 12,
#   'sid': '20170627060900bestoftoday.s0001.sentence.54',
#   'speakerId': 's0001',
#   'startTime': Decimal('612.24'),
#   'trans': "I think some of the things they're playing out at the moment."},
#  {'SummaryProb': Decimal('0.0599'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('626.51'),
#   'nwords': 47,
#   'sid': '20170627060900bestoftoday.s0001.sentence.55',
#   'speakerId': 's0001',
#   'startTime': Decimal('614.79'),
#   'trans': 'Maybe suggest that not all these problems happen fully fully grappled with, but I think the new regimes that have been put in place a certain empowering the regulator is to have the Tools to do that it, how was see Irish economy doing as a whole.'},
#  {'SummaryProb': Decimal('0.0286'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('633.54'),
#   'nwords': 20,
#   'sid': '20170627060900bestoftoday.s0001.sentence.56',
#   'speakerId': 's0001',
#   'startTime': Decimal('626.56'),
#   'trans': "The moment the economy's doing well, you know, it's growth rates are about twice the European norms amateur young economy."},
#  {'SummaryProb': Decimal('0.0195'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('641.93'),
#   'nwords': 23,
#   'sid': '20170627060900bestoftoday.s0001.sentence.57',
#   'speakerId': 's0001',
#   'startTime': Decimal('633.54'),
#   'trans': 'So we have the youngest population, demographic, and Europe, which, which is obviously very puzzled and across the board, between Finder action vestment.'},
#  {'SummaryProb': Decimal('0.0024'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('643.32'),
#   'nwords': 5,
#   'sid': '20170627060900bestoftoday.s0001.sentence.58',
#   'speakerId': 's0001',
#   'startTime': Decimal('641.93'),
#   'trans': "I mean that's happened domestically."},
#  {'SummaryProb': Decimal('0.0338'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('656.07'),
#   'nwords': 43,
#   'sid': '20170627060900bestoftoday.s0001.sentence.59',
#   'speakerId': 's0001',
#   'startTime': Decimal('643.62'),
#   'trans': "There's plenty of growth, unemployment, stand below six point four per cent of this stage, having been about fifteen percent, four years ago, so it's quite a dynamic economy and doing quite well, but potentially quite exposed to any fall out from bricks."},
#  {'SummaryProb': Decimal('0.0308'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('666.72'),
#   'nwords': 32,
#   'sid': '20170627060900bestoftoday.s0001.sentence.60',
#   'speakerId': 's0001',
#   'startTime': Decimal('657.15'),
#   'trans': "Yet there's obviously a very close link between the Irish and U.K. academies, but the Irish economy is pretty broadly based at this stage and are very significant exposure into Europe itself."},
#  {'SummaryProb': Decimal('0.02'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('669.05'),
#   'nwords': 5,
#   'sid': '20170627060900bestoftoday.s0001.sentence.61',
#   'speakerId': 's0001',
#   'startTime': Decimal('667.04'),
#   'trans': 'So I think, Kenny breaks.'},
#  {'SummaryProb': Decimal('0.0087'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('674.7'),
#   'nwords': 20,
#   'sid': '20170627060900bestoftoday.s0001.sentence.62',
#   'speakerId': 's0001',
#   'startTime': Decimal('669.06'),
#   'trans': 'It is something we all watch very carefully the opportunities that exist into European contacts are very significant as well.'},
#  {'SummaryProb': Decimal('0.0114'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('676.05'),
#   'nwords': 4,
#   'sid': '20170627060900bestoftoday.s0001.sentence.63',
#   'speakerId': 's0001',
#   'startTime': Decimal('675.42'),
#   'trans': 'Thank you very much.'},
#  {'SummaryProb': Decimal('0.0294'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('678.7'),
#   'nwords': 8,
#   'sid': '20170627060900bestoftoday.s0001.sentence.64',
#   'speakerId': 's0001',
#   'startTime': Decimal('676.05'),
#   'trans': 'Bernard Byrne, Chief Executive of allied Irish banks.'},
#  {'SummaryProb': Decimal('0.0542'),
#   'classId': 'transcript',
#   'conv': '20170627060900bestoftoday',
#   'endTime': Decimal('686.82'),
#   'nwords': 28,
#   'sid': '20170627060900bestoftoday.s0001.sentence.65',
#   'speakerId': 's0001',
#   'startTime': Decimal('678.87'),
#   'trans': 'You can listen to more free content from the today programme Bank going to w. w. w. dot b. b. c. dot co dot U.K. forward slash today.'},
#  {'SummaryProb': Decimal('0.0452'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('22.54'),
#   'nwords': 36,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.1',
#   'speakerId': 's0001',
#   'startTime': Decimal('7.68'),
#   'trans': 'This is the B.B.C. for details of a complete range of programmes go to B.B.C. world service dot com forward slash, Hello, welcome to the latest global news compiled in the early hours of the morning.'},
#  {'SummaryProb': Decimal('0.6321'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('60.66'),
#   'nwords': 113,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.2',
#   'speakerId': 's0001',
#   'startTime': Decimal('22.57'),
#   'trans': "On Tuesday, the twenty seventh of June, I'm Ben planned with a selection of highlights from across B.B.C. world service news today coming up, the U.S. Supreme Court has handed a partial victory to President trump in the legal battle over his attempt to ban travellers from six Muslim majority countries and refugees, the very back at that cream or at the green here in the face of any record, of course, up and down the levels, they have decided that this is an unjust indiscriminate toy Muzz also in the podcast Mister trump as welcome the Indian Prime Minister, the rentrer Modi defence and economic co operation were high on the agenda."},
#  {'SummaryProb': Decimal('0.2524'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('79.68'),
#   'nwords': 58,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.3',
#   'speakerId': 's0001',
#   'startTime': Decimal('60.92'),
#   'trans': "But there are major issues dividing the two leaders, the British Prime Minister Theresa may has told E.U. citizens living in the U.K., that they can stay after breaks it, but the E.U. says her guarantees do not go far enough, and later, how much did you get last night sleep, the world's biggest study on the subject."},
#  {'SummaryProb': Decimal('0.1595'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('92.21'),
#   'nwords': 45,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.4',
#   'speakerId': 's0001',
#   'startTime': Decimal('79.68'),
#   'trans': "And what happens when we don't get enough of it, stay with me and stay awake to find out how a sleepy health correspondent Fergus Walsh got on when he took part, we Were allowed just four hours sleep, and then re did the tests."},
#  {'SummaryProb': Decimal('0.1003'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('112.23'),
#   'nwords': 46,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.5',
#   'speakerId': 's0001',
#   'startTime': Decimal('92.77'),
#   'trans': "Most of us performed worse in the morning, down the night before, but first to the United States, Donal oggie sharp is calling for a total and complete shut of Muslims entering the United a Jill our country's representatives Kenfig, what the hell is going on."},
#  {'SummaryProb': Decimal('0.0314'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('115.17'),
#   'nwords': 10,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.6',
#   'speakerId': 's0001',
#   'startTime': Decimal('112.46'),
#   'trans': 'It was a key proposal on the presidential campaign trail.'},
#  {'SummaryProb': Decimal('0.0381'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('120.95'),
#   'nwords': 17,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.7',
#   'speakerId': 's0001',
#   'startTime': Decimal('115.17'),
#   'trans': 'Last year, a travel ban stopping people from certain countries entering the U.S and since taking power.'},
#  {'SummaryProb': Decimal('0.0807'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('131.77'),
#   'nwords': 29,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.8',
#   'speakerId': 's0001',
#   'startTime': Decimal('121.11'),
#   'trans': "President trump continued to push for it, despite widespread protests on Monday, the U.S. Supreme Court agreed to allow parts of the President's controversial travel ban to take effect."},
#  {'SummaryProb': Decimal('0.0173'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('136.22'),
#   'nwords': 14,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.9',
#   'speakerId': 's0001',
#   'startTime': Decimal('131.81'),
#   'trans': 'For now, while it considers whether the policy should be upheld or struck down.'},
#  {'SummaryProb': Decimal('0.2794'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('158.65'),
#   'nwords': 66,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.10',
#   'speakerId': 's0001',
#   'startTime': Decimal('136.9'),
#   'trans': 'Just to remind you, President trump wants a ninety day ban stopping people from six Muslim majority countries travelling to the U.S.. he also wants to suspend the U.S refugee programme for one hundred and twenty days President trump called the Supreme Court ruling a clear victory and said, the travel ban would help protect the U.S Stephen Troy is from the U.S. immigrant rights group.'},
#  {'SummaryProb': Decimal('0.074'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('171.4'),
#   'nwords': 32,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.11',
#   'speakerId': 's0001',
#   'startTime': Decimal('158.82'),
#   'trans': "New York immigration coalition in the Supreme Court has played it could be that they're narrowing going through here, but also created this brand new legal definition, we think it's extremely proud."},
#  {'SummaryProb': Decimal('0.0676'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': 193,
#   'nwords': 52,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.12',
#   'speakerId': 's0001',
#   'startTime': Decimal('172.55'),
#   'trans': "Mark my words, there's some folks are out there, calling this victory and saying that this is, I think, President trance Executive, or we Do not share, because the very fact that the Supreme Court has a green tick in the feet, I'll be wrecker, of course, I've been down the levels."},
#  {'SummaryProb': Decimal('0.1614'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('211.15'),
#   'nwords': 60,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.13',
#   'speakerId': 's0001',
#   'startTime': 193,
#   'trans': 'They had their say, this is an unjust and discriminate toy Muzz I spoke to the bee b. sees Barbara, plus a chef in Washington and asked what the implications of the ruling would be the Supreme Court said it had decided to take on the case, too, did to determine whether this trap will ban was constitutional or not.'},
#  {'SummaryProb': Decimal('0.0127'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': 213,
#   'nwords': 8,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.14',
#   'speakerId': 's0001',
#   'startTime': Decimal('211.19'),
#   'trans': "That's only going to take place in October."},
#  {'SummaryProb': Decimal('0.0529'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('221.42'),
#   'nwords': 29,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.15',
#   'speakerId': 's0001',
#   'startTime': 213,
#   'trans': "So that's significant that it will review the Constitution, Allergy have travel in the meantime, it has said that the travel Bank and go into force, but only partially."},
#  {'SummaryProb': Decimal('0.0547'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('234.88'),
#   'nwords': 45,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.16',
#   'speakerId': 's0001',
#   'startTime': Decimal('221.63'),
#   'trans': 'That means it can be enforced against travellers who do not have any strong a significant ties to the United States, those who do such as people who want to visit family members, students who were accepted at universities, people with with a business agenda.'},
#  {'SummaryProb': Decimal('0.0197'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('236.56'),
#   'nwords': 5,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.17',
#   'speakerId': 's0001',
#   'startTime': Decimal('235.12'),
#   'trans': 'Those will not be affected.'},
#  {'SummaryProb': Decimal('0.0922'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('252.32'),
#   'nwords': 44,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.18',
#   'speakerId': 's0001',
#   'startTime': Decimal('236.56'),
#   'trans': "So it's a partial enforcement of the band with the NA actual looking at whether it's constitutional not coming up in the autumn, so this is only a partial relaxation on an interim basis, then, yes, that's right end, it's going to be implemented."},
#  {'SummaryProb': Decimal('0.0802'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('269.53'),
#   'nwords': 54,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.19',
#   'speakerId': 's0001',
#   'startTime': Decimal('252.32'),
#   'trans': 'We understand very soon, before the Supreme Court ruling, the administration had said he could go into effect within seventy two hours since the ruling, the Department of homeland security is Command said yes, it will be done professionally with clear notice in NA co-ordination with travel partners in the industry, and so on.'},
#  {'SummaryProb': Decimal('0.0351'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('272.74'),
#   'nwords': 17,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.20',
#   'speakerId': 's0001',
#   'startTime': Decimal('269.53'),
#   'trans': 'I mean, I think they want to be quite careful to avoid the chaos that we sell.'},
#  {'SummaryProb': Decimal('0.0115'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('274.9'),
#   'nwords': 8,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.21',
#   'speakerId': 's0001',
#   'startTime': Decimal('272.74'),
#   'trans': 'When the ban was first announced in January.'},
#  {'SummaryProb': Decimal('0.0302'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('282.69'),
#   'nwords': 30,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.22',
#   'speakerId': 's0001',
#   'startTime': Decimal('274.9'),
#   'trans': "Since then, it has been revised and made clear that it doesn't apply to people with green cut a green card holder or a room for residents, and so on."},
#  {'SummaryProb': Decimal('0.0166'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('291.36'),
#   'nwords': 26,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.23',
#   'speakerId': 's0001',
#   'startTime': Decimal('282.68'),
#   'trans': "So it has, it has become much, much less chaotic, but they don't want any repeat of that it will be an interim and partial zing."},
#  {'SummaryProb': Decimal('0.0475'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('300.93'),
#   'nwords': 28,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.24',
#   'speakerId': 's0001',
#   'startTime': Decimal('291.39'),
#   'trans': 'But, having said that, the NA band itself involves three months for the administration to look at vetting procedures to determine whether they should be strengthened in House.'},
#  {'SummaryProb': Decimal('0.0202'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('305.19'),
#   'nwords': 16,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.25',
#   'speakerId': 's0001',
#   'startTime': Decimal('301.86'),
#   'trans': 'By the time you actually get to October for the Supreme Court to look at it.'},
#  {'SummaryProb': Decimal('0.0093'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('305.79'),
#   'nwords': 2,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.26',
#   'speakerId': 's0001',
#   'startTime': Decimal('305.19'),
#   'trans': "It's possible."},
#  {'SummaryProb': Decimal('0.0499'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('308.81'),
#   'nwords': 13,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.27',
#   'speakerId': 's0001',
#   'startTime': Decimal('305.79'),
#   'trans': 'The whole thing they have been done and just briefly Barbara what reactions.'},
#  {'SummaryProb': Decimal('0.7187'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('367.84'),
#   'nwords': 165,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.28',
#   'speakerId': 's0001',
#   'startTime': Decimal('308.81'),
#   'trans': "They've been to this ruling reaction from the President, declaring victory for national security reaction from some of the civil rights activists have been challenging it, saying the Supreme Court, now has a chance to prominently strike it down reaction from some Muslim American activists who have said that the Supreme Court ruling ignores the Islamophobic origins of the policy and emboldened Slammer folds in the trump administration Barbara plus usher in Washington, Josh Blackman is associate Professor of law at the South Texas College of law In Houston, is also a specialist in constitutional law on the Supreme Court ten francs asked him what he made of the ruling, the first thing to stress is that there was no dissent, and none of the justices even some of the more liberal churches raised any objection to this Roy, the second thing to stress is that this NA Rukwa decision cadre fires, the Executive order Andrew the Executive order people with certain close family relationships."},
#  {'SummaryProb': Decimal('0.1001'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('391.92'),
#   'nwords': 64,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.29',
#   'speakerId': 's0001',
#   'startTime': Decimal('368.13'),
#   'trans': "People employment relationships, the United States and people with a scholastic wreck relations, NA it would have been allowed to apply for a Weaver from the travel bear is sure a hardship, it would've been had made it, what the Supreme Court did hear it was a bed, we are going to allow anyone who meets his categories into seeds without proving a hardship."},
#  {'SummaryProb': Decimal('0.0157'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('394.32'),
#   'nwords': 8,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.30',
#   'speakerId': 's0001',
#   'startTime': Decimal('392.39'),
#   'trans': 'So the sorts of people, their present trouble.'},
#  {'SummaryProb': Decimal('0.0826'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': 408,
#   'nwords': 44,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.31',
#   'speakerId': 's0001',
#   'startTime': Decimal('394.34'),
#   'trans': "Why did to keep would be kept out and the sorts of people present trump what it would, and it will be limited in many respects this screw Court's decision reaffirms Executive order eight, it was striking, wasn't it, but it was nine zero."},
#  {'SummaryProb': Decimal('0.0814'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('416.74'),
#   'nwords': 17,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.32',
#   'speakerId': 's0001',
#   'startTime': Decimal('408.57'),
#   'trans': "What do you think this tells us about how the Supreme Court views, the President's right issue."},
#  {'SummaryProb': Decimal('0.0284'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('420.28'),
#   'nwords': 11,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.33',
#   'speakerId': 's0001',
#   'startTime': Decimal('416.87'),
#   'trans': 'The these sorts of Ritz when it comes to national security.'},
#  {'SummaryProb': Decimal('0.0588'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('438.78'),
#   'nwords': 51,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.34',
#   'speakerId': 's0001',
#   'startTime': Decimal('420.89'),
#   'trans': "I think the thing to stress is that President trump has lost and Court after Court after Court judge after a judge ruled against him here, no single One of the justices seemed offended by the policy, we didn't have this crew diving into President trumps Twitter account would never regret."},
#  {'SummaryProb': Decimal('0.0052'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('440.31'),
#   'nwords': 6,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.35',
#   'speakerId': 's0001',
#   'startTime': Decimal('438.82'),
#   'trans': 'Looking at his camp camping statements.'},
#  {'SummaryProb': Decimal('0.0232'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('442.89'),
#   'nwords': 10,
#   'sid': '20170626231400globalnewspodcast.s0001.sentence.36',
#   'speakerId': 's0001',
#   'startTime': Decimal('440.51'),
#   'trans': 'I think this is a signal to the law courts.'},
#  {'SummaryProb': Decimal('0.011'),
#   'classId': 'transcript',
#   'conv': '20170626231400globalnewspodcast',
#   'endTime': Decimal('444.01'),
#   'nwords': 4,
# ...
#  {'SummaryProb': Decimal('0.9654'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('192.54'),
#   'nwords': 202,
#   'sid': '20170626140000newshour.s0001.sentence.13',
#   'speakerId': 's0001',
#   'startTime': Decimal('126.57'),
#   'trans': "In accordance with our shared objectives for strengthening and enhancing a precious Union of the deal raises many questions, not least of which is its potential impact on the peace agreement in northern Ireland and Damian green is the U.K.'s first Minister of state effectively, the Deputy Prime Minister, so does this deal, mean that the government is abandoning the good Friday agreement which has kept the peace in northern Ireland for almost twenty years, we're not, and it's perfectly clear that this is an agreement between the conservative party and the democratic unionist party, and in the conservative party's full title has traditionally been the conservative and unionist party, we are always unionist wheat, we remain as unionist, as NA we ever have been, And I have been throughout the time when we've been able to deal with devolved institutions, but what we say is that absolutely, we continue to be committed to the notion of consent in northern Ireland, this is for the people of northern Ireland to decide on your own government structure on our political correspondent Rob Watson joins me now from Westminster and Rob the main points of this agreement, I think money is key, isn't it."},
#  {'SummaryProb': Decimal('0.0689'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('205.87'),
#   'nwords': 45,
#   'sid': '20170626140000newshour.s0001.sentence.14',
#   'speakerId': 's0001',
#   'startTime': Decimal('192.96'),
#   'trans': 'By and large, James, yes, it is all about money at basically in the nutshell, in return for the d. u. ten M.P.s, as you were saying, for their support on key votes in northern Ireland so things like the European Union bracts the budget.'},
#  {'SummaryProb': Decimal('0.03'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('215.03'),
#   'nwords': 29,
#   'sid': '20170626140000newshour.s0001.sentence.15',
#   'speakerId': 's0001',
#   'startTime': Decimal('205.87'),
#   'trans': 'Northern Ireland gets an extra one point three billion dollars of spanning over the next two years, which actually James works out nearly a thousand dollars for every voter.'},
#  {'SummaryProb': Decimal('0.1285'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('228.57'),
#   'nwords': 47,
#   'sid': '20170626140000newshour.s0001.sentence.16',
#   'speakerId': 's0001',
#   'startTime': Decimal('215.03'),
#   'trans': "No wonder those do you pee politicians were smiling, there is a bit more to it than that, in that the D.U.P. will also get some input on Brax negotiations, which is important because, while the D.U.P. will be only part in northern Ireland to back Brecht's."},
#  {'SummaryProb': Decimal('0.0092'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('231.47'),
#   'nwords': 10,
#   'sid': '20170626140000newshour.s0001.sentence.17',
#   'speakerId': 's0001',
#   'startTime': Decimal('228.61'),
#   'trans': "They NA don't want a hardboard with the Irish Republic."},
#  {'SummaryProb': Decimal('0.0852'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('242.88'),
#   'nwords': 38,
#   'sid': '20170626140000newshour.s0001.sentence.18',
#   'speakerId': 's0001',
#   'startTime': Decimal('231.97'),
#   'trans': "So, to what extent does this shore up Theresa may's government has she enters into these negotiations on breakfast, one, of course, on one level, it doesn't mean she now has a majority again or beer pretty small."},
#  {'SummaryProb': Decimal('0.1274'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('262.72'),
#   'nwords': 58,
#   'sid': '20170626140000newshour.s0001.sentence.19',
#   'speakerId': 's0001',
#   'startTime': Decimal('242.88'),
#   'trans': "I mean, on the Other hand, the big picture is that she is still very much a weakened leader of a weakened government facing the biggest peace time challenge with Brecht's since nineteen forty five against a backdrop of a weakening economy, a resurgent opposition labour party and the usual divisions within her own conservative ranks about Europe."},
#  {'SummaryProb': Decimal('0.0147'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('265.81'),
#   'nwords': 8,
#   'sid': '20170626140000newshour.s0001.sentence.20',
#   'speakerId': 's0001',
#   'startTime': Decimal('262.72'),
#   'trans': 'So I think, basically her position remains precarious.'},
#  {'SummaryProb': Decimal('0.0415'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('272.22'),
#   'nwords': 24,
#   'sid': '20170626140000newshour.s0001.sentence.21',
#   'speakerId': 's0001',
#   'startTime': Decimal('265.86'),
#   'trans': 'What about potential divisions in northern Ireland there plenty of people have been warning about the impact this could have on the peace process.'},
#  {'SummaryProb': Decimal('0.1737'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('290.72'),
#   'nwords': 60,
#   'sid': '20170626140000newshour.s0001.sentence.22',
#   'speakerId': 's0001',
#   'startTime': Decimal('272.22'),
#   'trans': "They're not least of whom was the U.K.'s former conservative Prime Minister, Sir John major we have seen in northern Ireland for very many years that events always don't unwind as you expect them to unwind here with the peace process, we need to be prepared for the expected, we need to hope for the best prepare for the worse."},
#  {'SummaryProb': Decimal('0.0846'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('304.81'),
#   'nwords': 46,
#   'sid': '20170626140000newshour.s0001.sentence.23',
#   'speakerId': 's0001',
#   'startTime': Decimal('291.53'),
#   'trans': "The last thing any of what he wishes to see his one or other of the Community's so aggrieved that the hard men who are still, they are lurking in the corners of the communities decide that they wish to return to some form of violence."},
#  {'SummaryProb': Decimal('0.1424'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('322.18'),
#   'nwords': 45,
#   'sid': '20170626140000newshour.s0001.sentence.24',
#   'speakerId': 's0001',
#   'startTime': Decimal('305.1'),
#   'trans': "We really need to do everything we conceivably can to make sure that that doesn't happen, and that does require an impartial U.K. government, because this deal robbers come in a pretty key week for the whole power sharing agreement in northern Ireland, hasn't it."},
#  {'SummaryProb': Decimal('0.0072'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('323.22'),
#   'nwords': 6,
#   'sid': '20170626140000newshour.s0001.sentence.25',
#   'speakerId': 's0001',
#   'startTime': Decimal('322.18'),
#   'trans': 'I mean, what sort of impact.'},
#  {'SummaryProb': Decimal('0.0119'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('324.89'),
#   'nwords': 6,
#   'sid': '20170626140000newshour.s0001.sentence.26',
#   'speakerId': 's0001',
#   'startTime': Decimal('323.25'),
#   'trans': 'Might it have on those negotiations.'},
#  {'SummaryProb': Decimal('0.0615'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('340.92'),
#   'nwords': 57,
#   'sid': '20170626140000newshour.s0001.sentence.27',
#   'speakerId': 's0001',
#   'startTime': Decimal('325.01'),
#   'trans': "Well, Look on the band side, it doesn't look good in terms of this is a government, which is trying to be seen as neutral and honest broker in northern Ireland, and it's now being kept in power by one of the main northern Irish parties and many Conservatives, not just John major or worried about this."},
#  {'SummaryProb': Decimal('0.026'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('344.67'),
#   'nwords': 13,
#   'sid': '20170626140000newshour.s0001.sentence.28',
#   'speakerId': 's0001',
#   'startTime': Decimal('341.58'),
#   'trans': "On the other hand, I've heard it argued that the offer of hole."},
#  {'SummaryProb': Decimal('0.0159'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('351.58'),
#   'nwords': 23,
#   'sid': '20170626140000newshour.s0001.sentence.29',
#   'speakerId': 's0001',
#   'startTime': Decimal('344.67'),
#   'trans': 'This extra money for the North might in a funny way helped to get those power sharing negotiations in the North going again.'},
#  {'SummaryProb': Decimal('0.0013'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('353.18'),
#   'nwords': 4,
#   'sid': '20170626140000newshour.s0001.sentence.30',
#   'speakerId': 's0001',
#   'startTime': Decimal('351.58'),
#   'trans': 'Between Protestants and Catholics.'},
#  {'SummaryProb': Decimal('0.013'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('356.76'),
#   'nwords': 14,
#   'sid': '20170626140000newshour.s0001.sentence.31',
#   'speakerId': 's0001',
#   'startTime': Decimal('353.18'),
#   'trans': 'Now they know they have all this lovely nice pile of money to spend.'},
#  {'SummaryProb': Decimal('0.0287'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('365.84'),
#   'nwords': 32,
#   'sid': '20170626140000newshour.s0001.sentence.32',
#   'speakerId': 's0001',
#   'startTime': Decimal('356.76'),
#   'trans': 'So, I mean, how much a threats peace process it, it obviously depends in part on how the agreement works out and really, in some ways, on how much of a problem.'},
#  {'SummaryProb': Decimal('0.0181'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('371.05'),
#   'nwords': 16,
#   'sid': '20170626140000newshour.s0001.sentence.33',
#   'speakerId': 's0001',
#   'startTime': Decimal('365.84'),
#   'trans': 'The mainly Catholic pro NA United Ireland Sinn Fein party seek to make of it well.'},
#  {'SummaryProb': Decimal('0.0675'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('376.47'),
#   'nwords': 25,
#   'sid': '20170626140000newshour.s0001.sentence.34',
#   'speakerId': 's0001',
#   'startTime': Decimal('371.08'),
#   'trans': 'Northern Ireland might have this pile of money, but there are other parts of the U.K., putting their hands up and saying, what about us.'},
#  {'SummaryProb': Decimal('0.0554'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('388.99'),
#   'nwords': 46,
#   'sid': '20170626140000newshour.s0001.sentence.35',
#   'speakerId': 's0001',
#   'startTime': Decimal('376.94'),
#   'trans': "You could have predicted this one couldn't eat that honestly, I think it was within less than a couple of minutes after this deal was announced that the, the head of the Welsh government, a labour politician was made, it was her Ang on a minute."},
#  {'SummaryProb': Decimal('0.0042'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('389.86'),
#   'nwords': 3,
#   'sid': '20170626140000newshour.s0001.sentence.36',
#   'speakerId': 's0001',
#   'startTime': Decimal('388.99'),
#   'trans': 'What about us.'},
#  {'SummaryProb': Decimal('0.02'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('402.23'),
#   'nwords': 33,
#   'sid': '20170626140000newshour.s0001.sentence.37',
#   'speakerId': 's0001',
#   'startTime': Decimal('390.24'),
#   'trans': "There were similar noises from the from the Scottish government and, of course, you've got lots of anti Austerity campaigners in favour of more public spending all sorts of our saying, come on."},
#  {'SummaryProb': Decimal('0.0193'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('408.47'),
#   'nwords': 21,
#   'sid': '20170626140000newshour.s0001.sentence.38',
#   'speakerId': 's0001',
#   'startTime': Decimal('402.26'),
#   'trans': 'What about us, not to mention the huge political price that Teresa mayors facing, with people saying, hang on a minute.'},
#  {'SummaryProb': Decimal('0.0049'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('414.14'),
#   'nwords': 16,
#   'sid': '20170626140000newshour.s0001.sentence.39',
#   'speakerId': 's0001',
#   'startTime': Decimal('408.78'),
#   'trans': 'Basically, how much does it cost to keep Teresa may empower well about one billion Pounds.'},
#  {'SummaryProb': Decimal('0.0068'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('416.13'),
#   'nwords': 5,
#   'sid': '20170626140000newshour.s0001.sentence.40',
#   'speakerId': 's0001',
#   'startTime': Decimal('414.14'),
#   'trans': 'One point three billion dollars.'},
#  {'SummaryProb': Decimal('0.0158'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('421.61'),
#   'nwords': 22,
#   'sid': '20170626140000newshour.s0001.sentence.41',
#   'speakerId': 's0001',
#   'startTime': Decimal('416.14'),
#   'trans': "So there's no doubt that this deal with the D.U.P., as has come at a price jamiah in more ways than one."},
#  {'SummaryProb': Decimal('0.0212'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('422.98'),
#   'nwords': 4,
#   'sid': '20170626140000newshour.s0001.sentence.42',
#   'speakerId': 's0001',
#   'startTime': Decimal('422.06'),
#   'trans': 'Rob thanks very much.'},
#  {'SummaryProb': Decimal('0.1907'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('444.17'),
#   'nwords': 44,
#   'sid': '20170626140000newshour.s0001.sentence.43',
#   'speakerId': 's0001',
#   'startTime': Decimal('423.12'),
#   'trans': "Rob Watson, on the line from Westminster India's Prime Minister, in the end, remote, he will become the latest world leader to try and strike up a good personal relationship with Donald trump when the two men meet in the white House later today."},
#  {'SummaryProb': Decimal('0.1179'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('453.59'),
#   'nwords': 30,
#   'sid': '20170626140000newshour.s0001.sentence.44',
#   'speakerId': 's0001',
#   'startTime': Decimal('444.29'),
#   'trans': "It will be their first face to face meeting, although the two leaders with a combined Twitter following of around sixty four million, I've already tweeted pleasantries to each other."},
#  {'SummaryProb': Decimal('0.2405'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('466.33'),
#   'nwords': 37,
#   'sid': '20170626140000newshour.s0001.sentence.45',
#   'speakerId': 's0001',
#   'startTime': Decimal('453.59'),
#   'trans': 'President trump calling Mister Modi a true friend, but beneath the chatty one hundred and forty characters surface tensions have developed between India and the United States in the trump era Hassan joined the reports from Delhi.'},
#  {'SummaryProb': Decimal('0.0049'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('473.74'),
#   'nwords': 3,
#   'sid': '20170626140000newshour.s0001.sentence.46',
#   'speakerId': 's0001',
#   'startTime': Decimal('473.24'),
#   'trans': 'What are you.'},
#  {'SummaryProb': Decimal('0.1466'),
#   'classId': 'transcript',
#   'conv': '20170626140000newshour',
#   'endTime': Decimal('489.07'),
#   'nwords': 31,
#   'sid': '20170626140000newshour.s0001.sentence.47',
#   'speakerId': 's0001',
#   'startTime': Decimal('473.74'),
#   'trans': 'All right, Minister, no two years ago, this was the rock star like welcome for marinda more the in the United States has arrived for a public meeting at silicon daddy.'},
#  ...]

# %%
#for May 1st week
cols = list(speakerInfo0[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo0):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
#df0 is the dataFrame of May 1st week
df0 = pd.DataFrame(rows, index = indices, columns = cols)
df0.convert_objects(convert_numeric=True)
#clean df0
del df0['classId']
del df0['conv']
del df0['sid']
del df0['SummaryProb']
del df0['trans']

#calculate in sentence level the average time for different speakers speak out a word
df0['time']=df0['endTime']-df0['startTime']
df0['average_time']=df0['time']/df0['nwords']
df0=df0.convert_objects(convert_numeric=True)
#find out how many different speakers
#df0['speakerId'].value_counts()
#df0.dtypes


#for May 2nd week
cols = list(speakerInfo1[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo1):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
#df1 is the dataFrame of May 2nd week
df1 = pd.DataFrame(rows, index = indices, columns = cols)
df1 = df1.convert_objects(convert_numeric=True)

#clean df1
del df1['classId']
del df1['conv']
del df1['sid']
del df1['SummaryProb']
del df1['trans']

#calculate in sentence level the average time for different speakers speak out a word
df1['time']=df1['endTime']-df1['startTime']
df1['average_time']=df1['time']/df1['nwords']


#for May 3rd week
cols = list(speakerInfo2[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo2):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
    
#df2 is the dataFrame of May 3rd week
df2 = pd.DataFrame(rows, index = indices, columns = cols)
df2=df2.convert_objects(convert_numeric=True)
#clean df2
del df2['classId']
del df2['conv']
del df2['sid']
del df2['SummaryProb']
del df2['trans']

#calculate in sentence level the average time for different speakers speak out a word
df2['time']=df2['endTime']-df2['startTime']
df2['average_time']=df2['time']/df2['nwords']
#find out how many different speakers
#df2['speakerId'].value_counts()



#for May 4th week
cols = list(speakerInfo3[0].keys())
rows = []
indices = []
for index, d in enumerate(speakerInfo3):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
    
#df3 is the dataFrame of May 4th week
df3 = pd.DataFrame(rows, index = indices, columns = cols)
df3=df3.convert_objects(convert_numeric=True)
#clean df3
del df3['classId']
del df3['conv']
del df3['sid']
del df3['SummaryProb']
del df3['trans']

#calculate in sentence level the average time for different speakers speak out a word
df3['time']=df3['endTime']-df3['startTime']
df3['average_time']=df3['time']/df3['nwords']
#find out how many different speakers
#df3['speakerId'].value_counts()


#dataFrame on April 1st week
data0=df0['average_time'].groupby(df0['speakerId']).sum()/df0['speakerId'].value_counts()
df_data0 = pd.DataFrame(data0,columns=['speed'])
df_data0.reset_index(level=0, inplace=True)
df_data0['date']='201706_1st'

#dataFrame on April 2nd week
data1=df1['average_time'].groupby(df1['speakerId']).sum()/df1['speakerId'].value_counts()
df_data1 = pd.DataFrame(data1,columns=['speed'])
df_data1.reset_index(level=0, inplace=True)
df_data1['date']='201706_2nd'

#dataFrame on April 3rd week
data2=df2['average_time'].groupby(df2['speakerId']).sum()/df2['speakerId'].value_counts()
df_data2 = pd.DataFrame(data2,columns=['speed'])
df_data2.reset_index(level=0, inplace=True)
df_data2['date']='201706_3rd'

#dataFrame on April 4th week
data3=df3['average_time'].groupby(df3['speakerId']).sum()/df3['speakerId'].value_counts()
df_data3 = pd.DataFrame(data3,columns=['speed'])
df_data3.reset_index(level=0, inplace=True)
df_data3['date']='201706_4th'
#merge these three dataFrames into one dataFrame
a = np.array(df_data0)
b = np.array(df_data1)
c = np.array(df_data2)
d = np.array(df_data3)
df_total_june=np.vstack ((a,b,c,d))
df_total_june=pd.DataFrame(df_total_june,columns=['speakerId','speed','date'])

df_total_june = df_total_june.convert_objects(convert_numeric=True)
df_total_june

#df_data1
# Out:
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   del sys.path[0]
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:69: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:98: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/sunyiwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:144: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   speakerId     speed        date
# 0     s0001  0.335133  201706_1st
# 1     s0001  0.327997  201706_2nd
# 2     s0001  0.337846  201706_3rd
# 3     s0001  0.337938  201706_4th

# %%
print('April:',df_total_april['speed'].mean(),'May:',df_total_may['speed'].mean(),'June:',df_total_june['speed'].mean())
# Out:
# April: 0.34349344309514696 May: 0.337811009055494 June: 0.3347286059076185

# %%
print ('The row and column of df0 is',df0.shape,'. The size of df0 is',df0.size)
print ('The row and column of df1 is',df1.shape,'. The size of df1 is',df1.size)
print ('The row and column of df2 is',df2.shape,'. The size of df2 is',df2.size)
print ('The row and column of df_total is',df_total.shape,'. The size of df_total is',df_total.size)
# Out:
# The row and column of df0 is (9593, 6) . The size of df0 is 57558
# The row and column of df1 is (9743, 6) . The size of df1 is 58458
# The row and column of df2 is (9777, 6) . The size of df2 is 58662
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a0d14a0bc8a4> in <module>()
#       2 print ('The row and column of df1 is',df1.shape,'. The size of df1 is',df1.size)
#       3 print ('The row and column of df2 is',df2.shape,'. The size of df2 is',df2.size)
# ----> 4 print ('The row and column of df_total is',df_total.shape,'. The size of df_total is',df_total.size)
#       5
#
# NameError: name 'df_total' is not defined

# %% [markdown]
# The variables and structure of each dataFrame.

# %%
#df0
print ('The variables of df0 is',df0.columns)
df0.head()

# %%
#df1
print ('The variables of df1 is',df1.columns)
df1.head()

# %%
#df2
print ('The variables of df2 is',df2.columns)
df2.head()

# %%
#df_total
print ('The variables of df_total is',df_total.columns)
df_total.head()

# %% [markdown]
# 3.What fields and data types are present?

# %%
print('The max in average time of df0 is',df0['average_time'].max(),'The min in average time of df0 is',df0['average_time'].min())
print('The max in average time of df1 is',df1['average_time'].max(),'The min in average time of df1 is',df1['average_time'].min())
print('The max in average time of df2 is',df2['average_time'].max(),'The min in average time of df2 is',df2['average_time'].min())
print('The max in speed of df_total is',df_total['speed'].max(),'The min in speed of df_total is',df_total['speed'].min())

# %%
print('The data types in df0 are',df0.dtypes)
print('The data types in df1 are',df1.dtypes)
print('The data types in df2 are',df2.dtypes)
print('The data types in df_total are',df_total.dtypes)

# %% [markdown]
# 4.Links between this data and other data.

# %% [markdown]
# There are three datasets in "Monitoring BBC podcasts" as mentioned before, but there is no foreign keys between them.
# As for the dataFrame df0, df1, df2 and df_total. The unique ids are"date" and "speakerId" for all of them and the foreign keys are also "date" and "speakerId".

# %% [markdown]
# 5.Summary statistics about the data.

# %%
print(df_total['speakerId'].value_counts())
print(df_total['date'].value_counts())
print(df_total['speed'].mean())

# %% [markdown]
# We can find there are 10 persons in this data. The time range is from 20160622 to 20160624. The average speed is 0.33287033393343396 word/second.

# %% [markdown]
# 6.How does the data relate to the questions that the data owner has discussed with you?
#
# Actually, there is no compulsive problem to be solved, and in this assignment, I want to discuss the relation between speaking speed, speakerId as well as different dates, even diffrent events. So I get the data about "speakerId", "speed" and "date".

# %% [markdown]
# Now we get a new dataFrame which shows the data about different speakers' speaking speed on June 22nd, 23rd, and 24th.

# %% [markdown]
# # Explore

# %% [markdown]
# Next step, we can try to generate some charts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Firstly, I draw a chart which nearly contains all information in the df_total.
#
# The different colors bars represent different speakers, and the x-axis shows different dates and the y-axis shows the value of speed(the higher the value, the slower the speed).
#
# So in this picture we can find there are 6 speakers on June 22nd and the fastest one is s0002 and the slowest one is s0006, it's over 0.4 second/word. On June 23rd there are 10 speakers and the fastest one is s0007, it's smaller than 0.3 second/word and the slowest one is s0008, it's also over 0.4 second/word. On June 24th, there are 8 speakers and the fastest one is also s0007, the speed is also faster than 0.3 second/word and the slowest one is s0006 and the speed is close to 0.33 second/word.
# Most speakers' speaking speed are slower than 0.30 word/second and the fastest speaker is s0007 and his speed is faster than 0.30 word/second.

# %%
fig, ax = plt.subplots(figsize=(10,7.5))
sns.set(style='whitegrid', rc={"grid.linewidth": 0.5})
sns.set_context( font_scale=1.5)
chart1=sns.barplot(x='date',y='speed',hue='speakerId',data=df_total,ci=0)

# %% [markdown]
# Secondly, I draw a box chart. It shows the median values and means and some "abnormal value"(Here I'm not sure that is it abnormal or not). From this chart through analyzing the median and mean we can found on June 23rd, the speed is slower than the speed on June 22nd and June 24th.

# %%
chart2=sns.boxplot(x=df_total['date'],y=df_total['speed'],showmeans=True)

# %% [markdown]
# Thirdly, I draw a distribution diagram which shows how speeds of s0001-s0006(because s0001-s0006 appeared in all three days.) distribute in these three days.
#
# From this chart, we can find that the range of speeds of s0001 is the smallest and the range of speeds of s0006 is the largest. As for the range of s0003, s0004 and s0005 is relatively moderate and s0002 is a little large.

# %%
fig, ax = plt.subplots(figsize=(10,7.5))
sns.set(style='whitegrid', rc={"grid.linewidth": 0.5})
sns.set_context( font_scale=1.5) 
chart3 = sns.distplot(df_total[df_total['speakerId']=='s0001']['speed'],label='s0001')
chart3 = sns.distplot(df_total[df_total['speakerId']=='s0002']['speed'],label='s0002')
chart3 = sns.distplot(df_total[df_total['speakerId']=='s0003']['speed'],label='s0003')
chart3 = sns.distplot(df_total[df_total['speakerId']=='s0004']['speed'],label='s0004')
chart3 = sns.distplot(df_total[df_total['speakerId']=='s0005']['speed'],label='s0005')
chart3 = sns.distplot(df_total[df_total['speakerId']=='s0006']['speed'],label='s0006')
chart3.legend()

# %% [markdown]
# Next I draw a bar chart. The different colors bars represent different dates, and the x-axis shows different speakers and the y-axis shows the value of speed(the higher the value, the slower the speed).
#
# From this chart, we can find that most speakers(s0001, s0002, s0003, s0004, s0005, s0007) spoke slowly on June 23rd. s0006 and s0008 speak faster on June 23rd.

# %%
fig, ax = plt.subplots(figsize=(10,7.5))
sns.set(style='whitegrid', rc={"grid.linewidth": 0.5})
sns.set_context( font_scale=1.5)
chart4=sns.barplot(x='speakerId',y='speed',hue='date',data=df_total,ci=0)

# %% [markdown]
# The relation between date and speed is on June 23rd, the speaking speed is slower than on the other two days. And the relation between speaker number and speed is the more the speaker, the slower the speed. From chart1 and chart2 we can find that on 23rd there are 10 people and on the 24th there are 8 people as well as on the 22nd there are only 6 people. And the speed on 23rd is slower than that on 24th and the speed on 24th is slower than that on 22nd.
#
# As for the trend, I think maybe on some events or some important day, the speaker will speak slowly. I think the more important relation is the date and speed. Maybe when you find the speaker speak slowly, there are something important thing happened on that day.

# %% [markdown]
# # Reflect and Hypothesise

# %% [markdown]
# I find that most speakers' speaking speed are between 0.30-0.35(from chart 1) and totally speakers speak slower on June 23rd(from chart2). From chart3 and chart4 I find that most speakers speak slower on June 23rd and most of them have little speed ranges. From chart1 and chart2 it also can be found that the fewer the people the faster the speed. And the date data can be related to an event date in real life, it is "Brexit vote". It is an importent event in real life.
#
# So the hypothesise1 is when there are some important thing happening, the speakers will speak slowly. From chart2 it can be found the speakers spoke slower on June 23rd and spoke faster on June 22nd and 24th. I think this is because the speakers are more cautious on special days and they need to ensure they read every word  correct and maybe they seldom broadcast such content so they are not familiar with that.
#
# The hypothesise2 is the more speakers the slower the speed. From chart1 and chart2 we can find that on 23rd there are 10 people and on the 24th there are 8 people as well as on the 22nd there are only 6 people. And the speed on 23rd is slower than that on 24th and the speed on 24th is slower than that on 22nd. The hypothesise3 is that BBC likes using the speaker who has steady speaking speed. From chart3 and chart4 we can find that most of the speakers have a steady speaking speed. So combined hypothesise2 and hypothesise3, I think the reason is the speaker who has a steady speaking speed represent who has skillful broadcast skills so this kind of speakers have more opportunities and they can work almost everyday and the work experience also make them be familiar with their job. So when the new speakers join in the speaking speed will slow down.
#
# The hypothesise4 is that when some important thing appear, there will be more speakers. This also can be found from chart1. I think that is because there are more content need to be reported, so they need more people to finish it on time or report more information.
