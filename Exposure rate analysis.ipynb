# %% [markdown]
# I used the BBC transcript to analyse. My purpose is that exploring the 2017 General Election, and discovering the hot news topics in April, May, June 2017.
#
# ①. What is the general type of the data?
#
# Online json
#
# ②. How large and complex is it?
#
# I have analysed the words data in April, May, June 2017. There are more than 4.5 million original words data. The complex part is that how I can get the online raw json data efficiently. Finally, I wrote a web spider to grab the raw data.
#
# ③. What fields and data types are present?
#
# string: wordId
# Fload: wordStartTime
# Fload: wordEndtTime
# Fload: wordConfidence
# String: date
#
# ④. Links between this data and other data?
#
# Foreign keys
#
# ⑤. Summary statistics about the data?
#
# I obtained the raw data from online json. There are more than 4.5 million rows in total. I used two kinds of stop words package to filtrate the ineffective words data, and then using the natural language processing function "nltk" to choose nounal words. Finally, I got around 100 thousand effective words to analyse. I counted and ranked the hot news words for each month.
#
# ⑥. How does the data relate to the questions that the data owner has discussed with you?
#
# On this stage, It is the basic natural language processing and analyses. In the next stage, based on this analyse it will solve the semantic analyses problem.

# %%
import pandas as pd
import numpy as np
import urllib.request
import ijson       #Installing ijson from this websit: https://pypi.python.org/pypi/ijson#downloads
import itertools
import requests
import bs4
import nltk      #Installing nltk from this websit:http://www.nltk.org/install.html

# %%
#Web spider
root_url = "http://data.cstr.ed.ac.uk/globalvox/asr/2017/"
index_url = root_url + '?C=N;O=D'
def getUrls():
    response = requests.get(index_url)
    soup = bs4.BeautifulSoup(response.text, "lxml")
    #return [a.attrs.get('href') for a in soup.select('[href^=201706]')]
    return [a.attrs.get('href') for a in soup.select('[href^=2017]')]

urls = []
for item in getUrls():
    urls.append(root_url + item)
urls
# Out:
# ['http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170627_060900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_231400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_222100_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_152800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_151000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_133100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_122200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_114500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170626_060900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170625_231500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170625_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170625_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170625_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170624_233500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170624_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170624_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170624_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170624_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170624_030000_in_the_balance.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_230500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_151400_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_150500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_142900_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_142200_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_130400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_125600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_055500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170623_023000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_230600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_154400_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_151100_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_145300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_122200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_115000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_071000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170622_013000_the_inquiry.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_230500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_221300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_150500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_150300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_124300_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_120100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_103900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_075300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170621_074700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_230800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_221600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_153400_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_150100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_120500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_115700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170620_054000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_221700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_151500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_145000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_115700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_113000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_055100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_004300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170618_230900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170618_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170618_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170618_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170617_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170617_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170617_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170617_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170617_083900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170617_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170617_030000_in_the_balance.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_230200_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_222600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_152800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_141100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_140600_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_135700_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_134900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_085000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170616_054600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_230600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_215300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_153600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_145600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_113400_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_111000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_103500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_085100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_063500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170615_023000_the_inquiry.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_230500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_220300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_142900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_114200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_111600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_103300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_070500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170614_023000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_230400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_221500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_152000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_143000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_130800_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_120700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_115300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_114200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170613_062900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_230300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_224000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_151400_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_142900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_115200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_111900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_111000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_054400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170611_230300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170611_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170611_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170611_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170610_230900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170610_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170610_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170610_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170610_092600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170610_072500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170610_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170610_023000_in_the_balance.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_234300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_230800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_151300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_145600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_125700_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_123500_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_100300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_081000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170609_020600_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_204300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_203200_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_151400_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_143900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_141400_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_113600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_105800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_100000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170608_092200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170607_151300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170607_143500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170607_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170607_130000_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170607_092500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170607_090300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170607_085600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170607_055900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_231700_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_215200_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_155500_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_152600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_143100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_130000_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_121100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_115900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_113700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170606_060000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_221700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_172100_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_144400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_130000_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_114100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_113700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_112700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_055700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170604_230200_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170604_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170604_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170604_153900_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170604_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170604_123600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170603_224800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170603_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170603_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170603_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170603_080500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170603_070300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170603_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_234300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_222100_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_152600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_145500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_135200_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_130000_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_121700_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_121300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_114000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170602_064600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_224800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_223100_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_160800_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_152100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_143300_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_133400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_130000_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_120000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_064100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_013000_the_inquiry.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_225000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_223000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_150600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_150500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_142300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_130000_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_122400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_111000_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_064600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_232400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_150800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_141100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_130000_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_114600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_114500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170530_054200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_232000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_152000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_141700_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_105500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_103900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_103100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_095600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_054300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170529_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170528_230900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170528_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170528_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170528_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170527_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170527_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170527_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170527_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170527_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170527_023000_in_the_balance.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_222300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_151800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_150700_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_124900_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_121900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_121100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_113100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170526_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_232500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_225100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_151100_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_144200_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_120600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_114300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_112500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_063800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170525_013000_the_inquiry.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_213300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_151600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_145800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_102500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_094900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170524_062900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_231700_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_215000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_191700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_153300_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_145300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170523_093600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_230900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_215500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_152300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_151300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_142700_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_124700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_113600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_112800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_103800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_055000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_004500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170521_230300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170521_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170521_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170521_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170520_230400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170520_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170520_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170520_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170520_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170520_023000_in_the_balance.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_231600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_221500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_153200_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_150400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_134200_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_114600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_112900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_063700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170519_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_232600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_222700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_153800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_152400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_114100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_104200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_085200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_060500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170518_013000_the_inquiry.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_221900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_213700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_153500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_145300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_115000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_105700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_102200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_055000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170517_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_221400_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_153700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_143300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_113200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_111400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_072500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170516_060500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_232700_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_220800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_152600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_150200_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_132600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_123500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_114700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_110800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_104100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_003800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170514_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170514_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170514_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170513_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170513_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170513_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170513_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170513_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_225400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_224800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_151900_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_151800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_140100_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_133900_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_113900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_105500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_102200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_070200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170512_010600_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_230200_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_145000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_114700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_112100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_093600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_054900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170511_013000_the_inquiry.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_224700_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_221600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_171900_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_152800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_152000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_114400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_111400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_102900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_083500_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170510_063000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_232100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_161300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_143600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_123100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_115200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_104600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170509_070000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_233900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_155700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_142100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_121400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_113300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_100800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_055000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170507_231000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170507_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170507_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170507_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170506_231600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170506_211600_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170506_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170506_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170506_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170506_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_230700_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_214400_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_155300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_145900_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_141600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_111900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170505_105900_best_of_today.asr.json',
# ...
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170407_115400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170407_113200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170407_060900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_230300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_222600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_152600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_152400_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_115000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_112000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170406_013000_the_inquiry.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_231800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_223900_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_155300_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_150900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_150800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_115300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_061200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170405_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_230000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_223000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_150700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_142300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_113600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_111300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_101600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170404_054600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_225200_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_223300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_150800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_144000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_120200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_115000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_113000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170403_053900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170402_231100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170402_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170402_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170402_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_081300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_075800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_074700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_023000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_230100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_221300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_154000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_153200_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_151700_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_142400_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_132700_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_122100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_115500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_111500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_054200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170331_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_230500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_220100_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_152000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_150400_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_114900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_112700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_105600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_094600_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_064300_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170330_013000_the_inquiry.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_230400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_220800_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_144900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_115100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_094800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_063100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170329_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170328_231300_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170328_153700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170328_150900_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170328_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170328_115800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170328_090400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170328_082600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170328_055800_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_225600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_221000_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_173000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_154200_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_144000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_124500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_123100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_120900_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_080100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_071500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_013000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170327_003700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170326_230400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170326_210000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170326_171500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170326_130000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170326_000100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_220000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_181500_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_140000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_110100_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_103400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_090400_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_033000_the_world_this_week.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_003200_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170325_000200_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_220000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_183000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_161400_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_150000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_145600_the_fifth_floor.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_134500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_125200_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_121500_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_111700_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_100100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_070600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_023000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_011000_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170324_001900_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_220000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_183000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_182200_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_160100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_150000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_134500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_132000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_100100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_071000_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170323_014500_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_231300_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_220000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_183000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_182200_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_162800_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_150000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_134500_world_at_one.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_124600_best_of_today.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_102600_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_023000_hardtalk.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170322_000100_global_news_podcast.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170321_232700_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170321_220000_newshour.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170321_183000_six_oclock_news.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170321_181500_world_business_report.asr.json',
#  'http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170321_155700_global_news_podcast.asr.json',
#  ...]

# %%
Apr_week1 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170409_230100_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170401_023000_the_world_this_week.asr.json")+1]

Apr_week2 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170416_231800_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170410_092100_best_of_today.asr.json")+1]
     
Apr_week3 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170423_223900_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170417_013000_hardtalk.asr.json")+1]
     
Apr_week4 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170430_222100_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170424_004200_world_business_report.asr.json")+1]

May_week1 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170507_231000_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170501_054100_best_of_today.asr.json")+1]

May_week2 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170514_230100_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170508_055000_best_of_today.asr.json")+1]

May_week3 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170521_230300_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170515_003800_world_business_report.asr.json")+1]

May_week4 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170531_225000_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170522_004500_world_business_report.asr.json")+1]

Jun_week1 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170604_230200_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170601_013000_the_inquiry.asr.json")+1]

Jun_week2 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170611_230300_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170605_055700_best_of_today.asr.json")+1]

Jun_week3 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170618_230900_global_news_podcast.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170612_054400_best_of_today.asr.json")+1]

Jun_week4 = urls[urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170627_060900_best_of_today.asr.json"):
            urls.index("http://data.cstr.ed.ac.uk/globalvox/asr/2017/20170619_004300_world_business_report.asr.json")+1]

# %%
urls = Apr_week1
a = []
for item in urls:     #April_week1
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")    #Dismantling json
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]    #Dismantling json
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)
spokenWords_Apr_week1 = list(itertools.chain.from_iterable(a))

urls = Apr_week2
a = []
for item in urls:     #April_week2
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)
spokenWords_Apr_week2 = list(itertools.chain.from_iterable(a))

urls = Apr_week3   #April_week3
a = []
for item in urls:     
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)
spokenWords_Apr_week3 = list(itertools.chain.from_iterable(a))

urls = Apr_week4   #April_week4
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_Apr_week4 = list(itertools.chain.from_iterable(a))

# %%
urls = May_week1   
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_May_week1 = list(itertools.chain.from_iterable(a))

urls = May_week2   
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_May_week2 = list(itertools.chain.from_iterable(a))

urls = May_week3   
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_May_week3 = list(itertools.chain.from_iterable(a))

urls = May_week4
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_May_week4 = list(itertools.chain.from_iterable(a))

# %%
urls = Jun_week1
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_Jun_week1 = list(itertools.chain.from_iterable(a))

urls = Jun_week2
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_Jun_week2 = list(itertools.chain.from_iterable(a))

urls = Jun_week3
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")      #
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_Jun_week3 = list(itertools.chain.from_iterable(a))

urls = Jun_week4
a = []
for item in urls:
    f = urllib.request.urlopen(item)
    objects = ijson.items(f, "segments.item")
    segments = list (objects)
    spokenWords = [words["spokenWords"] for words in segments]
    spokenWords = list(itertools.chain.from_iterable(spokenWords))
    a.append(spokenWords)  
spokenWords_Jun_week4 = list(itertools.chain.from_iterable(a))

# %%
spokenWords = spokenWords_Apr_week1

cols = list(spokenWords[0].keys())       #integrating the data become DataFrame
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)

df = pd.DataFrame(rows, index = indices, columns = cols)

df_Apr_week1 = df.convert_objects(convert_numeric=True)
df_Apr_week1
# Out:
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
#         wordEnd      wordId  wordStart  wordConfidence
# 0          7.81        THIS       7.58            1.00
# 1          7.94          IS       7.81            1.00
# 2          8.03         THE       7.94            1.00
# 3          8.72      B.B.C.       8.03            0.99
# 4          9.31         FOR       9.17            0.98
# 5          9.80     DETAILS       9.31            1.00
# 6          9.88          OF       9.80            0.97
# 7         10.00           A       9.88            0.86
# 8         10.50    COMPLETE      10.00            1.00
# 9         10.77       RANGE      10.50            1.00
# 10        10.86          OF      10.77            1.00
# 11        11.49  PROGRAMMES      10.86            1.00
# 12        11.88          GO      11.69            1.00
# 13        12.00          TO      11.88            1.00
# 14        12.59      B.B.C.      12.00            1.00
# 15        12.95       WORLD      12.59            1.00
# 16        13.40     SERVICE      12.95            1.00
# 17        13.66         DOT      13.40            1.00
# 18        14.05         COM      13.66            1.00
# 19        14.64     FORWARD      14.31            1.00
# 20        14.90       SLASH      14.64            1.00
# 21        19.52     WELCOME      19.11            1.00
# 22        19.62          TO      19.52            1.00
# 23        19.71         THE      19.62            1.00
# 24        20.14      LATEST      19.71            1.00
# 25        20.56      GLOBAL      20.14            1.00
# 26        20.99        NEWS      20.56            1.00
# 27        21.44    COMPILED      20.99            1.00
# 28        21.55          IN      21.44            1.00
# 29        21.69         THE      21.55            1.00
# ...         ...         ...        ...             ...
# 374240  1404.65     SERVICE    1404.27            1.00
# 374241  1404.89         VIA    1404.65            0.96
# 374242  1405.35    FACEBOOK    1404.89            1.00
# 374243  1405.56          OR    1405.38            1.00
# 374244  1406.07     TWITTER    1405.56            1.00
# 374245  1406.55         AND    1406.29            1.00
# 374246  1406.81       DON'T    1406.58            1.00
# 374247  1407.09      FORGET    1406.81            1.00
# 374248  1407.19          TO    1407.09            1.00
# 374249  1407.43        JOIN    1407.19            1.00
# 374250  1407.72       PETER    1407.43            0.86
# 374251  1408.05        HUNT    1407.72            1.00
# 374252  1408.18          AT    1408.08            1.00
# 374253  1408.25         THE    1408.18            1.00
# 374254  1408.52        SAME    1408.25            1.00
# 374255  1408.77        TIME    1408.52            1.00
# 374256  1409.08        NEXT    1408.77            1.00
# 374257  1409.36        WEEK    1409.08            1.00
# 374258  1409.63         FOR    1409.45            1.00
# 374259  1409.71           A    1409.63            1.00
# 374260  1409.97        LOOK    1409.71            1.00
# 374261  1410.32        BACK    1409.97            1.00
# 374262  1410.47          AT    1410.32            1.00
# 374263  1410.68        WHAT    1410.47            0.89
# 374264  1411.13    HAPPENED    1410.68            1.00
# 374265  1411.37          IN    1411.19            1.00
# 374266  1411.43         THE    1411.37            1.00
# 374267  1411.68        NEXT    1411.43            1.00
# 374268  1411.92       SEVEN    1411.68            1.00
# 374269  1412.25        DAYS    1411.92            1.00
#
# [374270 rows x 4 columns]

# %%
spokenWords = spokenWords_Apr_week2
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_Apr_week2 = df.convert_objects(convert_numeric=True)

spokenWords = spokenWords_Apr_week3
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_Apr_week3 = df.convert_objects(convert_numeric=True)

spokenWords = spokenWords_Apr_week4
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)

df = pd.DataFrame(rows, index = indices, columns = cols)
df_Apr_week4 = df.convert_objects(convert_numeric=True)
# Out:
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if sys.path[0] == '':
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:39: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
spokenWords = spokenWords_May_week1
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_May_week1 = df.convert_objects(convert_numeric=True)

spokenWords = spokenWords_May_week2
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_May_week2 = df.convert_objects(convert_numeric=True)

spokenWords = spokenWords_May_week3
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_May_week3 = df.convert_objects(convert_numeric=True)

spokenWords = spokenWords_May_week4
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_May_week4 = df.convert_objects(convert_numeric=True)
# Out:
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if sys.path[0] == '':
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:38: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:51: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
spokenWords = spokenWords_Jun_week1
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_Jun_week1 = df.convert_objects(convert_numeric=True)

spokenWords = spokenWords_Jun_week2
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_Jun_week2 = df.convert_objects(convert_numeric=True)

spokenWords = spokenWords_Jun_week3
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_Jun_week3 = df.convert_objects(convert_numeric=True)

spokenWords = spokenWords_Jun_week4
cols = list(spokenWords[0].keys())
rows = []
indices = []
for index, d in enumerate(spokenWords):
    indices.append(index)
    values = []
    for col in cols:
        values.append(d[col])
    rows.append(values)
df = pd.DataFrame(rows, index = indices, columns = cols)
df_Jun_week4 = df.convert_objects(convert_numeric=True)
# Out:
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if sys.path[0] == '':
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:38: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/Kunry/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:51: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
#Removing extra symbols

strWordId = df_Apr_week1
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_Apr_week1 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")


strWordId = df_Apr_week2
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_Apr_week2 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

strWordId = df_Apr_week3
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_Apr_week3 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

strWordId = df_Apr_week4
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_Apr_week4 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

# %%
strWordId = df_May_week1
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_May_week1 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

strWordId = df_May_week2
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_May_week2 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

strWordId = df_May_week3
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_May_week3 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

strWordId = df_May_week4
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_May_week4 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

# %%
strWordId = df_Jun_week1
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_Jun_week1 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

strWordId = df_Jun_week2
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_Jun_week2 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

strWordId = df_Jun_week3
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_Jun_week3 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

strWordId = df_Jun_week4
strWordId = str(list(strWordId.wordId))
strWordId = strWordId.replace('"', "'")
strWordId = strWordId.replace("'", "")
strWordId = strWordId.replace("[", "")
strWordId = strWordId.replace("]", "")
strWordId = strWordId.replace(",", "")
strWordId = strWordId.replace("CONSERVATIVES ", "CONSERVATIVE ")
strWordId = strWordId.replace("ATTACKER ", "ATTACK ")
strWordId = strWordId.replace("TERRORISTS ", "TERRORIST ")
strWordId_Jun_week4 = strWordId.replace("INVESTMENTS ", "INVESTMENT ")

# %%
#add and integrate stopwords
from nltk.corpus import stopwords
from stop_words import get_stop_words
stop_words = get_stop_words('english')
stop_words = str(stop_words)

stop_words = stop_words.replace('"', "'")
stop_words = stop_words.replace(" '", "'")
stop_words = stop_words.replace("'", "")
stop_words = stop_words.replace("[", "")
stop_words = stop_words.replace("]", "")

stop_words = stop_words.split(',',-1)
myAddstopwords = ["people", "time", "years", "year", "way", "today", "country", "news", "things", "something", "part", "lot", "day", "course", "kind", "point", "b.b.c", "government", "world", "president"]
stopwords = stopwords.words('english') + stop_words + myAddstopwords

# %%
#natural language processing function to get noun

strWordId = strWordId_Apr_week1
sentences=nltk.sent_tokenize(strWordId)
words=[word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)] #单词化
words=[word for word in words if word not in stopwords] #去除停用词
word_tag_Apr_week1=[var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']] #词性标注并选择出名词和动词

strWordId = strWordId_Apr_week2
sentences = nltk.sent_tokenize(strWordId)
words=[word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words=[word for word in words if word not in stopwords]
word_tag_Apr_week2=[var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

strWordId = strWordId_Apr_week3
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_Apr_week3 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

strWordId = strWordId_Apr_week4
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_Apr_week4 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

# %%
strWordId = strWordId_May_week1
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_May_week1 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

strWordId = strWordId_May_week2
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_May_week2 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

strWordId = strWordId_May_week3
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_May_week3 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

strWordId = strWordId_May_week4
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_May_week4 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

# %%
strWordId = strWordId_Jun_week1
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_Jun_week1 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

strWordId = strWordId_Jun_week2
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_Jun_week2 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

strWordId = strWordId_Jun_week3
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_Jun_week3 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

strWordId = strWordId_Jun_week4
sentences = nltk.sent_tokenize(strWordId)
words = [word.lower() for sentence in sentences for word in nltk.word_tokenize(sentence)]
words = [word for word in words if word not in stopwords]
word_tag_Jun_week4 = [var[0] for var in nltk.pos_tag(words) if var[1][0] in ['N']]

# %%
import collections

data = word_tag_Apr_week1
data = collections.Counter(data).most_common()        #Word repetition frequency
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-04 week1"
data_Apr_week1 = data.sort_values(by = 'repeat',ascending = False)  
data_Apr_week1
# Out:
#               words  repeat           date
# 0            attack     439  2017-04 week1
# 1           weapons     371  2017-04 week1
# 2             trump     318  2017-04 week1
# 3            police     286  2017-04 week1
# 4             state     266  2017-04 week1
# 5               war     257  2017-04 week1
# 6           service     256  2017-04 week1
# 7             syria     254  2017-04 week1
# 8          security     254  2017-04 week1
# 9          business     251  2017-04 week1
# 10             city     234  2017-04 week1
# 11         children     227  2017-04 week1
# 12           states     224  2017-04 week1
# 13           twenty     224  2017-04 week1
# 14              man     223  2017-04 week1
# 15             sort     221  2017-04 week1
# 16         chemical     220  2017-04 week1
# 17             week     218  2017-04 week1
# 18            china     213  2017-04 week1
# 19            thing     212  2017-04 week1
# 20            money     207  2017-04 week1
# 21             work     205  2017-04 week1
# 22           action     205  2017-04 week1
# 23              air     197  2017-04 week1
# 24            house     194  2017-04 week1
# 25           moment     192  2017-04 week1
# 26           policy     190  2017-04 week1
# 27         minister     187  2017-04 week1
# 28           russia     182  2017-04 week1
# 29             look     181  2017-04 week1
# ...             ...     ...            ...
# 7340    defenceless       1  2017-04 week1
# 7327            s.e       1  2017-04 week1
# 7328   manipulating       1  2017-04 week1
# 7329    destabilise       1  2017-04 week1
# 7330         torque       1  2017-04 week1
# 7331        violate       1  2017-04 week1
# 7332         rulers       1  2017-04 week1
# 7333        adjunct       1  2017-04 week1
# 7334         berias       1  2017-04 week1
# 7335    spontaneity       1  2017-04 week1
# 7336       welcomes       1  2017-04 week1
# 7337         whites       1  2017-04 week1
# 7338           diet       1  2017-04 week1
# 7339           moat       1  2017-04 week1
# 7341           gent       1  2017-04 week1
# 7355         artics       1  2017-04 week1
# 7342           yana       1  2017-04 week1
# 7343         gellen       1  2017-04 week1
# 7344         header       1  2017-04 week1
# 7345         scutes       1  2017-04 week1
# 7346       bustling       1  2017-04 week1
# 7347          argot       1  2017-04 week1
# 7348       washburn       1  2017-04 week1
# 7349     communists       1  2017-04 week1
# 7350       kindness       1  2017-04 week1
# 7351      bourgeois       1  2017-04 week1
# 7352        elitist       1  2017-04 week1
# 7353    memberships       1  2017-04 week1
# 7354        mirrors       1  2017-04 week1
# 10132     calibrate       1  2017-04 week1
#
# [10133 rows x 3 columns]

# %%
data = word_tag_Apr_week2
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-04 week2"
data_Apr_week2 = data.sort_values(by = 'repeat',ascending = False)

data = word_tag_Apr_week3
data = collections.Counter(data).most_common()        
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-04 week3"
data_Apr_week3 = data.sort_values(by = 'repeat',ascending = False)   

data = word_tag_Apr_week4
data = collections.Counter(data).most_common()        
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-04 week4"
data_Apr_week4 = data.sort_values(by = 'repeat',ascending = False)

# %%
data = word_tag_May_week1
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-05 week1"
data_May_week1 = data.sort_values(by = 'repeat',ascending = False)

data = word_tag_May_week2
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-05 week2"
data_May_week2 = data.sort_values(by = 'repeat',ascending = False)

data = word_tag_May_week3
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-05 week3"
data_May_week3 = data.sort_values(by = 'repeat',ascending = False)

data = word_tag_May_week4
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-05 week4"
data_May_week4 = data.sort_values(by = 'repeat',ascending = False)

# %%
data = word_tag_Jun_week1
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-06 week1"
data_Jun_week1 = data.sort_values(by = 'repeat',ascending = False)

data = word_tag_Jun_week2
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-06 week2"
data_Jun_week2 = data.sort_values(by = 'repeat',ascending = False)

data = word_tag_Jun_week3
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-06 week3"
data_Jun_week3 = data.sort_values(by = 'repeat',ascending = False)

data = word_tag_Jun_week4
data = collections.Counter(data).most_common()       
data = pd.DataFrame(data)
data.columns=["words", "repeat"]
data["date"] = "2017-06 week4"
data_Jun_week4 = data.sort_values(by = 'repeat',ascending = False)

# %%
dataSelect = data_Apr_week1
dataSelect_Apr_week1 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_Apr_week2
dataSelect_Apr_week2 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_Apr_week3
dataSelect_Apr_week3 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_Apr_week4
dataSelect_Apr_week4 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

# %%
dataSelect = data_May_week1
dataSelect_May_week1 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_May_week2
dataSelect_May_week2 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_May_week3
dataSelect_May_week3 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_May_week4
dataSelect_May_week4 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

# %%
dataSelect = data_Jun_week1
dataSelect_Jun_week1 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_Jun_week2
dataSelect_Jun_week2 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_Jun_week3
dataSelect_Jun_week3 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

dataSelect = data_Jun_week4
dataSelect_Jun_week4 = dataSelect [(dataSelect["words"] == "trump")|(dataSelect["words"] == "conservative")|(dataSelect["words"] == "theresa")
                                   |(dataSelect["words"] == "attack")|(dataSelect["words"] == "labour")|(dataSelect["words"] == "jeremy")
                                   |(dataSelect["words"] == "timothy")|(dataSelect["words"] == "democrats")]

# %%
a = word_tag_Apr_week1
b = word_tag_Apr_week2
c = word_tag_Apr_week3
d = word_tag_Apr_week4

e = np.array(a + b + c + d)
month_data = pd.DataFrame(e)
month_data.columns=["April_words"]
month_data = pd.DataFrame({'repeat' : month_data.groupby( ["April_words"] ).size()}).reset_index()
april_data = month_data.sort_values(by = 'repeat',ascending = False)
april_data
# Out:
#         April_words  repeat
# 5812       election    1437
# 12687         party    1035
# 16584         state    1020
# 18190        twenty     889
# 1038         attack     867
# 11337      minister     847
# 18080         trump     792
# 13240        police     790
# 2494       business     785
# 11493         money     774
# 15607       service     761
# 10684           man     754
# 19119          work     744
# 3188       children     738
# 17556         thing     738
# 16285          sort     736
# 16588        states     733
# 17558         think     702
# 15481      security     693
# 11477        moment     689
# 10236          life     687
# 6992         france     672
# 18868          week     664
# 8499          house     645
# 18751           war     635
# 13113         place     630
# 3321           city     619
# 2660       campaign     616
# 10398          look     613
# 4626           days     605
# ...             ...     ...
# 6771     flashlight       1
# 6770        flashes       1
# 6723         firsts       1
# 13682       prompts       1
# 6724          firth       1
# 13680     promoters       1
# 6726         fisher       1
# 6727      fisherman       1
# 6728     fishermans       1
# 13675   promiscuity       1
# 6736          fitch       1
# 13672     promenade       1
# 6740        fitting       1
# 13669   proletariat       1
# 13668        proles       1
# 6745       fixation       1
# 13665    projection       1
# 13664    projecting       1
# 6747         fixers       1
# 6748          fixes       1
# 6751         fizzes       1
# 13660  progressives       1
# 6752          fizzy       1
# 6755       flagging       1
# 13654   programmers       1
# 6763       flamingo       1
# 6766       flankers       1
# 6767        flapper       1
# 6768          flare       1
# 5309      diversify       1
#
# [19349 rows x 2 columns]

# %%
a = word_tag_May_week1
b = word_tag_May_week2
c = word_tag_May_week3
d = word_tag_May_week4

e = np.array(a + b + c + d)
month_data = pd.DataFrame(e)
month_data.columns=["May_words"]
month_data = pd.DataFrame({'repeat' : month_data.groupby( ["May_words"] ).size()}).reset_index()
may_data = month_data.sort_values(by = 'repeat',ascending = False)
may_data
# Out:
#             May_words  repeat
# 5966         election    1534
# 13015           party    1130
# 18444           trump     998
# 13601          police     941
# 18545          twenty     925
# 17940           thing     918
# 11796           money     893
# 19485            work     886
# 15998         service     862
# 15873        security     844
# 16975           state     835
# 17941           think     775
# 16654            sort     774
# 2573         business     773
# 3414             city     773
# 11638        minister     770
# 10482            life     748
# 2731         campaign     745
# 19217            week     730
# 10660            look     726
# 8700            house     725
# 12396          number     716
# 13459           place     700
# 6547             fact     700
# 11783          moment     698
# 1878              bit     692
# 10956             man     689
# 4255    correspondent     670
# 3128           change     644
# 4799             deal     640
# ...               ...     ...
# 6957             flew       1
# 6956          fleurie       1
# 6899          fissure       1
# 6908            fitzy       1
# 6909            fives       1
# 6911         fixation       1
# 6915          fixture       1
# 13974         probing       1
# 6916             fizz       1
# 13972         probert       1
# 6918         flagging       1
# 6923            flake       1
# 6926         flamenco       1
# 6927           flames       1
# 6930         flanagan       1
# 6932           flares       1
# 13963      privileges       1
# 13961          privet       1
# 6936             flat       1
# 13959  privatisations       1
# 6940       flatulence       1
# 6941       flavonoids       1
# 6945         flawless       1
# 13954           priti       1
# 6947             flax       1
# 13952          prissy       1
# 6951            flees       1
# 6954         fletcher       1
# 6955            fleur       1
# 19719              zz       1
#
# [19720 rows x 2 columns]

# %%
a = word_tag_Jun_week1
b = word_tag_Jun_week2
c = word_tag_Jun_week3
d = word_tag_Jun_week4

e = np.array(a + b + c + d)
month_data = pd.DataFrame(e)
month_data.columns=["June_words"]
month_data = pd.DataFrame({'repeat' : month_data.groupby( ["June_words"] ).size()}).reset_index() 
june_data = month_data.sort_values(by = 'repeat',ascending = False)
june_data
# Out:
#           June_words  repeat
# 11448          party    1292
# 5255        election    1231
# 10226       minister    1091
# 6086            fire     975
# 11978         police     848
# 17285           work     816
# 15882          thing     794
# 2208        business     749
# 10926         number     742
# 4217            deal     730
# 10372          money     694
# 16458         twenty     687
# 14761           sort     679
# 15041          state     674
# 2985            city     643
# 15883          think     631
# 9393            look     624
# 15873        theresa     621
# 9380          london     609
# 10355         moment     606
# 14157        service     602
# 16567          union     595
# 9058          leader     585
# 17048           week     584
# 9636             man     583
# 3725   correspondent     582
# 1585             bit     575
# 4205            days     575
# 15796          terms     572
# 2367        campaign     568
# ...              ...     ...
# 7048            guji       1
# 1522           biggs       1
# 7024       guardians       1
# 781         arriving       1
# 7007            grub       1
# 6993     groundswell       1
# 783           arrows       1
# 1527            biko       1
# 784             arse       1
# 6996         groupie       1
# 6997        grouping       1
# 6999          groves       1
# 12402    proprietors       1
# 12401     proprietor       1
# 7001          grower       1
# 1524          bigots       1
# 7010        gruesome       1
# 7022     guardbridge       1
# 7011           gruff       1
# 7012         grumeti       1
# 7013          gruner       1
# 788         arteries       1
# 7015              gu       1
# 12386     propensity       1
# 12385        propels       1
# 12384     propagator       1
# 12383  propagandists       1
# 7016           guage       1
# 7017      guantanamo       1
# 9849           mathy       1
#
# [17479 rows x 2 columns]

# %%
a = np.array(dataSelect_Apr_week1)
b = np.array(dataSelect_Apr_week2)
c = np.array(dataSelect_Apr_week3)
d = np.array(dataSelect_Apr_week4)
e = np.array(dataSelect_May_week1)
f = np.array(dataSelect_May_week2)
g = np.array(dataSelect_May_week3)
h = np.array(dataSelect_May_week4)
i = np.array(dataSelect_Jun_week1)
j = np.array(dataSelect_Jun_week2)
k = np.array(dataSelect_Jun_week3)
l = np.array(dataSelect_Jun_week4)
m = np.vstack((a, b, c, d, e, f, g, h, i, j, k, l))
words_data = pd.DataFrame(m)
words_data.columns=["words", "repeat","date"]
words_data = words_data.pivot(index="date", columns="words", values="repeat")
words_data
# Out:
# words         attack democrats jeremy labour theresa timothy trump
# date
# 2017-04 week1    439        13     33     25      36    None   318
# 2017-04 week2    198         2     15     10       6    None   160
# 2017-04 week3    143        61    112     99     176    None    82
# 2017-04 week4     87        32     57     48      67    None   232
# 2017-05 week1     48        58     55     70      93    None    71
# 2017-05 week2     72        91     81     96      76    None   237
# 2017-05 week3     49        46     68     76      61       3   342
# 2017-05 week4    436        14    141     67     142    None   348
# 2017-06 week1    137        42     65     64      90       1   159
# 2017-06 week2    194        41    159    126     261       3   133
# 2017-06 week3     35        21     32     38     137       3   124
# 2017-06 week4     91        32     61     34     133    None   114

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline

# %%
dataSelect = april_data
dataSelect = dataSelect [dataSelect["repeat"] > 750]        
sns.factorplot(data=dataSelect, x="April_words", y="repeat", kind="bar", size=8)
plt.title('Hot words ranking in April 2017')

dataSelect = may_data
dataSelect = dataSelect [dataSelect["repeat"] > 800]        
sns.factorplot(data=dataSelect, x="May_words", y="repeat", kind="bar", size=8)
plt.title('Hot words ranking in May 2017')

dataSelect = june_data
dataSelect = dataSelect [dataSelect["repeat"] > 700]        
sns.factorplot(data=dataSelect, x="June_words", y="repeat", kind="bar", size=8)
plt.title('Hot words ranking in June 2017')

# %% [markdown]
# According to the hot words in 3 months. We can see the general election event during this period. It is because, in April, May, June, the high-frequent news words are election, party. But there are also some high-frequent negative news words, such as attack, fire, police. So, I think the world is not very stable during this period.

# %%
dfp = words_data

fig, ax = plt.subplots(1, 1, figsize=(15, 6))

dfp.plot(ax=ax)

ax.set(xlabel='Date', ylabel='Repeat', title='Timelines')

ax.legend(loc=1)
fig.autofmt_xdate()

# %% [markdown]
# Looking at this figure, I find the rate of media exposure in presidential candidates can predict the future president. Before the 8th June, the three presidential candidates had the different rate of media exposure. In general, the Theresa media exposure rate was higher than other two candidates. However, it seems that the candidate's success has nothing to do with the media exposure of their political party. Through this line chart, we can find the Theresa's Conservative Party did not get lots of media exposure. In contrast, the Jeremy's Labour Party had a range of media exposure, even the rate was higher than the Jeremy. But he still lost.
#
# Interestingly, during the period of UK general election, the America president Trump's media exposure rate was much higher than British future president. Probably, Trump made some global news at that time.
#
# There is an important data we must pay more attention. The news about "attack", it increased sharply between the period of the third week in May 2017 and the first week in June 2017. This time was the key period in UK general election. So we need to increase the self-protection awareness in this kind of sensitive period.
